# %%
from google.colab import drive
# Mount Google Drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import cohen_kappa_score
import seaborn as sns
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.xception import Xception
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.utils import model_to_dot
from PIL import Image
from keras.applications import ResNet152V2
from keras.models import Sequential
from keras.layers import GaussianNoise, GlobalAveragePooling2D, Dense, BatchNormalization, Dropout, Flatten
import json
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

# %%
! unzip "/content/gdrive/MyDrive/25K.zip" #
#! unzip "/content/gdrive/MyDrive/50K.zip" #
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3940.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3949.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3954.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3957.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3964.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_397.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3970.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3975.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3980.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3988.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3991.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3994.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_3996.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4000.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4002.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4003.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4004.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4005.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4006.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4008.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4009.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_401.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4010.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4014.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4034.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4037.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4040.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4043.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4051.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4054.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4062.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4070.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4071.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4073.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4077.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4078.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4082.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4088.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_409.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4092.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4094.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_410.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4104.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4107.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4109.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4115.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4118.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4122.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4131.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4133.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4135.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4137.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4139.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4140.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4143.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4146.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4149.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4151.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4155.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4161.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4162.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4164.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4165.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4167.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4168.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4169.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_417.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4175.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4179.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4181.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4194.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4197.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4201.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4205.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4208.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4212.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4213.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4215.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4216.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_422.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4220.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4221.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4222.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4223.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4226.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4228.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4229.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4231.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4232.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4233.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4235.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4237.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4247.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4249.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4250.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4253.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4256.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4257.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4260.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4262.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4268.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_427.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4270.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4272.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4275.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4276.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_428.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4285.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4288.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4292.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4294.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_43.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_430.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4303.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4304.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4305.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4309.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_431.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4312.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4314.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4316.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4318.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_432.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4323.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4325.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4328.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4329.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_433.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4331.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4332.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4333.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4335.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4350.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4354.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4357.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4367.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4379.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_438.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4383.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4386.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4387.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4388.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4392.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4393.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4394.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4397.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4401.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4404.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4405.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4409.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_441.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4416.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4425.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4426.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4433.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4436.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4437.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4438.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4441.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4443.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_445.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4454.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4456.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4457.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4465.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_447.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4470.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4471.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4475.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4477.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4479.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4480.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4482.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4485.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4487.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_449.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4490.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4493.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4497.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_45.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4502.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4504.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_451.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4511.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4514.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4519.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4523.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4524.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4535.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4538.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4539.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4546.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4547.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4550.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4551.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4553.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4556.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4560.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4564.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4569.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_457.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4579.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4583.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4585.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4586.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4594.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4596.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4598.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4600.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4604.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4606.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_461.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4612.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4614.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4617.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4621.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4641.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4643.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4645.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4647.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4648.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4649.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4650.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4656.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4658.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4659.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4665.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4668.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4672.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4673.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4674.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4675.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4677.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4679.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4681.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4684.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4687.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4688.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_469.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4690.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4691.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4692.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4695.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4696.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4697.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4699.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4706.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4707.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4709.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4710.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4718.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4719.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4721.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4726.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_473.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4733.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4735.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4739.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_474.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4741.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4742.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4744.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4759.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4767.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4770.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4772.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4773.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4774.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4779.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4780.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4781.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4790.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4792.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4796.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4798.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4802.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4807.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4809.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4814.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_482.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4822.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4823.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4824.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4825.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4826.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4828.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_483.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4831.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4833.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4840.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4841.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4843.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4845.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4846.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_485.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4850.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4853.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4856.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4858.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4861.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4879.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_488.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4881.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4882.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4886.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4891.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4894.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4896.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4898.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4900.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4901.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4904.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4908.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4913.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_492.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4921.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4925.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4929.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_493.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4937.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4943.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4944.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4954.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4957.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_496.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4961.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4963.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4965.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4966.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4967.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4968.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4969.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4970.png
#  extracting: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4971.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4972.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4973.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4977.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_498.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4980.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4983.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4984.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_499.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4990.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4991.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_4994.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_500.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_5000.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_501.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_506.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_51.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_513.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_518.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_52.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_520.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_523.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_524.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_525.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_531.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_533.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_534.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_539.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_542.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_543.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_546.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_548.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_55.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_551.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_553.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_558.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_559.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_561.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_565.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_570.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_574.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_578.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_580.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_581.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_591.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_592.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_594.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_596.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_597.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_60.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_602.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_608.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_613.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_615.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_616.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_617.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_619.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_62.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_623.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_629.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_630.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_632.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_634.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_635.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_636.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_637.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_64.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_642.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_643.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_650.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_651.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_662.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_665.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_672.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_675.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_678.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_682.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_685.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_689.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_694.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_696.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_697.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_698.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_699.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_700.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_702.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_706.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_717.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_72.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_720.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_734.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_737.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_740.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_742.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_744.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_748.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_752.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_755.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_756.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_76.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_764.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_771.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_772.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_773.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_774.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_777.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_782.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_79.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_790.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_793.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_794.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_798.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_80.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_800.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Large_cell_carcinoma/Large_cell_carcinoma_805.png
# ...
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_535.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_536.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_54.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_546.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_547.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_548.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_555.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_558.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_56.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_560.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_564.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_575.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_582.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_587.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_595.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_596.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_599.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_60.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_606.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_612.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_613.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_62.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_625.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_626.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_630.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_633.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_639.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_643.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_648.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_656.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_658.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_663.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_668.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_670.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_672.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_673.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_676.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_677.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_678.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_680.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_684.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_686.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_687.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_688.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_689.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_690.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_691.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_694.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_695.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_70.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_701.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_709.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_71.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_713.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_714.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_716.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_720.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_724.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_729.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_732.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_738.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_741.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_743.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_744.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_75.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_751.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_762.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_766.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_77.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_772.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_773.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_774.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_777.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_780.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_790.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_793.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_794.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_798.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_8.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_800.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_802.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_803.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_806.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_807.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_808.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_81.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_811.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_815.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_821.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_823.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_828.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_829.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_835.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_845.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_852.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_859.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_862.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_865.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_866.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_867.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_870.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_872.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_873.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_875.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_878.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_879.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_885.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_889.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_890.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_894.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_904.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_905.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_906.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_907.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_908.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_917.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_919.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_92.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_922.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_923.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_926.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_930.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_931.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_936.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_940.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_947.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_949.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_951.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_958.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_961.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_962.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_965.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_967.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_968.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_974.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_976.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_977.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_979.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_980.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_984.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_994.png
#   inflating: NSCLC_Radiomics_50k_splitted2/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_997.png

# %%
path = "/content/NSCLC_Radiomics_50k_splitted2" #25K
#path = "/content/NSCLC_Radiomics_50k_TTV" #50K + cost sensitive

# %%
train_ds = keras.utils.image_dataset_from_directory(
    f"{path}/train",
    labels='inferred',
    label_mode='int',
    batch_size=64,
    image_size=(300, 300)

)

test_ds = keras.utils.image_dataset_from_directory(
    f"{path}/test",
    labels='inferred',
    label_mode='int',
    batch_size=64,
    image_size=(300, 300)

)

val_ds = keras.utils.image_dataset_from_directory(
    f"{path}/validation",
    labels='inferred',
    label_mode='int',
    batch_size=64,
    image_size=(300, 300)

)
# Out:
# Found 10000 files belonging to 5 classes.
# Found 7500 files belonging to 5 classes.
# Found 7500 files belonging to 5 classes.

# %%
# Define the new image size
new_image_size = (80, 80)

# Function to resize images
def resize_image(image, label):
    image = tf.image.resize(image, new_image_size)
    return image, label

# Apply resizing to the datasets
train_ds = train_ds.map(resize_image)
test_ds = test_ds.map(resize_image)
val_ds = val_ds.map(resize_image)

# %%
# Normalize the pixel values
def preprocess(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)  # Convert to float32
    image = image / 255.0  # Normalize pixel values
    return image, label

# Apply preprocessing to the datasets
train_ds = train_ds.map(preprocess)
test_ds = test_ds.map(preprocess)
val_ds = val_ds.map(preprocess)

# One-hot encode the labels
num_classes = 5  # Update with the actual number of classes
train_ds = train_ds.map(lambda image, label: (image, tf.one_hot(label, num_classes)))
test_ds = test_ds.map(lambda image, label: (image, tf.one_hot(label, num_classes)))
val_ds = val_ds.map(lambda image, label: (image, tf.one_hot(label, num_classes)))

# Configure the datasets for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super().__init__()
        self.teacher = teacher
        self.student = student

    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.7, # 0.3,0.5,0.7
        temperature=30, #7,15,22,30
    ):
        """ Configure the distiller.

        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super().compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        x, y = data

        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)

        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)

            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)

            # Compute scaled distillation loss from https://arxiv.org/abs/1503.02531
            # The magnitudes of the gradients produced by the soft targets scale
            # as 1/T^2, multiply them by T^2 when using both hard and soft targets.
            distillation_loss = (
                self.distillation_loss_fn(
                    tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                    tf.nn.softmax(student_predictions / self.temperature, axis=1),
                )
                * self.temperature**2
            )

            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss

        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))

        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        x, y = data

        # Compute predictions
        y_prediction = self.student(x, training=False)

        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)

        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)

        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %%
num_classes = 5
num_positions = 144  # Example for 18x18 image patches
input_shape = (80, 80, 3)
learning_rate = 0.001
weight_decay = 0.0001  # Increase weight decay if overfitting occurs
batch_size = 64
num_epochs = 100
image_size = 80
patch_size = 12
# Increase model complexity
transformer_layers = 1  # Increase the number of Transformer layers
projection_dim = 256    # Increase projection dimension(256)
num_heads = 4
num_patches = (image_size // patch_size) ** 2
transformer_units = [projection_dim , projection_dim]
mlp_head_units = [256, 128, 64]  # Increase MLP size[256, 128, 64]
          # Increase the number of attention heads

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = keras.Input(shape=input_shape)

    # Create patches.
    patches = Patches(patch_size)(inputs)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = layers.Dropout(0.1)(x3)  # Adjust dropout rate
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # MLP head
    mlp = layers.Dense(256, activation="relu")(representation)  # You can modify the size of the MLP
    mlp = layers.Dropout(0.5)(mlp)
    mlp = layers.Dense(128, activation="relu")(mlp)  # Add more dense layers as needed

    # Classify outputs.
    logits = layers.Dense(num_classes, activation="softmax")(mlp)  # Output layer for classification

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
vit = create_vit_classifier();
vit.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 80, 80, 3)]          0         []
#
#  patches (Patches)           (None, None, 432)            0         ['input_1[0][0]']
#
#  patch_encoder (PatchEncode  (None, 36, 256)              120064    ['patches[0][0]']
#  r)
#
#  layer_normalization (Layer  (None, 36, 256)              512       ['patch_encoder[0][0]']
#  Normalization)
#
#  multi_head_attention (Mult  (None, 36, 256)              1051904   ['layer_normalization[0][0]',
#  iHeadAttention)                                                     'layer_normalization[0][0]']
#
#  add (Add)                   (None, 36, 256)              0         ['multi_head_attention[0][0]',
#                                                                      'patch_encoder[0][0]']
#
#  layer_normalization_1 (Lay  (None, 36, 256)              512       ['add[0][0]']
#  erNormalization)
#
#  dropout (Dropout)           (None, 36, 256)              0         ['layer_normalization_1[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 36, 256)              0         ['dropout[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_2 (Lay  (None, 36, 256)              512       ['add_1[0][0]']
#  erNormalization)
#
#  flatten (Flatten)           (None, 9216)                 0         ['layer_normalization_2[0][0]'
#                                                                     ]
#
#  dropout_1 (Dropout)         (None, 9216)                 0         ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  2359552   ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 256)                  0         ['dense_1[0][0]']
#
#  dense_2 (Dense)             (None, 128)                  32896     ['dropout_2[0][0]']
#
#  dense_3 (Dense)             (None, 5)                    645       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 3566597 (13.61 MB)
# Trainable params: 3566597 (13.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Define early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # You can choose any metric to monitor
    patience=30,          # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    restore_best_weights=True  # Do restore best weights
)

# Compile the model
vit.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_categorical_accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.CosineSimilarity(name='cosine_similarity')
    ]
)

# Initialize variables to keep track of the best validation loss and corresponding model weights
best_val_loss = float('inf')
best_weights = None

# Lists to store training and validation metrics
vit_train_losses = []
vit_val_losses = []
vit_train_accuracies = []
vit_val_accuracies = []
vit_train_precisions = []
vit_val_precisions = []
vit_train_recalls = []
vit_val_recalls = []
vit_train_cosine_similarity = []
vit_val_cosine_similarity = []

for epoch in range(100):
    # Train the model for one epoch
    #history = vit.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping],class_weight = class_weights)
    history = vit.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping])
    # Append training and validation metrics for plotting
    vit_train_losses.append(history.history['loss'][0])
    vit_val_losses.append(history.history['val_loss'][0])
    vit_train_accuracies.append(history.history['categorical_accuracy'][0])
    vit_val_accuracies.append(history.history['val_categorical_accuracy'][0])
    vit_train_precisions.append(history.history['precision'][0])
    vit_val_precisions.append(history.history['val_precision'][0])
    vit_train_recalls.append(history.history['recall'][0])
    vit_val_recalls.append(history.history['val_recall'][0])
    vit_train_cosine_similarity.append(history.history['cosine_similarity'][0])
    vit_val_cosine_similarity.append(history.history['val_cosine_similarity'][0])

    # Check if the current validation loss is better than the best seen so far
    if history.history['val_loss'][0] < best_val_loss:
        best_val_loss = history.history['val_loss'][0]
        best_weights = vit.get_weights()
        # You can also save the weights to a file here if desired

# After training, you can set the model weights to the best weights
vit.set_weights(best_weights)

# Now you have the training and validation metrics (loss, accuracy, precision, recall, and cosine similarity) stored in the respective lists.
# Out:
# 100/100 [==============================] - 17s 80ms/step - loss: 1.5150 - categorical_accuracy: 0.3636 - top_5_categorical_accuracy: 1.0000 - precision: 0.5408 - recall: 0.1616 - cosine_similarity: 0.5042 - val_loss: 1.1784 - val_categorical_accuracy: 0.5123 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9324 - val_recall: 0.1859 - val_cosine_similarity: 0.6067
# 100/100 [==============================] - 5s 46ms/step - loss: 1.2248 - categorical_accuracy: 0.4630 - top_5_categorical_accuracy: 1.0000 - precision: 0.7205 - recall: 0.2461 - cosine_similarity: 0.5881 - val_loss: 1.1222 - val_categorical_accuracy: 0.5215 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9564 - val_recall: 0.1929 - val_cosine_similarity: 0.6220
# 100/100 [==============================] - 5s 45ms/step - loss: 1.1637 - categorical_accuracy: 0.4855 - top_5_categorical_accuracy: 1.0000 - precision: 0.7537 - recall: 0.2683 - cosine_similarity: 0.6102 - val_loss: 1.0824 - val_categorical_accuracy: 0.5588 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9304 - val_recall: 0.2140 - val_cosine_similarity: 0.6411
# 100/100 [==============================] - 5s 49ms/step - loss: 1.1215 - categorical_accuracy: 0.5002 - top_5_categorical_accuracy: 1.0000 - precision: 0.7406 - recall: 0.3030 - cosine_similarity: 0.6213 - val_loss: 1.0318 - val_categorical_accuracy: 0.5725 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8881 - val_recall: 0.2667 - val_cosine_similarity: 0.6589
# 100/100 [==============================] - 5s 45ms/step - loss: 1.0816 - categorical_accuracy: 0.5252 - top_5_categorical_accuracy: 1.0000 - precision: 0.7452 - recall: 0.3203 - cosine_similarity: 0.6370 - val_loss: 1.0124 - val_categorical_accuracy: 0.5883 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9126 - val_recall: 0.2700 - val_cosine_similarity: 0.6677
# 100/100 [==============================] - 5s 45ms/step - loss: 1.0513 - categorical_accuracy: 0.5497 - top_5_categorical_accuracy: 1.0000 - precision: 0.7434 - recall: 0.3531 - cosine_similarity: 0.6501 - val_loss: 0.9652 - val_categorical_accuracy: 0.6039 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9178 - val_recall: 0.2992 - val_cosine_similarity: 0.6838
# 100/100 [==============================] - 5s 49ms/step - loss: 1.0279 - categorical_accuracy: 0.5569 - top_5_categorical_accuracy: 1.0000 - precision: 0.7505 - recall: 0.3661 - cosine_similarity: 0.6566 - val_loss: 0.9309 - val_categorical_accuracy: 0.6180 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8948 - val_recall: 0.3504 - val_cosine_similarity: 0.6952
# 100/100 [==============================] - 5s 44ms/step - loss: 0.9971 - categorical_accuracy: 0.5669 - top_5_categorical_accuracy: 1.0000 - precision: 0.7410 - recall: 0.3809 - cosine_similarity: 0.6655 - val_loss: 0.9008 - val_categorical_accuracy: 0.6252 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8662 - val_recall: 0.4083 - val_cosine_similarity: 0.7050
# 100/100 [==============================] - 5s 45ms/step - loss: 0.9744 - categorical_accuracy: 0.5814 - top_5_categorical_accuracy: 1.0000 - precision: 0.7588 - recall: 0.4050 - cosine_similarity: 0.6741 - val_loss: 0.8836 - val_categorical_accuracy: 0.6367 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8789 - val_recall: 0.4133 - val_cosine_similarity: 0.7119
# 100/100 [==============================] - 5s 47ms/step - loss: 0.9430 - categorical_accuracy: 0.6017 - top_5_categorical_accuracy: 1.0000 - precision: 0.7655 - recall: 0.4255 - cosine_similarity: 0.6866 - val_loss: 0.8704 - val_categorical_accuracy: 0.6452 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8687 - val_recall: 0.4357 - val_cosine_similarity: 0.7188
# 100/100 [==============================] - 5s 44ms/step - loss: 0.9215 - categorical_accuracy: 0.6077 - top_5_categorical_accuracy: 1.0000 - precision: 0.7717 - recall: 0.4420 - cosine_similarity: 0.6956 - val_loss: 0.8711 - val_categorical_accuracy: 0.6492 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8836 - val_recall: 0.4119 - val_cosine_similarity: 0.7203
# 100/100 [==============================] - 5s 46ms/step - loss: 0.9040 - categorical_accuracy: 0.6092 - top_5_categorical_accuracy: 1.0000 - precision: 0.7690 - recall: 0.4484 - cosine_similarity: 0.6967 - val_loss: 0.8366 - val_categorical_accuracy: 0.6608 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8880 - val_recall: 0.4396 - val_cosine_similarity: 0.7305
# 100/100 [==============================] - 5s 44ms/step - loss: 0.8966 - categorical_accuracy: 0.6234 - top_5_categorical_accuracy: 1.0000 - precision: 0.7729 - recall: 0.4622 - cosine_similarity: 0.7011 - val_loss: 0.8186 - val_categorical_accuracy: 0.6744 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8771 - val_recall: 0.4807 - val_cosine_similarity: 0.7377
# 100/100 [==============================] - 5s 44ms/step - loss: 0.8731 - categorical_accuracy: 0.6319 - top_5_categorical_accuracy: 1.0000 - precision: 0.7812 - recall: 0.4820 - cosine_similarity: 0.7113 - val_loss: 0.7971 - val_categorical_accuracy: 0.6736 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8652 - val_recall: 0.4809 - val_cosine_similarity: 0.7427
# 100/100 [==============================] - 5s 48ms/step - loss: 0.8561 - categorical_accuracy: 0.6355 - top_5_categorical_accuracy: 1.0000 - precision: 0.7790 - recall: 0.4980 - cosine_similarity: 0.7160 - val_loss: 0.7908 - val_categorical_accuracy: 0.6787 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8498 - val_recall: 0.4977 - val_cosine_similarity: 0.7435
# 100/100 [==============================] - 5s 44ms/step - loss: 0.8377 - categorical_accuracy: 0.6470 - top_5_categorical_accuracy: 1.0000 - precision: 0.7880 - recall: 0.5075 - cosine_similarity: 0.7233 - val_loss: 0.7544 - val_categorical_accuracy: 0.7053 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9001 - val_recall: 0.4972 - val_cosine_similarity: 0.7610
# 100/100 [==============================] - 5s 44ms/step - loss: 0.8215 - categorical_accuracy: 0.6630 - top_5_categorical_accuracy: 1.0000 - precision: 0.7958 - recall: 0.5188 - cosine_similarity: 0.7298 - val_loss: 0.7405 - val_categorical_accuracy: 0.7059 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8886 - val_recall: 0.5177 - val_cosine_similarity: 0.7639
# 100/100 [==============================] - 5s 48ms/step - loss: 0.7940 - categorical_accuracy: 0.6645 - top_5_categorical_accuracy: 1.0000 - precision: 0.7936 - recall: 0.5364 - cosine_similarity: 0.7377 - val_loss: 0.7188 - val_categorical_accuracy: 0.7215 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8898 - val_recall: 0.5232 - val_cosine_similarity: 0.7708
# 100/100 [==============================] - 5s 44ms/step - loss: 0.7867 - categorical_accuracy: 0.6697 - top_5_categorical_accuracy: 1.0000 - precision: 0.7992 - recall: 0.5466 - cosine_similarity: 0.7408 - val_loss: 0.7215 - val_categorical_accuracy: 0.7221 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8939 - val_recall: 0.5268 - val_cosine_similarity: 0.7716
# 100/100 [==============================] - 5s 44ms/step - loss: 0.7675 - categorical_accuracy: 0.6794 - top_5_categorical_accuracy: 1.0000 - precision: 0.8032 - recall: 0.5587 - cosine_similarity: 0.7481 - val_loss: 0.6653 - val_categorical_accuracy: 0.7515 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8983 - val_recall: 0.5737 - val_cosine_similarity: 0.7909
# 100/100 [==============================] - 5s 47ms/step - loss: 0.7591 - categorical_accuracy: 0.6784 - top_5_categorical_accuracy: 1.0000 - precision: 0.7950 - recall: 0.5653 - cosine_similarity: 0.7483 - val_loss: 0.6846 - val_categorical_accuracy: 0.7365 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8991 - val_recall: 0.5619 - val_cosine_similarity: 0.7843
# 100/100 [==============================] - 5s 46ms/step - loss: 0.7332 - categorical_accuracy: 0.6936 - top_5_categorical_accuracy: 1.0000 - precision: 0.8075 - recall: 0.5808 - cosine_similarity: 0.7586 - val_loss: 0.6812 - val_categorical_accuracy: 0.7349 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9027 - val_recall: 0.5703 - val_cosine_similarity: 0.7851
# 100/100 [==============================] - 5s 46ms/step - loss: 0.7152 - categorical_accuracy: 0.7066 - top_5_categorical_accuracy: 1.0000 - precision: 0.8121 - recall: 0.5975 - cosine_similarity: 0.7662 - val_loss: 0.6344 - val_categorical_accuracy: 0.7707 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9192 - val_recall: 0.5977 - val_cosine_similarity: 0.8043
# 100/100 [==============================] - 5s 44ms/step - loss: 0.6910 - categorical_accuracy: 0.7173 - top_5_categorical_accuracy: 1.0000 - precision: 0.8190 - recall: 0.6152 - cosine_similarity: 0.7753 - val_loss: 0.6056 - val_categorical_accuracy: 0.7712 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8927 - val_recall: 0.6337 - val_cosine_similarity: 0.8100
# 100/100 [==============================] - 5s 44ms/step - loss: 0.6930 - categorical_accuracy: 0.7152 - top_5_categorical_accuracy: 1.0000 - precision: 0.8150 - recall: 0.6159 - cosine_similarity: 0.7743 - val_loss: 0.6439 - val_categorical_accuracy: 0.7515 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8848 - val_recall: 0.6092 - val_cosine_similarity: 0.7985
# 100/100 [==============================] - 5s 48ms/step - loss: 0.6629 - categorical_accuracy: 0.7333 - top_5_categorical_accuracy: 1.0000 - precision: 0.8278 - recall: 0.6355 - cosine_similarity: 0.7860 - val_loss: 0.5889 - val_categorical_accuracy: 0.7764 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8864 - val_recall: 0.6556 - val_cosine_similarity: 0.8164
# 100/100 [==============================] - 5s 44ms/step - loss: 0.6601 - categorical_accuracy: 0.7231 - top_5_categorical_accuracy: 1.0000 - precision: 0.8213 - recall: 0.6355 - cosine_similarity: 0.7837 - val_loss: 0.5806 - val_categorical_accuracy: 0.7791 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8962 - val_recall: 0.6633 - val_cosine_similarity: 0.8191
# 100/100 [==============================] - 5s 44ms/step - loss: 0.6519 - categorical_accuracy: 0.7389 - top_5_categorical_accuracy: 1.0000 - precision: 0.8210 - recall: 0.6492 - cosine_similarity: 0.7888 - val_loss: 0.5578 - val_categorical_accuracy: 0.7889 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8991 - val_recall: 0.6783 - val_cosine_similarity: 0.8259
# 100/100 [==============================] - 5s 48ms/step - loss: 0.6308 - categorical_accuracy: 0.7458 - top_5_categorical_accuracy: 1.0000 - precision: 0.8347 - recall: 0.6578 - cosine_similarity: 0.7965 - val_loss: 0.5474 - val_categorical_accuracy: 0.8008 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9158 - val_recall: 0.6699 - val_cosine_similarity: 0.8323
# 100/100 [==============================] - 5s 46ms/step - loss: 0.6206 - categorical_accuracy: 0.7477 - top_5_categorical_accuracy: 1.0000 - precision: 0.8344 - recall: 0.6678 - cosine_similarity: 0.7986 - val_loss: 0.5573 - val_categorical_accuracy: 0.8028 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9272 - val_recall: 0.6609 - val_cosine_similarity: 0.8302
# 100/100 [==============================] - 5s 44ms/step - loss: 0.5992 - categorical_accuracy: 0.7552 - top_5_categorical_accuracy: 1.0000 - precision: 0.8447 - recall: 0.6741 - cosine_similarity: 0.8055 - val_loss: 0.5115 - val_categorical_accuracy: 0.8059 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9001 - val_recall: 0.7115 - val_cosine_similarity: 0.8422
# 100/100 [==============================] - 5s 46ms/step - loss: 0.5901 - categorical_accuracy: 0.7600 - top_5_categorical_accuracy: 1.0000 - precision: 0.8444 - recall: 0.6844 - cosine_similarity: 0.8089 - val_loss: 0.5257 - val_categorical_accuracy: 0.8108 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9229 - val_recall: 0.6875 - val_cosine_similarity: 0.8405
# 100/100 [==============================] - 5s 45ms/step - loss: 0.5722 - categorical_accuracy: 0.7644 - top_5_categorical_accuracy: 1.0000 - precision: 0.8390 - recall: 0.6839 - cosine_similarity: 0.8129 - val_loss: 0.5153 - val_categorical_accuracy: 0.8167 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9194 - val_recall: 0.7092 - val_cosine_similarity: 0.8449
# 100/100 [==============================] - 5s 47ms/step - loss: 0.5576 - categorical_accuracy: 0.7756 - top_5_categorical_accuracy: 1.0000 - precision: 0.8485 - recall: 0.7019 - cosine_similarity: 0.8207 - val_loss: 0.4929 - val_categorical_accuracy: 0.8292 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9275 - val_recall: 0.7160 - val_cosine_similarity: 0.8522
# 100/100 [==============================] - 5s 45ms/step - loss: 0.5319 - categorical_accuracy: 0.7917 - top_5_categorical_accuracy: 1.0000 - precision: 0.8545 - recall: 0.7233 - cosine_similarity: 0.8302 - val_loss: 0.5181 - val_categorical_accuracy: 0.8123 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9047 - val_recall: 0.7072 - val_cosine_similarity: 0.8425
# 100/100 [==============================] - 5s 45ms/step - loss: 0.5489 - categorical_accuracy: 0.7767 - top_5_categorical_accuracy: 1.0000 - precision: 0.8541 - recall: 0.7072 - cosine_similarity: 0.8237 - val_loss: 0.4914 - val_categorical_accuracy: 0.8120 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8839 - val_recall: 0.7463 - val_cosine_similarity: 0.8484
# 100/100 [==============================] - 5s 48ms/step - loss: 0.5231 - categorical_accuracy: 0.7877 - top_5_categorical_accuracy: 1.0000 - precision: 0.8558 - recall: 0.7250 - cosine_similarity: 0.8314 - val_loss: 0.4562 - val_categorical_accuracy: 0.8341 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9097 - val_recall: 0.7495 - val_cosine_similarity: 0.8620
# 100/100 [==============================] - 5s 44ms/step - loss: 0.5219 - categorical_accuracy: 0.7948 - top_5_categorical_accuracy: 1.0000 - precision: 0.8586 - recall: 0.7317 - cosine_similarity: 0.8342 - val_loss: 0.4678 - val_categorical_accuracy: 0.8325 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9116 - val_recall: 0.7525 - val_cosine_similarity: 0.8600
# 100/100 [==============================] - 5s 44ms/step - loss: 0.4998 - categorical_accuracy: 0.8047 - top_5_categorical_accuracy: 1.0000 - precision: 0.8643 - recall: 0.7416 - cosine_similarity: 0.8405 - val_loss: 0.4374 - val_categorical_accuracy: 0.8483 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9287 - val_recall: 0.7612 - val_cosine_similarity: 0.8705
# 100/100 [==============================] - 5s 49ms/step - loss: 0.4824 - categorical_accuracy: 0.8105 - top_5_categorical_accuracy: 1.0000 - precision: 0.8719 - recall: 0.7553 - cosine_similarity: 0.8476 - val_loss: 0.4336 - val_categorical_accuracy: 0.8543 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9292 - val_recall: 0.7652 - val_cosine_similarity: 0.8722
# 100/100 [==============================] - 5s 45ms/step - loss: 0.4784 - categorical_accuracy: 0.8094 - top_5_categorical_accuracy: 1.0000 - precision: 0.8636 - recall: 0.7538 - cosine_similarity: 0.8470 - val_loss: 0.4236 - val_categorical_accuracy: 0.8647 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9299 - val_recall: 0.7840 - val_cosine_similarity: 0.8771
# 100/100 [==============================] - 5s 45ms/step - loss: 0.4721 - categorical_accuracy: 0.8166 - top_5_categorical_accuracy: 1.0000 - precision: 0.8681 - recall: 0.7602 - cosine_similarity: 0.8498 - val_loss: 0.4396 - val_categorical_accuracy: 0.8491 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9131 - val_recall: 0.7745 - val_cosine_similarity: 0.8714
# 100/100 [==============================] - 5s 47ms/step - loss: 0.4550 - categorical_accuracy: 0.8219 - top_5_categorical_accuracy: 1.0000 - precision: 0.8763 - recall: 0.7706 - cosine_similarity: 0.8549 - val_loss: 0.4004 - val_categorical_accuracy: 0.8635 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9260 - val_recall: 0.7928 - val_cosine_similarity: 0.8823
# 100/100 [==============================] - 5s 45ms/step - loss: 0.4405 - categorical_accuracy: 0.8297 - top_5_categorical_accuracy: 1.0000 - precision: 0.8804 - recall: 0.7830 - cosine_similarity: 0.8606 - val_loss: 0.4091 - val_categorical_accuracy: 0.8563 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9215 - val_recall: 0.7915 - val_cosine_similarity: 0.8783
# 100/100 [==============================] - 5s 47ms/step - loss: 0.4558 - categorical_accuracy: 0.8205 - top_5_categorical_accuracy: 1.0000 - precision: 0.8689 - recall: 0.7684 - cosine_similarity: 0.8548 - val_loss: 0.4022 - val_categorical_accuracy: 0.8623 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9314 - val_recall: 0.7841 - val_cosine_similarity: 0.8819
# 100/100 [==============================] - 5s 45ms/step - loss: 0.4295 - categorical_accuracy: 0.8298 - top_5_categorical_accuracy: 1.0000 - precision: 0.8755 - recall: 0.7825 - cosine_similarity: 0.8637 - val_loss: 0.3904 - val_categorical_accuracy: 0.8620 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9139 - val_recall: 0.8120 - val_cosine_similarity: 0.8835
# 100/100 [==============================] - 5s 45ms/step - loss: 0.4294 - categorical_accuracy: 0.8320 - top_5_categorical_accuracy: 1.0000 - precision: 0.8788 - recall: 0.7825 - cosine_similarity: 0.8632 - val_loss: 0.3780 - val_categorical_accuracy: 0.8721 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9222 - val_recall: 0.8120 - val_cosine_similarity: 0.8888
# 100/100 [==============================] - 5s 49ms/step - loss: 0.4128 - categorical_accuracy: 0.8372 - top_5_categorical_accuracy: 1.0000 - precision: 0.8802 - recall: 0.7897 - cosine_similarity: 0.8686 - val_loss: 0.3726 - val_categorical_accuracy: 0.8803 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9304 - val_recall: 0.8269 - val_cosine_similarity: 0.8940
# 100/100 [==============================] - 5s 44ms/step - loss: 0.3959 - categorical_accuracy: 0.8462 - top_5_categorical_accuracy: 1.0000 - precision: 0.8886 - recall: 0.8073 - cosine_similarity: 0.8752 - val_loss: 0.4007 - val_categorical_accuracy: 0.8653 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9236 - val_recall: 0.7996 - val_cosine_similarity: 0.8829
# 100/100 [==============================] - 5s 45ms/step - loss: 0.3898 - categorical_accuracy: 0.8553 - top_5_categorical_accuracy: 1.0000 - precision: 0.8913 - recall: 0.8109 - cosine_similarity: 0.8774 - val_loss: 0.3691 - val_categorical_accuracy: 0.8844 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9477 - val_recall: 0.8115 - val_cosine_similarity: 0.8968
# 100/100 [==============================] - 5s 51ms/step - loss: 0.3773 - categorical_accuracy: 0.8567 - top_5_categorical_accuracy: 1.0000 - precision: 0.8947 - recall: 0.8175 - cosine_similarity: 0.8808 - val_loss: 0.3449 - val_categorical_accuracy: 0.8865 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9303 - val_recall: 0.8401 - val_cosine_similarity: 0.9006
# 100/100 [==============================] - 5s 45ms/step - loss: 0.3879 - categorical_accuracy: 0.8498 - top_5_categorical_accuracy: 1.0000 - precision: 0.8901 - recall: 0.8128 - cosine_similarity: 0.8775 - val_loss: 0.3538 - val_categorical_accuracy: 0.8817 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9253 - val_recall: 0.8324 - val_cosine_similarity: 0.8972
# 100/100 [==============================] - 5s 48ms/step - loss: 0.3764 - categorical_accuracy: 0.8534 - top_5_categorical_accuracy: 1.0000 - precision: 0.8960 - recall: 0.8188 - cosine_similarity: 0.8820 - val_loss: 0.3485 - val_categorical_accuracy: 0.8836 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9276 - val_recall: 0.8365 - val_cosine_similarity: 0.8995
# 100/100 [==============================] - 5s 45ms/step - loss: 0.3452 - categorical_accuracy: 0.8697 - top_5_categorical_accuracy: 1.0000 - precision: 0.9074 - recall: 0.8330 - cosine_similarity: 0.8925 - val_loss: 0.3514 - val_categorical_accuracy: 0.8815 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9216 - val_recall: 0.8420 - val_cosine_similarity: 0.8983
# 100/100 [==============================] - 5s 45ms/step - loss: 0.3379 - categorical_accuracy: 0.8681 - top_5_categorical_accuracy: 1.0000 - precision: 0.9021 - recall: 0.8364 - cosine_similarity: 0.8927 - val_loss: 0.3347 - val_categorical_accuracy: 0.8832 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9161 - val_recall: 0.8543 - val_cosine_similarity: 0.9023
# 100/100 [==============================] - 5s 49ms/step - loss: 0.3389 - categorical_accuracy: 0.8708 - top_5_categorical_accuracy: 1.0000 - precision: 0.9024 - recall: 0.8350 - cosine_similarity: 0.8939 - val_loss: 0.3414 - val_categorical_accuracy: 0.8888 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9376 - val_recall: 0.8377 - val_cosine_similarity: 0.9034
# 100/100 [==============================] - 5s 45ms/step - loss: 0.3419 - categorical_accuracy: 0.8681 - top_5_categorical_accuracy: 1.0000 - precision: 0.9008 - recall: 0.8372 - cosine_similarity: 0.8936 - val_loss: 0.3165 - val_categorical_accuracy: 0.9000 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9420 - val_recall: 0.8569 - val_cosine_similarity: 0.9116
# 100/100 [==============================] - 5s 46ms/step - loss: 0.3360 - categorical_accuracy: 0.8784 - top_5_categorical_accuracy: 1.0000 - precision: 0.9116 - recall: 0.8489 - cosine_similarity: 0.8982 - val_loss: 0.3206 - val_categorical_accuracy: 0.8945 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9396 - val_recall: 0.8581 - val_cosine_similarity: 0.9091
# 100/100 [==============================] - 5s 49ms/step - loss: 0.3402 - categorical_accuracy: 0.8673 - top_5_categorical_accuracy: 1.0000 - precision: 0.9012 - recall: 0.8427 - cosine_similarity: 0.8932 - val_loss: 0.3094 - val_categorical_accuracy: 0.9031 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9444 - val_recall: 0.8623 - val_cosine_similarity: 0.9143
# 100/100 [==============================] - 5s 45ms/step - loss: 0.2974 - categorical_accuracy: 0.8867 - top_5_categorical_accuracy: 1.0000 - precision: 0.9152 - recall: 0.8612 - cosine_similarity: 0.9075 - val_loss: 0.3035 - val_categorical_accuracy: 0.9016 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9362 - val_recall: 0.8767 - val_cosine_similarity: 0.9154
# 100/100 [==============================] - 5s 47ms/step - loss: 0.3076 - categorical_accuracy: 0.8839 - top_5_categorical_accuracy: 1.0000 - precision: 0.9099 - recall: 0.8572 - cosine_similarity: 0.9040 - val_loss: 0.2987 - val_categorical_accuracy: 0.9045 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9398 - val_recall: 0.8716 - val_cosine_similarity: 0.9165
# 100/100 [==============================] - 5s 45ms/step - loss: 0.3085 - categorical_accuracy: 0.8781 - top_5_categorical_accuracy: 1.0000 - precision: 0.9094 - recall: 0.8469 - cosine_similarity: 0.9015 - val_loss: 0.3294 - val_categorical_accuracy: 0.8876 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9130 - val_recall: 0.8673 - val_cosine_similarity: 0.9051
# 100/100 [==============================] - 5s 44ms/step - loss: 0.2965 - categorical_accuracy: 0.8861 - top_5_categorical_accuracy: 1.0000 - precision: 0.9148 - recall: 0.8625 - cosine_similarity: 0.9074 - val_loss: 0.3213 - val_categorical_accuracy: 0.8911 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9186 - val_recall: 0.8651 - val_cosine_similarity: 0.9069
# 100/100 [==============================] - 5s 49ms/step - loss: 0.2906 - categorical_accuracy: 0.8869 - top_5_categorical_accuracy: 1.0000 - precision: 0.9139 - recall: 0.8644 - cosine_similarity: 0.9083 - val_loss: 0.2950 - val_categorical_accuracy: 0.9052 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9369 - val_recall: 0.8756 - val_cosine_similarity: 0.9175
# 100/100 [==============================] - 5s 44ms/step - loss: 0.2731 - categorical_accuracy: 0.8966 - top_5_categorical_accuracy: 1.0000 - precision: 0.9206 - recall: 0.8745 - cosine_similarity: 0.9151 - val_loss: 0.2786 - val_categorical_accuracy: 0.9089 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9351 - val_recall: 0.8872 - val_cosine_similarity: 0.9219
# 100/100 [==============================] - 5s 44ms/step - loss: 0.2816 - categorical_accuracy: 0.8970 - top_5_categorical_accuracy: 1.0000 - precision: 0.9222 - recall: 0.8700 - cosine_similarity: 0.9130 - val_loss: 0.2907 - val_categorical_accuracy: 0.9111 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9466 - val_recall: 0.8744 - val_cosine_similarity: 0.9207
# 100/100 [==============================] - 5s 48ms/step - loss: 0.2806 - categorical_accuracy: 0.8928 - top_5_categorical_accuracy: 1.0000 - precision: 0.9165 - recall: 0.8694 - cosine_similarity: 0.9126 - val_loss: 0.2732 - val_categorical_accuracy: 0.9127 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9441 - val_recall: 0.8843 - val_cosine_similarity: 0.9245
# 100/100 [==============================] - 5s 44ms/step - loss: 0.2770 - categorical_accuracy: 0.8933 - top_5_categorical_accuracy: 1.0000 - precision: 0.9207 - recall: 0.8695 - cosine_similarity: 0.9132 - val_loss: 0.2667 - val_categorical_accuracy: 0.9132 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9440 - val_recall: 0.8915 - val_cosine_similarity: 0.9258
# 100/100 [==============================] - 5s 47ms/step - loss: 0.2634 - categorical_accuracy: 0.8995 - top_5_categorical_accuracy: 1.0000 - precision: 0.9207 - recall: 0.8784 - cosine_similarity: 0.9175 - val_loss: 0.2751 - val_categorical_accuracy: 0.9141 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9486 - val_recall: 0.8811 - val_cosine_similarity: 0.9243
# 100/100 [==============================] - 5s 46ms/step - loss: 0.2682 - categorical_accuracy: 0.8972 - top_5_categorical_accuracy: 1.0000 - precision: 0.9224 - recall: 0.8748 - cosine_similarity: 0.9157 - val_loss: 0.2692 - val_categorical_accuracy: 0.9176 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9459 - val_recall: 0.8923 - val_cosine_similarity: 0.9259
# 100/100 [==============================] - 5s 45ms/step - loss: 0.2492 - categorical_accuracy: 0.8992 - top_5_categorical_accuracy: 1.0000 - precision: 0.9236 - recall: 0.8806 - cosine_similarity: 0.9210 - val_loss: 0.2638 - val_categorical_accuracy: 0.9165 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9450 - val_recall: 0.8917 - val_cosine_similarity: 0.9280
# 100/100 [==============================] - 5s 47ms/step - loss: 0.2571 - categorical_accuracy: 0.9059 - top_5_categorical_accuracy: 1.0000 - precision: 0.9272 - recall: 0.8841 - cosine_similarity: 0.9206 - val_loss: 0.2758 - val_categorical_accuracy: 0.9139 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9393 - val_recall: 0.8929 - val_cosine_similarity: 0.9258
# 100/100 [==============================] - 5s 45ms/step - loss: 0.2581 - categorical_accuracy: 0.9013 - top_5_categorical_accuracy: 1.0000 - precision: 0.9257 - recall: 0.8813 - cosine_similarity: 0.9198 - val_loss: 0.2498 - val_categorical_accuracy: 0.9220 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9451 - val_recall: 0.8981 - val_cosine_similarity: 0.9314
# 100/100 [==============================] - 5s 45ms/step - loss: 0.2431 - categorical_accuracy: 0.9100 - top_5_categorical_accuracy: 1.0000 - precision: 0.9293 - recall: 0.8898 - cosine_similarity: 0.9252 - val_loss: 0.2600 - val_categorical_accuracy: 0.9197 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9443 - val_recall: 0.8968 - val_cosine_similarity: 0.9296
# 100/100 [==============================] - 5s 49ms/step - loss: 0.2197 - categorical_accuracy: 0.9187 - top_5_categorical_accuracy: 1.0000 - precision: 0.9364 - recall: 0.9036 - cosine_similarity: 0.9328 - val_loss: 0.2559 - val_categorical_accuracy: 0.9219 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9424 - val_recall: 0.9011 - val_cosine_similarity: 0.9308
# 100/100 [==============================] - 5s 45ms/step - loss: 0.2454 - categorical_accuracy: 0.9061 - top_5_categorical_accuracy: 1.0000 - precision: 0.9256 - recall: 0.8883 - cosine_similarity: 0.9226 - val_loss: 0.2787 - val_categorical_accuracy: 0.9113 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9405 - val_recall: 0.8832 - val_cosine_similarity: 0.9228
# 100/100 [==============================] - 5s 46ms/step - loss: 0.2288 - categorical_accuracy: 0.9125 - top_5_categorical_accuracy: 1.0000 - precision: 0.9313 - recall: 0.8953 - cosine_similarity: 0.9291 - val_loss: 0.2511 - val_categorical_accuracy: 0.9185 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9389 - val_recall: 0.9023 - val_cosine_similarity: 0.9307
# 100/100 [==============================] - 5s 49ms/step - loss: 0.2216 - categorical_accuracy: 0.9162 - top_5_categorical_accuracy: 1.0000 - precision: 0.9346 - recall: 0.8995 - cosine_similarity: 0.9316 - val_loss: 0.2724 - val_categorical_accuracy: 0.9143 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9424 - val_recall: 0.8813 - val_cosine_similarity: 0.9241
# 100/100 [==============================] - 5s 46ms/step - loss: 0.2241 - categorical_accuracy: 0.9211 - top_5_categorical_accuracy: 1.0000 - precision: 0.9379 - recall: 0.9033 - cosine_similarity: 0.9317 - val_loss: 0.2444 - val_categorical_accuracy: 0.9219 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9440 - val_recall: 0.9036 - val_cosine_similarity: 0.9330
# 100/100 [==============================] - 5s 47ms/step - loss: 0.2073 - categorical_accuracy: 0.9202 - top_5_categorical_accuracy: 1.0000 - precision: 0.9376 - recall: 0.9059 - cosine_similarity: 0.9350 - val_loss: 0.2444 - val_categorical_accuracy: 0.9237 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9479 - val_recall: 0.9029 - val_cosine_similarity: 0.9342
# 100/100 [==============================] - 5s 44ms/step - loss: 0.2173 - categorical_accuracy: 0.9164 - top_5_categorical_accuracy: 1.0000 - precision: 0.9346 - recall: 0.9003 - cosine_similarity: 0.9322 - val_loss: 0.2524 - val_categorical_accuracy: 0.9172 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9346 - val_recall: 0.9032 - val_cosine_similarity: 0.9303
# 100/100 [==============================] - 5s 44ms/step - loss: 0.2148 - categorical_accuracy: 0.9191 - top_5_categorical_accuracy: 1.0000 - precision: 0.9339 - recall: 0.9027 - cosine_similarity: 0.9330 - val_loss: 0.2523 - val_categorical_accuracy: 0.9235 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9408 - val_recall: 0.9076 - val_cosine_similarity: 0.9335
# 100/100 [==============================] - 5s 49ms/step - loss: 0.2116 - categorical_accuracy: 0.9181 - top_5_categorical_accuracy: 1.0000 - precision: 0.9356 - recall: 0.9017 - cosine_similarity: 0.9341 - val_loss: 0.2519 - val_categorical_accuracy: 0.9221 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9441 - val_recall: 0.9031 - val_cosine_similarity: 0.9327
# 100/100 [==============================] - 5s 43ms/step - loss: 0.2017 - categorical_accuracy: 0.9294 - top_5_categorical_accuracy: 1.0000 - precision: 0.9422 - recall: 0.9125 - cosine_similarity: 0.9394 - val_loss: 0.2526 - val_categorical_accuracy: 0.9177 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9365 - val_recall: 0.9051 - val_cosine_similarity: 0.9303
# 100/100 [==============================] - 5s 44ms/step - loss: 0.1987 - categorical_accuracy: 0.9270 - top_5_categorical_accuracy: 1.0000 - precision: 0.9418 - recall: 0.9150 - cosine_similarity: 0.9393 - val_loss: 0.2580 - val_categorical_accuracy: 0.9176 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9379 - val_recall: 0.9035 - val_cosine_similarity: 0.9306
# 100/100 [==============================] - 5s 47ms/step - loss: 0.2036 - categorical_accuracy: 0.9220 - top_5_categorical_accuracy: 1.0000 - precision: 0.9389 - recall: 0.9095 - cosine_similarity: 0.9374 - val_loss: 0.2335 - val_categorical_accuracy: 0.9244 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9444 - val_recall: 0.9119 - val_cosine_similarity: 0.9365
# 100/100 [==============================] - 5s 46ms/step - loss: 0.1912 - categorical_accuracy: 0.9275 - top_5_categorical_accuracy: 1.0000 - precision: 0.9418 - recall: 0.9148 - cosine_similarity: 0.9408 - val_loss: 0.2423 - val_categorical_accuracy: 0.9267 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9447 - val_recall: 0.9111 - val_cosine_similarity: 0.9355
# 100/100 [==============================] - 5s 45ms/step - loss: 0.1861 - categorical_accuracy: 0.9295 - top_5_categorical_accuracy: 1.0000 - precision: 0.9426 - recall: 0.9156 - cosine_similarity: 0.9426 - val_loss: 0.2305 - val_categorical_accuracy: 0.9256 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9450 - val_recall: 0.9075 - val_cosine_similarity: 0.9371
# 100/100 [==============================] - 5s 46ms/step - loss: 0.1834 - categorical_accuracy: 0.9344 - top_5_categorical_accuracy: 1.0000 - precision: 0.9492 - recall: 0.9198 - cosine_similarity: 0.9443 - val_loss: 0.2339 - val_categorical_accuracy: 0.9225 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9416 - val_recall: 0.9091 - val_cosine_similarity: 0.9349
# 100/100 [==============================] - 5s 45ms/step - loss: 0.1913 - categorical_accuracy: 0.9352 - top_5_categorical_accuracy: 1.0000 - precision: 0.9484 - recall: 0.9223 - cosine_similarity: 0.9434 - val_loss: 0.2279 - val_categorical_accuracy: 0.9299 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9490 - val_recall: 0.9157 - val_cosine_similarity: 0.9397
# 100/100 [==============================] - 5s 48ms/step - loss: 0.1779 - categorical_accuracy: 0.9378 - top_5_categorical_accuracy: 1.0000 - precision: 0.9522 - recall: 0.9237 - cosine_similarity: 0.9466 - val_loss: 0.2283 - val_categorical_accuracy: 0.9280 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9451 - val_recall: 0.9173 - val_cosine_similarity: 0.9392
# 100/100 [==============================] - 5s 45ms/step - loss: 0.1854 - categorical_accuracy: 0.9334 - top_5_categorical_accuracy: 1.0000 - precision: 0.9465 - recall: 0.9225 - cosine_similarity: 0.9439 - val_loss: 0.2421 - val_categorical_accuracy: 0.9228 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9388 - val_recall: 0.9096 - val_cosine_similarity: 0.9346
# 100/100 [==============================] - 5s 45ms/step - loss: 0.1706 - categorical_accuracy: 0.9388 - top_5_categorical_accuracy: 1.0000 - precision: 0.9524 - recall: 0.9250 - cosine_similarity: 0.9486 - val_loss: 0.2568 - val_categorical_accuracy: 0.9176 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9313 - val_recall: 0.9085 - val_cosine_similarity: 0.9307
# 100/100 [==============================] - 5s 48ms/step - loss: 0.1672 - categorical_accuracy: 0.9347 - top_5_categorical_accuracy: 1.0000 - precision: 0.9471 - recall: 0.9261 - cosine_similarity: 0.9478 - val_loss: 0.2276 - val_categorical_accuracy: 0.9280 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9452 - val_recall: 0.9156 - val_cosine_similarity: 0.9389
# 100/100 [==============================] - 5s 45ms/step - loss: 0.1635 - categorical_accuracy: 0.9394 - top_5_categorical_accuracy: 1.0000 - precision: 0.9499 - recall: 0.9309 - cosine_similarity: 0.9506 - val_loss: 0.2443 - val_categorical_accuracy: 0.9256 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9390 - val_recall: 0.9156 - val_cosine_similarity: 0.9363
# 100/100 [==============================] - 5s 45ms/step - loss: 0.1695 - categorical_accuracy: 0.9372 - top_5_categorical_accuracy: 1.0000 - precision: 0.9480 - recall: 0.9278 - cosine_similarity: 0.9482 - val_loss: 0.2266 - val_categorical_accuracy: 0.9275 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9457 - val_recall: 0.9180 - val_cosine_similarity: 0.9391
# 100/100 [==============================] - 5s 48ms/step - loss: 0.1627 - categorical_accuracy: 0.9405 - top_5_categorical_accuracy: 1.0000 - precision: 0.9521 - recall: 0.9284 - cosine_similarity: 0.9508 - val_loss: 0.2131 - val_categorical_accuracy: 0.9321 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9456 - val_recall: 0.9247 - val_cosine_similarity: 0.9432
# 100/100 [==============================] - 5s 45ms/step - loss: 0.1554 - categorical_accuracy: 0.9428 - top_5_categorical_accuracy: 1.0000 - precision: 0.9539 - recall: 0.9342 - cosine_similarity: 0.9529 - val_loss: 0.2345 - val_categorical_accuracy: 0.9264 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9397 - val_recall: 0.9176 - val_cosine_similarity: 0.9382
# 100/100 [==============================] - 5s 48ms/step - loss: 0.1662 - categorical_accuracy: 0.9378 - top_5_categorical_accuracy: 1.0000 - precision: 0.9524 - recall: 0.9292 - cosine_similarity: 0.9488 - val_loss: 0.2350 - val_categorical_accuracy: 0.9277 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9434 - val_recall: 0.9180 - val_cosine_similarity: 0.9392
# 100/100 [==============================] - 5s 46ms/step - loss: 0.1709 - categorical_accuracy: 0.9358 - top_5_categorical_accuracy: 1.0000 - precision: 0.9468 - recall: 0.9262 - cosine_similarity: 0.9466 - val_loss: 0.2260 - val_categorical_accuracy: 0.9317 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9483 - val_recall: 0.9187 - val_cosine_similarity: 0.9410

# %%
import matplotlib.pyplot as plt

# Create a single figure for all subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

# Plot training and validation loss
axes[0, 0].plot(vit_train_losses, label='Training Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(vit_val_losses, label='Validation Loss', linestyle='--', linewidth=2)
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].set_title('Training and Validation Loss (VIT)')

# Plot training and validation accuracy
axes[0, 1].plot(vit_train_accuracies, label='Training Accuracy', linestyle='-', linewidth=2)
axes[0, 1].plot(vit_val_accuracies, label='Validation Accuracy', linestyle='--', linewidth=2)
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].set_title('Training and Validation Accuracy (VIT)')

# Plot precision, recall, and cosine similarity
axes[0, 2].plot(vit_train_precisions, label='Training Precision', linestyle='-', linewidth=2)
axes[0, 2].plot(vit_val_precisions, label='Validation Precision', linestyle='--', linewidth=2)
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend()
axes[0, 2].set_title('Training and Validation Precision (VIT)')

axes[1, 0].plot(vit_train_recalls, label='Training Recall', linestyle='-', linewidth=2)
axes[1, 0].plot(vit_val_recalls, label='Validation Recall', linestyle='--', linewidth=2)
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend()
axes[1, 0].set_title('Training and Validation Recall (VIT)')

axes[1, 1].plot(vit_train_cosine_similarity, label='Training Cosine Similarity', linestyle='-', linewidth=2)
axes[1, 1].plot(vit_val_cosine_similarity, label='Validation Cosine Similarity', linestyle='--', linewidth=2)
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Cosine Similarity')
axes[1, 1].legend()
axes[1, 1].set_title('Training and Validation Cosine Similarity (VIT)')

# Ensure that the layout is tight
plt.tight_layout()

plt.show()

# %%
# Evaluate the model
evaluation_results = vit.evaluate(test_ds, batch_size=32)
print("Evaluation results:", evaluation_results)
# Save the trained model to a file
vit.save(f"{path}/vit.h5")
print("Model saved to", f"{path}/vit.h5")
# Out:
# 118/118 [==============================] - 4s 33ms/step - loss: 0.2045 - categorical_accuracy: 0.9381 - top_5_categorical_accuracy: 1.0000 - precision: 0.9509 - recall: 0.9297 - cosine_similarity: 0.9464
# Evaluation results: [0.20447306334972382, 0.9381333589553833, 1.0, 0.9509068727493286, 0.9297333359718323, 0.9463591575622559]
# Model saved to /content/NSCLC_Radiomics_50k_splitted2/vit.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Generate predictions for train, validation, and test datasets
train_predictions = vit.predict(train_ds)
val_predictions = vit.predict(val_ds)
test_predictions = vit.predict(test_ds)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
val_pred_labels = np.argmax(val_predictions, axis=1)
test_pred_labels = np.argmax(test_predictions, axis=1)

# Get true labels for training, validation, and test datasets
train_true_labels = np.concatenate([y for _, y in train_ds], axis=0)
val_true_labels = np.concatenate([y for _, y in val_ds], axis=0)
test_true_labels = np.concatenate([y for _, y in test_ds], axis=0)

# Convert one-hot encoded labels to integer labels
train_true_labels = np.argmax(train_true_labels, axis=1)
val_true_labels = np.argmax(val_true_labels, axis=1)
test_true_labels = np.argmax(test_true_labels, axis=1)

# Calculate confusion matrices
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
val_conf_matrix = confusion_matrix(val_true_labels, val_pred_labels)
test_conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)

# Plot confusion matrices
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.heatmap(train_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Train Confusion Matrix (VIT)')

plt.subplot(1, 3, 2)
sns.heatmap(val_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Validation Confusion Matrix (VIT)')

plt.subplot(1, 3, 3)
sns.heatmap(test_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Test Confusion Matrix (VIT)')

plt.tight_layout()
plt.show()
# Out:
# 157/157 [==============================] - 6s 33ms/step
# 118/118 [==============================] - 1s 6ms/step
# 118/118 [==============================] - 1s 5ms/step

# %%
from keras.applications import ResNet152V2
#Creating Models (Reducing dimentions and preventing Overfitting)
base_model = ResNet152V2(weights='imagenet', include_top=False, input_shape=(80, 80, 3))


for layer in base_model.layers:
    layer.trainable=True
resnet = Sequential()
resnet.add(base_model)
resnet.add(GaussianNoise(0.25))
resnet.add(GlobalAveragePooling2D())
resnet.add(Dense(128,activation='relu'))
resnet.add(BatchNormalization())
resnet.add(GaussianNoise(0.25))
resnet.add(Dropout(0.25))
resnet.add(Flatten())
resnet.add(Dense(5, activation='softmax'))
resnet.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 10s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 3, 3, 2048)        58331648
#
#  gaussian_noise (GaussianNo  (None, 3, 3, 2048)        0
#  ise)
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 128)               262272
#
#  batch_normalization (Batch  (None, 128)               512
#  Normalization)
#
#  gaussian_noise_1 (Gaussian  (None, 128)               0
#  Noise)
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 58595077 (223.52 MB)
# Trainable params: 58451077 (222.97 MB)
# Non-trainable params: 144000 (562.50 KB)
# _________________________________________________________________

# %%
# Define early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_student_loss',
    patience=30,
    verbose=1,
    restore_best_weights=True
)
distiller = Distiller(student=resnet, teacher=vit)
distiller.compile(
    optimizer=tf.keras.optimizers.SGD(),
    student_loss_fn=keras.losses.CategoricalCrossentropy(),
    distillation_loss_fn=keras.losses.KLDivergence(),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_categorical_accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.CosineSimilarity(name='cosine_similarity')
    ]
)

# Initialize variables to keep track of the best validation loss and corresponding model weights
best_val_loss = float('inf')
best_weights = None

# Lists to store training and validation metrics
distiller_train1_losses = []
distiller_train2_losses = []
distiller_val_losses = []
distiller_train_accuracies = []
distiller_val_accuracies = []
distiller_train_precisions = []
distiller_val_precisions = []
distiller_train_recalls = []
distiller_val_recalls = []
distiller_train_cosine_similarity = []
distiller_val_cosine_similarity = []

for epoch in range(100):
    # Train the model for one epoch
    history = distiller.fit(train_ds, epochs=1, validation_data=val_ds, steps_per_epoch=100, callbacks=[early_stopping])
    # Append training and validation metrics for plotting
    distiller_train1_losses.append(history.history['distillation_loss'][0])
    distiller_train2_losses.append(history.history['student_loss'][0])
    distiller_val_losses.append(history.history['val_student_loss'][0])
    distiller_train_accuracies.append(history.history['categorical_accuracy'][0])
    distiller_val_accuracies.append(history.history['val_categorical_accuracy'][0])
    distiller_train_precisions.append(history.history['precision'][0])
    distiller_val_precisions.append(history.history['val_precision'][0])
    distiller_train_recalls.append(history.history['recall'][0])
    distiller_val_recalls.append(history.history['val_recall'][0])
    distiller_train_cosine_similarity.append(history.history['cosine_similarity'][0])
    distiller_val_cosine_similarity.append(history.history['val_cosine_similarity'][0])

    # Check if the current validation loss is better than the best seen so far
    if history.history['val_student_loss'][0] < best_val_loss:
        best_val_loss = history.history['val_student_loss'][0]
        best_weights = distiller.get_weights()
        # You can also save the weights to a file here if desired

# After training, you can set the model weights to the best weights
distiller.set_weights(best_weights)

# Now you have the training and validation metrics (loss, accuracy, precision, recall, and cosine similarity) stored in the respective lists.
# Out:
# 100/100 [==============================] - 92s 413ms/step - categorical_accuracy: 0.5366 - top_5_categorical_accuracy: 1.0000 - precision: 0.6490 - recall: 0.4244 - cosine_similarity: 0.6238 - student_loss: 1.2111 - distillation_loss: 0.0570 - val_categorical_accuracy: 0.5472 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.6941 - val_recall: 0.3860 - val_cosine_similarity: 0.6379 - val_student_loss: 0.6510
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 0.7281 - top_5_categorical_accuracy: 1.0000 - precision: 0.8159 - recall: 0.6427 - cosine_similarity: 0.7809 - student_loss: 0.6881 - distillation_loss: 0.0336 - val_categorical_accuracy: 0.6960 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8006 - val_recall: 0.5879 - val_cosine_similarity: 0.7565 - val_student_loss: 0.9941
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 0.8736 - top_5_categorical_accuracy: 1.0000 - precision: 0.9144 - recall: 0.8375 - cosine_similarity: 0.8947 - student_loss: 0.3536 - distillation_loss: 0.0163 - val_categorical_accuracy: 0.7980 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8494 - val_recall: 0.7477 - val_cosine_similarity: 0.8314 - val_student_loss: 0.5772
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 0.9561 - top_5_categorical_accuracy: 1.0000 - precision: 0.9699 - recall: 0.9411 - cosine_similarity: 0.9616 - student_loss: 0.1476 - distillation_loss: 0.0062 - val_categorical_accuracy: 0.8463 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8735 - val_recall: 0.8216 - val_cosine_similarity: 0.8693 - val_student_loss: 0.4040
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 0.9911 - top_5_categorical_accuracy: 1.0000 - precision: 0.9936 - recall: 0.9869 - cosine_similarity: 0.9901 - student_loss: 0.0547 - distillation_loss: 0.0020 - val_categorical_accuracy: 0.8789 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8945 - val_recall: 0.8644 - val_cosine_similarity: 0.8950 - val_student_loss: 0.2416
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 0.9991 - top_5_categorical_accuracy: 1.0000 - precision: 0.9994 - recall: 0.9986 - cosine_similarity: 0.9983 - student_loss: 0.0208 - distillation_loss: 7.8391e-04 - val_categorical_accuracy: 0.8831 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9006 - val_recall: 0.8708 - val_cosine_similarity: 0.9005 - val_student_loss: 0.3516
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 0.9997 - top_5_categorical_accuracy: 1.0000 - precision: 0.9997 - recall: 0.9997 - cosine_similarity: 0.9994 - student_loss: 0.0117 - distillation_loss: 6.5383e-04 - val_categorical_accuracy: 0.8905 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8789 - val_cosine_similarity: 0.9062 - val_student_loss: 0.2531
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9998 - student_loss: 0.0072 - distillation_loss: 6.0317e-04 - val_categorical_accuracy: 0.8921 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9034 - val_recall: 0.8812 - val_cosine_similarity: 0.9071 - val_student_loss: 0.2571
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - student_loss: 0.0057 - distillation_loss: 6.1170e-04 - val_categorical_accuracy: 0.8927 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9056 - val_recall: 0.8836 - val_cosine_similarity: 0.9075 - val_student_loss: 0.2610
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - student_loss: 0.0047 - distillation_loss: 6.0074e-04 - val_categorical_accuracy: 0.8941 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9062 - val_recall: 0.8859 - val_cosine_similarity: 0.9078 - val_student_loss: 0.2956
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - student_loss: 0.0043 - distillation_loss: 6.0321e-04 - val_categorical_accuracy: 0.8937 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9047 - val_recall: 0.8851 - val_cosine_similarity: 0.9081 - val_student_loss: 0.3006
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9999 - student_loss: 0.0036 - distillation_loss: 6.1274e-04 - val_categorical_accuracy: 0.8951 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9068 - val_recall: 0.8863 - val_cosine_similarity: 0.9083 - val_student_loss: 0.2781
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0032 - distillation_loss: 5.9265e-04 - val_categorical_accuracy: 0.8957 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9051 - val_recall: 0.8863 - val_cosine_similarity: 0.9082 - val_student_loss: 0.2972
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - student_loss: 0.0029 - distillation_loss: 6.0875e-04 - val_categorical_accuracy: 0.8952 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9052 - val_recall: 0.8851 - val_cosine_similarity: 0.9080 - val_student_loss: 0.2717
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0026 - distillation_loss: 6.0267e-04 - val_categorical_accuracy: 0.8951 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9049 - val_recall: 0.8868 - val_cosine_similarity: 0.9082 - val_student_loss: 0.2708
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0024 - distillation_loss: 6.0958e-04 - val_categorical_accuracy: 0.8944 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9044 - val_recall: 0.8872 - val_cosine_similarity: 0.9083 - val_student_loss: 0.2801
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0021 - distillation_loss: 6.0675e-04 - val_categorical_accuracy: 0.8947 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9044 - val_recall: 0.8867 - val_cosine_similarity: 0.9086 - val_student_loss: 0.2782
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0021 - distillation_loss: 6.0426e-04 - val_categorical_accuracy: 0.8944 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9050 - val_recall: 0.8869 - val_cosine_similarity: 0.9085 - val_student_loss: 0.2811
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0019 - distillation_loss: 6.0653e-04 - val_categorical_accuracy: 0.8955 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9035 - val_recall: 0.8872 - val_cosine_similarity: 0.9082 - val_student_loss: 0.2812
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0018 - distillation_loss: 6.0931e-04 - val_categorical_accuracy: 0.8951 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9045 - val_recall: 0.8873 - val_cosine_similarity: 0.9087 - val_student_loss: 0.2774
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0017 - distillation_loss: 6.0914e-04 - val_categorical_accuracy: 0.8965 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9050 - val_recall: 0.8881 - val_cosine_similarity: 0.9086 - val_student_loss: 0.2943
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0016 - distillation_loss: 6.1005e-04 - val_categorical_accuracy: 0.8956 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9038 - val_recall: 0.8877 - val_cosine_similarity: 0.9086 - val_student_loss: 0.2957
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0016 - distillation_loss: 6.1324e-04 - val_categorical_accuracy: 0.8967 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9043 - val_recall: 0.8883 - val_cosine_similarity: 0.9088 - val_student_loss: 0.2934
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0014 - distillation_loss: 6.1300e-04 - val_categorical_accuracy: 0.8960 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9034 - val_recall: 0.8881 - val_cosine_similarity: 0.9085 - val_student_loss: 0.2930
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0013 - distillation_loss: 6.0859e-04 - val_categorical_accuracy: 0.8955 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8865 - val_cosine_similarity: 0.9087 - val_student_loss: 0.2698
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0012 - distillation_loss: 6.1054e-04 - val_categorical_accuracy: 0.8960 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9044 - val_recall: 0.8868 - val_cosine_similarity: 0.9087 - val_student_loss: 0.2662
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0012 - distillation_loss: 6.1244e-04 - val_categorical_accuracy: 0.8963 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9036 - val_recall: 0.8875 - val_cosine_similarity: 0.9088 - val_student_loss: 0.2584
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0012 - distillation_loss: 6.1469e-04 - val_categorical_accuracy: 0.8957 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8879 - val_cosine_similarity: 0.9086 - val_student_loss: 0.2542
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0011 - distillation_loss: 6.1149e-04 - val_categorical_accuracy: 0.8963 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9041 - val_recall: 0.8884 - val_cosine_similarity: 0.9088 - val_student_loss: 0.2624
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0011 - distillation_loss: 6.1314e-04 - val_categorical_accuracy: 0.8967 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9045 - val_recall: 0.8883 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2588
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0010 - distillation_loss: 6.1503e-04 - val_categorical_accuracy: 0.8973 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9048 - val_recall: 0.8887 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2681
# 100/100 [==============================] - 37s 373ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0011 - distillation_loss: 6.1597e-04 - val_categorical_accuracy: 0.8969 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9044 - val_recall: 0.8892 - val_cosine_similarity: 0.9088 - val_student_loss: 0.2748
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0010 - distillation_loss: 6.1505e-04 - val_categorical_accuracy: 0.8971 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9048 - val_recall: 0.8895 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2799
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 0.0011 - distillation_loss: 6.1436e-04 - val_categorical_accuracy: 0.8979 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9043 - val_recall: 0.8899 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2868
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 9.8374e-04 - distillation_loss: 6.1212e-04 - val_categorical_accuracy: 0.8984 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9054 - val_recall: 0.8905 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2796
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 9.6729e-04 - distillation_loss: 6.1390e-04 - val_categorical_accuracy: 0.8988 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9052 - val_recall: 0.8909 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2791
# 100/100 [==============================] - 37s 373ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 9.0915e-04 - distillation_loss: 6.1604e-04 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9049 - val_recall: 0.8904 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2723
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 8.9577e-04 - distillation_loss: 6.1634e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8907 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2775
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 8.7681e-04 - distillation_loss: 6.1529e-04 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9042 - val_recall: 0.8911 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2773
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 8.3932e-04 - distillation_loss: 6.1595e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9044 - val_recall: 0.8907 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2608
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 8.2533e-04 - distillation_loss: 6.1595e-04 - val_categorical_accuracy: 0.8976 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9043 - val_recall: 0.8907 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2725
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 8.0888e-04 - distillation_loss: 6.1543e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9049 - val_recall: 0.8908 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2689
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 7.7256e-04 - distillation_loss: 6.1719e-04 - val_categorical_accuracy: 0.8984 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9045 - val_recall: 0.8907 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2694
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 7.1361e-04 - distillation_loss: 6.1590e-04 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9051 - val_recall: 0.8909 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2698
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 7.2058e-04 - distillation_loss: 6.1707e-04 - val_categorical_accuracy: 0.8976 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9047 - val_recall: 0.8908 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2676
# 100/100 [==============================] - 37s 373ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 7.2841e-04 - distillation_loss: 6.1673e-04 - val_categorical_accuracy: 0.8977 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9038 - val_recall: 0.8911 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2695
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 6.8058e-04 - distillation_loss: 6.1560e-04 - val_categorical_accuracy: 0.8975 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9038 - val_recall: 0.8905 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2702
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 7.0524e-04 - distillation_loss: 6.1689e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9039 - val_recall: 0.8904 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2662
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 7.0802e-04 - distillation_loss: 6.1760e-04 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9048 - val_recall: 0.8905 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2689
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 6.5255e-04 - distillation_loss: 6.1729e-04 - val_categorical_accuracy: 0.8976 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9043 - val_recall: 0.8907 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2697
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 6.2551e-04 - distillation_loss: 6.1564e-04 - val_categorical_accuracy: 0.8977 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9044 - val_recall: 0.8909 - val_cosine_similarity: 0.9089 - val_student_loss: 0.2703
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 6.6055e-04 - distillation_loss: 6.1649e-04 - val_categorical_accuracy: 0.8973 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9045 - val_recall: 0.8904 - val_cosine_similarity: 0.9090 - val_student_loss: 0.2617
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 6.0461e-04 - distillation_loss: 6.1709e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9045 - val_recall: 0.8911 - val_cosine_similarity: 0.9091 - val_student_loss: 0.2663
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.9050e-04 - distillation_loss: 6.1637e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8916 - val_cosine_similarity: 0.9091 - val_student_loss: 0.2713
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 6.0506e-04 - distillation_loss: 6.1706e-04 - val_categorical_accuracy: 0.8979 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9038 - val_recall: 0.8915 - val_cosine_similarity: 0.9091 - val_student_loss: 0.2703
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.9800e-04 - distillation_loss: 6.1687e-04 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8916 - val_cosine_similarity: 0.9091 - val_student_loss: 0.2798
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.7679e-04 - distillation_loss: 6.1813e-04 - val_categorical_accuracy: 0.8979 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8913 - val_cosine_similarity: 0.9091 - val_student_loss: 0.2789
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.5241e-04 - distillation_loss: 6.1779e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9045 - val_recall: 0.8915 - val_cosine_similarity: 0.9091 - val_student_loss: 0.2786
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.7086e-04 - distillation_loss: 6.1800e-04 - val_categorical_accuracy: 0.8984 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9045 - val_recall: 0.8916 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2851
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.4366e-04 - distillation_loss: 6.1881e-04 - val_categorical_accuracy: 0.8987 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9048 - val_recall: 0.8917 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2859
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.3756e-04 - distillation_loss: 6.1708e-04 - val_categorical_accuracy: 0.8988 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9043 - val_recall: 0.8912 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2841
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.1662e-04 - distillation_loss: 6.1799e-04 - val_categorical_accuracy: 0.8979 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9041 - val_recall: 0.8913 - val_cosine_similarity: 0.9091 - val_student_loss: 0.2837
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.2335e-04 - distillation_loss: 6.1699e-04 - val_categorical_accuracy: 0.8989 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9043 - val_recall: 0.8917 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2840
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.5471e-04 - distillation_loss: 6.1700e-04 - val_categorical_accuracy: 0.8989 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9037 - val_recall: 0.8921 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2874
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.9553e-04 - distillation_loss: 6.1785e-04 - val_categorical_accuracy: 0.8991 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9038 - val_recall: 0.8919 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2837
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.1769e-04 - distillation_loss: 6.1645e-04 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9038 - val_recall: 0.8917 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2844
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 5.0683e-04 - distillation_loss: 6.1654e-04 - val_categorical_accuracy: 0.8988 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9039 - val_recall: 0.8921 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2854
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.8906e-04 - distillation_loss: 6.1734e-04 - val_categorical_accuracy: 0.8991 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9045 - val_recall: 0.8925 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2870
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.7253e-04 - distillation_loss: 6.1774e-04 - val_categorical_accuracy: 0.8995 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9044 - val_recall: 0.8920 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2834
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.5377e-04 - distillation_loss: 6.1908e-04 - val_categorical_accuracy: 0.8989 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9042 - val_recall: 0.8925 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2808
# 100/100 [==============================] - 37s 373ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.6554e-04 - distillation_loss: 6.1815e-04 - val_categorical_accuracy: 0.8989 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8919 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2851
# 100/100 [==============================] - 37s 374ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.7109e-04 - distillation_loss: 6.1741e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9031 - val_recall: 0.8915 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2866
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.8122e-04 - distillation_loss: 6.1963e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9037 - val_recall: 0.8924 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2864
# 100/100 [==============================] - 37s 375ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.3047e-04 - distillation_loss: 6.1746e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9038 - val_recall: 0.8919 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2871
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.4355e-04 - distillation_loss: 6.1847e-04 - val_categorical_accuracy: 0.8984 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9041 - val_recall: 0.8920 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2860
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.4735e-04 - distillation_loss: 6.1739e-04 - val_categorical_accuracy: 0.8980 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9037 - val_recall: 0.8923 - val_cosine_similarity: 0.9094 - val_student_loss: 0.2865
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.0729e-04 - distillation_loss: 6.1872e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8923 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2861
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.2818e-04 - distillation_loss: 6.1863e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9043 - val_recall: 0.8928 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2919
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.3591e-04 - distillation_loss: 6.1851e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8923 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2949
# 100/100 [==============================] - 38s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.9506e-04 - distillation_loss: 6.1789e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9039 - val_recall: 0.8927 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2893
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.1333e-04 - distillation_loss: 6.1862e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9038 - val_recall: 0.8927 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2870
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 4.0098e-04 - distillation_loss: 6.1883e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8925 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2861
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.9220e-04 - distillation_loss: 6.1895e-04 - val_categorical_accuracy: 0.8984 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9044 - val_recall: 0.8925 - val_cosine_similarity: 0.9094 - val_student_loss: 0.2892
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.7841e-04 - distillation_loss: 6.1861e-04 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9046 - val_recall: 0.8928 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2954
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.9685e-04 - distillation_loss: 6.1914e-04 - val_categorical_accuracy: 0.8989 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9042 - val_recall: 0.8932 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2951
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.9937e-04 - distillation_loss: 6.1910e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9045 - val_recall: 0.8936 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2990
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.6635e-04 - distillation_loss: 6.1950e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9042 - val_recall: 0.8932 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2958
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.7534e-04 - distillation_loss: 6.1768e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9043 - val_recall: 0.8933 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2961
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.7782e-04 - distillation_loss: 6.1814e-04 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8929 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2956
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.3949e-04 - distillation_loss: 6.1885e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8931 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2945
# 100/100 [==============================] - 38s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.6728e-04 - distillation_loss: 6.1798e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9039 - val_recall: 0.8931 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2971
# 100/100 [==============================] - 38s 378ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.7989e-04 - distillation_loss: 6.1825e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9041 - val_recall: 0.8929 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2925
# 100/100 [==============================] - 37s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.4839e-04 - distillation_loss: 6.1981e-04 - val_categorical_accuracy: 0.8980 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9043 - val_recall: 0.8929 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2957
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.4279e-04 - distillation_loss: 6.1947e-04 - val_categorical_accuracy: 0.8983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9042 - val_recall: 0.8927 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2927
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.5170e-04 - distillation_loss: 6.1887e-04 - val_categorical_accuracy: 0.8980 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8928 - val_cosine_similarity: 0.9093 - val_student_loss: 0.2939
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.4648e-04 - distillation_loss: 6.1974e-04 - val_categorical_accuracy: 0.8977 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9039 - val_recall: 0.8928 - val_cosine_similarity: 0.9092 - val_student_loss: 0.3014
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.4309e-04 - distillation_loss: 6.2062e-04 - val_categorical_accuracy: 0.8987 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9044 - val_recall: 0.8932 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2973
# 100/100 [==============================] - 38s 376ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.3645e-04 - distillation_loss: 6.1947e-04 - val_categorical_accuracy: 0.8980 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9039 - val_recall: 0.8928 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2954
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.3042e-04 - distillation_loss: 6.1984e-04 - val_categorical_accuracy: 0.8981 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9038 - val_recall: 0.8927 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2943
# 100/100 [==============================] - 38s 377ms/step - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - student_loss: 3.2669e-04 - distillation_loss: 6.1983e-04 - val_categorical_accuracy: 0.8980 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9035 - val_recall: 0.8929 - val_cosine_similarity: 0.9092 - val_student_loss: 0.2932

# %%
import matplotlib.pyplot as plt

# Create a single figure for all subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

# Plot training and validation loss
axes[0, 0].plot(distiller_train1_losses, label='Distillation Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(distiller_train2_losses, label='Student Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(distiller_val_losses, label='Validation_Student Loss', linestyle='--', linewidth=2)
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].set_title('Training and Validation Loss (Distilled RESNET)')

# Plot training and validation accuracy
axes[0, 1].plot(distiller_train_accuracies, label='Training Accuracy', linestyle='-', linewidth=2)
axes[0, 1].plot(distiller_val_accuracies, label='Validation Accuracy', linestyle='--', linewidth=2)
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].set_title('Training and Validation Accuracy (Distilled RESNET)')

# Plot precision, recall, and cosine similarity
axes[0, 2].plot(distiller_train_precisions, label='Training Precision', linestyle='-', linewidth=2)
axes[0, 2].plot(distiller_val_precisions, label='Validation Precision', linestyle='--', linewidth=2)
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend()
axes[0, 2].set_title('Training and Validation Precision (Distilled RESNET)')

axes[1, 0].plot(distiller_train_recalls, label='Training Recall', linestyle='-', linewidth=2)
axes[1, 0].plot(distiller_val_recalls, label='Validation Recall', linestyle='--', linewidth=2)
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend()
axes[1, 0].set_title('Training and Validation Recall (Distilled RESNET)')

axes[1, 1].plot(distiller_train_cosine_similarity, label='Training Cosine Similarity', linestyle='-', linewidth=2)
axes[1, 1].plot(distiller_val_cosine_similarity, label='Validation Cosine Similarity', linestyle='--', linewidth=2)
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Cosine Similarity')
axes[1, 1].legend()
axes[1, 1].set_title('Training and Validation Cosine Similarity (Distilled RESNET)')

# Ensure that the layout is tight
plt.tight_layout()

plt.show()

# %%
# Evaluate the model
evaluation_results = distiller.evaluate(test_ds, batch_size=32)
print("Evaluation results:", evaluation_results)
# Save the trained model to a file
#distiller.save(f"{path}/distiller.h5")
print("Model saved to", f"{path}/distiller1.h5")
# Out:
# 118/118 [==============================] - 10s 86ms/step - categorical_accuracy: 0.8803 - top_5_categorical_accuracy: 1.0000 - precision: 0.8961 - recall: 0.8703 - cosine_similarity: 0.8967 - student_loss: 0.3814
# Evaluation results: [0.8802666664123535, 1.0, 0.896073579788208, 0.8702666759490967, 0.8967262506484985, 0.323778361082077]
# Model saved to /content/NSCLC_Radiomics_50k_splitted2/distiller1.h5

# %%
# Generate predictions for train, validation, and test datasets
train_predictions = resnet.predict(train_ds)
val_predictions = resnet.predict(val_ds)
test_predictions = resnet.predict(test_ds)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
val_pred_labels = np.argmax(val_predictions, axis=1)
test_pred_labels = np.argmax(test_predictions, axis=1)

# Get true labels for training, validation, and test datasets
train_true_labels = np.concatenate([y for _, y in train_ds], axis=0)
val_true_labels = np.concatenate([y for _, y in val_ds], axis=0)
test_true_labels = np.concatenate([y for _, y in test_ds], axis=0)

# Convert one-hot encoded labels to integer labels
train_true_labels = np.argmax(train_true_labels, axis=1)
val_true_labels = np.argmax(val_true_labels, axis=1)
test_true_labels = np.argmax(test_true_labels, axis=1)

# Calculate confusion matrices
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
val_conf_matrix = confusion_matrix(val_true_labels, val_pred_labels)
test_conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)

# Plot confusion matrices
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.heatmap(train_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Train Confusion Matrix (Distilled RESNET) ')

plt.subplot(1, 3, 2)
sns.heatmap(val_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Validation Confusion Matrix (Distilled RESNET)')

plt.subplot(1, 3, 3)
sns.heatmap(test_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Test Confusion Matrix (Distilled RESNET)')

plt.tight_layout()
plt.show()
# Out:
# 157/157 [==============================] - 15s 82ms/step
# 118/118 [==============================] - 9s 78ms/step
# 118/118 [==============================] - 9s 78ms/step

# %%
# Define early stopping callback for ResNet
early_stopping_resnet = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # You can choose any metric to monitor
    patience=30,          # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    restore_best_weights=True  # Do restore best weights
)

# Compile the ResNet model with additional metrics (Precision, Recall, and Cosine Similarity)
resnet.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_categorical_accuracy'),
        tf.keras.metrics.Precision(name='precision'),  # Precision
        tf.keras.metrics.Recall(name='recall'),  # Recall
        tf.keras.metrics.CosineSimilarity(name='cosine_similarity')  # Cosine Similarity
    ]
)

# Initialize variables to keep track of the best validation loss and corresponding model weights for ResNet
best_val_loss_resnet = float('inf')
best_weights_resnet = None

# Lists to store training and validation metrics for ResNet
resnet_train_losses = []
resnet_val_losses = []
resnet_train_accuracies = []
resnet_val_accuracies = []
resnet_train_precisions = []
resnet_val_precisions = []
resnet_train_recalls = []
resnet_val_recalls = []
resnet_train_cosine_similarity = []
resnet_val_cosine_similarity = []

for epoch in range(100):
    # Train the ResNet model for one epoch
    #history = resnet.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping],class_weight = class_weights)
    history = resnet.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping])
    # Append training and validation metrics for plotting
    resnet_train_losses.append(history.history['loss'][0])
    resnet_val_losses.append(history.history['val_loss'][0])
    resnet_train_accuracies.append(history.history['categorical_accuracy'][0])
    resnet_val_accuracies.append(history.history['val_categorical_accuracy'][0])
    resnet_train_precisions.append(history.history['precision'][0])
    resnet_val_precisions.append(history.history['val_precision'][0])
    resnet_train_recalls.append(history.history['recall'][0])
    resnet_val_recalls.append(history.history['val_recall'][0])
    resnet_train_cosine_similarity.append(history.history['cosine_similarity'][0])
    resnet_val_cosine_similarity.append(history.history['val_cosine_similarity'][0])

    # Check if the current validation loss is better than the best seen so far for ResNet
    if history.history['val_loss'][0] < best_val_loss_resnet:
        best_val_loss_resnet = history.history['val_loss'][0]
        best_weights_resnet = resnet.get_weights()

# After training, you can set the model weights to the best weights for ResNet
resnet.set_weights(best_weights_resnet)

# Now you have the training and validation metrics (loss, accuracy, precision, recall, and cosine similarity) stored in the respective lists for ResNet.
# Out:
# 100/100 [==============================] - ETA: 0s - loss: 0.0224 - categorical_accuracy: 0.9981 - top_5_categorical_accuracy: 1.0000 - precision: 0.9987 - recall: 0.9970 - cosine_similarity: 0.9978
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 81s 396ms/step - loss: 0.0224 - categorical_accuracy: 0.9981 - top_5_categorical_accuracy: 1.0000 - precision: 0.9987 - recall: 0.9970 - cosine_similarity: 0.9978 - val_loss: 0.3692 - val_categorical_accuracy: 0.8872 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9018 - val_recall: 0.8764 - val_cosine_similarity: 0.9019
# 100/100 [==============================] - ETA: 0s - loss: 0.0113 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9993
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 37s 366ms/step - loss: 0.0113 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9993 - val_loss: 0.3575 - val_categorical_accuracy: 0.8920 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9040 - val_recall: 0.8811 - val_cosine_similarity: 0.9066
# 100/100 [==============================] - ETA: 0s - loss: 0.0068 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9998
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 37s 367ms/step - loss: 0.0068 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9998 - val_loss: 0.3575 - val_categorical_accuracy: 0.8952 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9073 - val_recall: 0.8871 - val_cosine_similarity: 0.9088
# 100/100 [==============================] - ETA: 0s - loss: 0.0047 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 0.9998 - cosine_similarity: 0.9999
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 37s 368ms/step - loss: 0.0047 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 0.9998 - cosine_similarity: 0.9999 - val_loss: 0.3564 - val_categorical_accuracy: 0.8963 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9068 - val_recall: 0.8875 - val_cosine_similarity: 0.9093
# 100/100 [==============================] - ETA: 0s - loss: 0.0037 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9999
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 37s 366ms/step - loss: 0.0037 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9999 - val_loss: 0.3599 - val_categorical_accuracy: 0.8957 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9059 - val_recall: 0.8877 - val_cosine_similarity: 0.9092
# 100/100 [==============================] - ETA: 0s - loss: 0.0032 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 0.9998 - cosine_similarity: 0.9999
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 37s 367ms/step - loss: 0.0032 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 0.9998 - cosine_similarity: 0.9999 - val_loss: 0.3619 - val_categorical_accuracy: 0.8971 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9069 - val_recall: 0.8887 - val_cosine_similarity: 0.9095
# 100/100 [==============================] - ETA: 0s - loss: 0.0027 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 37s 367ms/step - loss: 0.0027 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3616 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9083 - val_recall: 0.8912 - val_cosine_similarity: 0.9103
# 100/100 [==============================] - ETA: 0s - loss: 0.0023 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 37s 367ms/step - loss: 0.0023 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3628 - val_categorical_accuracy: 0.8993 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9075 - val_recall: 0.8917 - val_cosine_similarity: 0.9105
# 100/100 [==============================] - ETA: 0s - loss: 0.0021 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 0.0021 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3619 - val_categorical_accuracy: 0.8992 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9077 - val_recall: 0.8921 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 0.0019 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 0.0019 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3640 - val_categorical_accuracy: 0.8999 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9077 - val_recall: 0.8931 - val_cosine_similarity: 0.9113
# 100/100 [==============================] - ETA: 0s - loss: 0.0017 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 0.0017 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3676 - val_categorical_accuracy: 0.8995 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9081 - val_recall: 0.8929 - val_cosine_similarity: 0.9106
# 100/100 [==============================] - ETA: 0s - loss: 0.0017 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 0.0017 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3694 - val_categorical_accuracy: 0.8995 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9072 - val_recall: 0.8911 - val_cosine_similarity: 0.9105
# 100/100 [==============================] - ETA: 0s - loss: 0.0015 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0015 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3701 - val_categorical_accuracy: 0.8989 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9074 - val_recall: 0.8920 - val_cosine_similarity: 0.9105
# 100/100 [==============================] - ETA: 0s - loss: 0.0014 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0014 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3704 - val_categorical_accuracy: 0.8999 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9064 - val_recall: 0.8924 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 0.0012 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3731 - val_categorical_accuracy: 0.8985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9067 - val_recall: 0.8925 - val_cosine_similarity: 0.9103
# 100/100 [==============================] - ETA: 0s - loss: 0.0012 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0012 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3728 - val_categorical_accuracy: 0.8995 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9069 - val_recall: 0.8923 - val_cosine_similarity: 0.9106
# 100/100 [==============================] - ETA: 0s - loss: 0.0011 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0011 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3743 - val_categorical_accuracy: 0.9005 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9074 - val_recall: 0.8928 - val_cosine_similarity: 0.9106
# 100/100 [==============================] - ETA: 0s - loss: 0.0011 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0011 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3735 - val_categorical_accuracy: 0.8996 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9064 - val_recall: 0.8935 - val_cosine_similarity: 0.9106
# 100/100 [==============================] - ETA: 0s - loss: 0.0010 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 0.0010 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3742 - val_categorical_accuracy: 0.8999 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9064 - val_recall: 0.8931 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 0.0010 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 0.0010 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3736 - val_categorical_accuracy: 0.9003 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9072 - val_recall: 0.8943 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 9.0537e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 9.0537e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3750 - val_categorical_accuracy: 0.8996 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9068 - val_recall: 0.8943 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 8.8009e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 8.8009e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3759 - val_categorical_accuracy: 0.8997 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9073 - val_recall: 0.8940 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 8.1329e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 8.1329e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3774 - val_categorical_accuracy: 0.8995 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9066 - val_recall: 0.8935 - val_cosine_similarity: 0.9106
# 100/100 [==============================] - ETA: 0s - loss: 8.1796e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 8.1796e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3791 - val_categorical_accuracy: 0.8989 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9065 - val_recall: 0.8935 - val_cosine_similarity: 0.9105
# 100/100 [==============================] - ETA: 0s - loss: 8.1267e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 8.1267e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3792 - val_categorical_accuracy: 0.8997 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9067 - val_recall: 0.8939 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 8.2233e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 8.2233e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3788 - val_categorical_accuracy: 0.8999 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9067 - val_recall: 0.8940 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 7.3222e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 7.3222e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3804 - val_categorical_accuracy: 0.8996 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9065 - val_recall: 0.8936 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 7.5374e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 7.5374e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3814 - val_categorical_accuracy: 0.8997 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9063 - val_recall: 0.8941 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 6.7903e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 6.7903e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3820 - val_categorical_accuracy: 0.8999 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9069 - val_recall: 0.8948 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 6.7202e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 6.7202e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3823 - val_categorical_accuracy: 0.9001 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9070 - val_recall: 0.8945 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 6.3901e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 6.3901e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3825 - val_categorical_accuracy: 0.9007 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9068 - val_recall: 0.8948 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 6.5167e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 6.5167e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3834 - val_categorical_accuracy: 0.8999 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9065 - val_recall: 0.8947 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 6.1983e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 6.1983e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3843 - val_categorical_accuracy: 0.9009 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9067 - val_recall: 0.8949 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 5.7962e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 5.7962e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3850 - val_categorical_accuracy: 0.9015 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9077 - val_recall: 0.8955 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 5.7983e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 5.7983e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3855 - val_categorical_accuracy: 0.9005 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9064 - val_recall: 0.8948 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 5.6966e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 5.6966e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3860 - val_categorical_accuracy: 0.9001 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9065 - val_recall: 0.8951 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 5.7090e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 5.7090e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3865 - val_categorical_accuracy: 0.9005 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9065 - val_recall: 0.8953 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 5.5156e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 5.5156e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3873 - val_categorical_accuracy: 0.9008 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9069 - val_recall: 0.8953 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 5.5992e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 5.5992e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3879 - val_categorical_accuracy: 0.9012 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9072 - val_recall: 0.8957 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 4.9111e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 4.9111e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3884 - val_categorical_accuracy: 0.9012 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9067 - val_recall: 0.8953 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 4.8700e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 4.8700e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3883 - val_categorical_accuracy: 0.9004 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9067 - val_recall: 0.8952 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 5.0784e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 366ms/step - loss: 5.0784e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3887 - val_categorical_accuracy: 0.9001 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9062 - val_recall: 0.8951 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 4.9187e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 4.9187e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3889 - val_categorical_accuracy: 0.9004 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9058 - val_recall: 0.8948 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 4.7264e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 4.7264e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3896 - val_categorical_accuracy: 0.9003 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9055 - val_recall: 0.8945 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 4.4543e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 4.4543e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3898 - val_categorical_accuracy: 0.9005 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9065 - val_recall: 0.8951 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 4.4999e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 4.4999e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3907 - val_categorical_accuracy: 0.9001 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9058 - val_recall: 0.8945 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 4.4553e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 4.4553e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3911 - val_categorical_accuracy: 0.9007 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9057 - val_recall: 0.8951 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 4.3994e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 4.3994e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3912 - val_categorical_accuracy: 0.9003 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9053 - val_recall: 0.8949 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 4.0938e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 4.0938e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3915 - val_categorical_accuracy: 0.9007 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9053 - val_recall: 0.8945 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 4.2104e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 4.2104e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3909 - val_categorical_accuracy: 0.9004 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9057 - val_recall: 0.8949 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 4.0794e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 4.0794e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3912 - val_categorical_accuracy: 0.9005 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9060 - val_recall: 0.8952 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 3.9954e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 363ms/step - loss: 3.9954e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3914 - val_categorical_accuracy: 0.9005 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9060 - val_recall: 0.8955 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 4.2817e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 4.2817e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.3918 - val_categorical_accuracy: 0.8999 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9058 - val_recall: 0.8948 - val_cosine_similarity: 0.9109
# ...
# 100/100 [==============================] - 36s 364ms/step - loss: 2.8747e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4017 - val_categorical_accuracy: 0.9003 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9060 - val_recall: 0.8956 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 2.5612e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.5612e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4021 - val_categorical_accuracy: 0.9003 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9058 - val_recall: 0.8957 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 2.5904e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 2.5904e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4021 - val_categorical_accuracy: 0.9005 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9057 - val_recall: 0.8956 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 2.5932e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.5932e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4024 - val_categorical_accuracy: 0.9005 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9055 - val_recall: 0.8957 - val_cosine_similarity: 0.9110
# 100/100 [==============================] - ETA: 0s - loss: 2.5201e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 2.5201e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4026 - val_categorical_accuracy: 0.9004 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9061 - val_recall: 0.8957 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 2.5464e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.5464e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4031 - val_categorical_accuracy: 0.9003 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9059 - val_recall: 0.8957 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 2.4158e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.4158e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4034 - val_categorical_accuracy: 0.9001 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9062 - val_recall: 0.8961 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 2.4269e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 2.4269e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4038 - val_categorical_accuracy: 0.9004 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9063 - val_recall: 0.8959 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 2.4067e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.4067e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4041 - val_categorical_accuracy: 0.9000 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9057 - val_recall: 0.8961 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 2.4889e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 363ms/step - loss: 2.4889e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4046 - val_categorical_accuracy: 0.9001 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9059 - val_recall: 0.8960 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 2.4215e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.4215e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4047 - val_categorical_accuracy: 0.9003 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9061 - val_recall: 0.8963 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 2.3909e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.3909e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4045 - val_categorical_accuracy: 0.9000 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9057 - val_recall: 0.8965 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 2.3718e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.3718e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4049 - val_categorical_accuracy: 0.8999 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9054 - val_recall: 0.8960 - val_cosine_similarity: 0.9109
# 100/100 [==============================] - ETA: 0s - loss: 2.3519e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 365ms/step - loss: 2.3519e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4053 - val_categorical_accuracy: 0.8997 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9056 - val_recall: 0.8961 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 2.2386e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.2386e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4056 - val_categorical_accuracy: 0.9001 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9052 - val_recall: 0.8963 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 2.2111e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 363ms/step - loss: 2.2111e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4058 - val_categorical_accuracy: 0.9004 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9052 - val_recall: 0.8963 - val_cosine_similarity: 0.9108
# 100/100 [==============================] - ETA: 0s - loss: 2.1247e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.1247e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4065 - val_categorical_accuracy: 0.8999 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9053 - val_recall: 0.8960 - val_cosine_similarity: 0.9107
# 100/100 [==============================] - ETA: 0s - loss: 2.2302e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000
# WARNING:tensorflow:Early stopping conditioned on metric `val_student_loss` which is not available. Available metrics are: loss,categorical_accuracy,top_5_categorical_accuracy,precision,recall,cosine_similarity,val_loss,val_categorical_accuracy,val_top_5_categorical_accuracy,val_precision,val_recall,val_cosine_similarity
# 100/100 [==============================] - 36s 364ms/step - loss: 2.2302e-04 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 0.4068 - val_categorical_accuracy: 0.8997 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9052 - val_recall: 0.8961 - val_cosine_similarity: 0.9107

# %%
import matplotlib.pyplot as plt

# Create a single figure for all subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

# Plot training and validation loss
axes[0, 0].plot(resnet_train_losses, label='Training Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(resnet_val_losses, label='Validation Loss', linestyle='--', linewidth=2)
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].set_title('Training and Validation Loss (ResNet)')

# Plot training and validation accuracy
axes[0, 1].plot(resnet_train_accuracies, label='Training Accuracy', linestyle='-', linewidth=2)
axes[0, 1].plot(resnet_val_accuracies, label='Validation Accuracy', linestyle='--', linewidth=2)
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].set_title('Training and Validation Accuracy (ResNet)')

# Plot precision, recall, and cosine similarity
axes[0, 2].plot(resnet_train_precisions, label='Training Precision', linestyle='-', linewidth=2)
axes[0, 2].plot(resnet_val_precisions, label='Validation Precision', linestyle='--', linewidth=2)
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend()
axes[0, 2].set_title('Training and Validation Precision (ResNet)')

axes[1, 0].plot(resnet_train_recalls, label='Training Recall', linestyle='-', linewidth=2)
axes[1, 0].plot(resnet_val_recalls, label='Validation Recall', linestyle='--', linewidth=2)
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend()
axes[1, 0].set_title('Training and Validation Recall (ResNet)')

axes[1, 1].plot(resnet_train_cosine_similarity, label='Training Cosine Similarity', linestyle='-', linewidth=2)
axes[1, 1].plot(resnet_val_cosine_similarity, label='Validation Cosine Similarity', linestyle='--', linewidth=2)
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Cosine Similarity')
axes[1, 1].legend()
axes[1, 1].set_title('Training and Validation Cosine Similarity (ResNet)')

# Ensure that the layout is tight
plt.tight_layout()

plt.show()

# %%
# Evaluate the model
evaluation_results = resnet.evaluate(test_ds, batch_size=32)
print("Evaluation results:", evaluation_results)
# Save the trained model to a file
resnet.save(f"{path}/resnet.h5")
print("Model saved to", f"{path}/resnet.h5")
# Out:
# 118/118 [==============================] - 10s 84ms/step - loss: 0.3487 - categorical_accuracy: 0.8975 - top_5_categorical_accuracy: 1.0000 - precision: 0.9101 - recall: 0.8900 - cosine_similarity: 0.9108
# Evaluation results: [0.3487471044063568, 0.8974666595458984, 1.0, 0.9101445078849792, 0.8899999856948853, 0.9107763171195984]
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model saved to /content/NSCLC_Radiomics_50k_splitted2/resnet.h5

# %%
# Generate predictions for train, validation, and test datasets
train_predictions = resnet.predict(train_ds)
val_predictions = resnet.predict(val_ds)
test_predictions = resnet.predict(test_ds)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
val_pred_labels = np.argmax(val_predictions, axis=1)
test_pred_labels = np.argmax(test_predictions, axis=1)

# Get true labels for training, validation, and test datasets
train_true_labels = np.concatenate([y for _, y in train_ds], axis=0)
val_true_labels = np.concatenate([y for _, y in val_ds], axis=0)
test_true_labels = np.concatenate([y for _, y in test_ds], axis=0)

# Convert one-hot encoded labels to integer labels
train_true_labels = np.argmax(train_true_labels, axis=1)
val_true_labels = np.argmax(val_true_labels, axis=1)
test_true_labels = np.argmax(test_true_labels, axis=1)

# Calculate confusion matrices
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
val_conf_matrix = confusion_matrix(val_true_labels, val_pred_labels)
test_conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)

# Plot confusion matrices
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.heatmap(train_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Train Confusion Matrix (RESNET)')

plt.subplot(1, 3, 2)
sns.heatmap(val_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Validation Confusion Matrix (RESNET)')

plt.subplot(1, 3, 3)
sns.heatmap(test_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Test Confusion Matrix (RESNET)')

plt.tight_layout()
plt.show()
# Out:
# 157/157 [==============================] - 15s 81ms/step
# 118/118 [==============================] - 10s 81ms/step
# 118/118 [==============================] - 10s 81ms/step

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Dropout

# Create a simple CNN model
cnn = Sequential()
cnn.add(Conv2D(64, (3, 3), activation='relu', input_shape=(80, 80, 3)))
cnn.add(MaxPooling2D((2, 2)))
cnn.add(Flatten())
cnn.add(Dense(256, activation='relu'))
cnn.add(Dropout(0.25))
cnn.add(Dense(128, activation='relu'))
cnn.add(Dropout(0.25))
cnn.add(Dense(64, activation='relu'))
cnn.add(Dropout(0.25))
cnn.add(Dense(5, activation='softmax'))

# Display the model summary
cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 78, 78, 64)        1792
#
#  max_pooling2d_3 (MaxPoolin  (None, 39, 39, 64)        0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 97344)             0
#
#  dense_6 (Dense)             (None, 256)               24920320
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 64)                8256
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 24963589 (95.23 MB)
# Trainable params: 24963589 (95.23 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_student_loss',
    patience=30,
    verbose=1,
    restore_best_weights=True
)
distiller = Distiller(student=cnn, teacher=resnet)
distiller.compile(
    optimizer=tf.keras.optimizers.SGD(),
    student_loss_fn=keras.losses.CategoricalCrossentropy(),
    distillation_loss_fn=keras.losses.KLDivergence(),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_categorical_accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.CosineSimilarity(name='cosine_similarity')
    ]
)

# Initialize variables to keep track of the best validation loss and corresponding model weights
best_val_loss = float('inf')
best_weights = None

# Lists to store training and validation metrics
distiller_train1_losses = []
distiller_train2_losses = []
distiller_val_losses = []
distiller_train_accuracies = []
distiller_val_accuracies = []
distiller_train_precisions = []
distiller_val_precisions = []
distiller_train_recalls = []
distiller_val_recalls = []
distiller_train_cosine_similarity = []
distiller_val_cosine_similarity = []

for epoch in range(100):
    # Train the model for one epoch
    history = distiller.fit(train_ds, epochs=1, validation_data=val_ds, steps_per_epoch=100, callbacks=[early_stopping])
    # Append training and validation metrics for plotting
    distiller_train1_losses.append(history.history['distillation_loss'][0])
    distiller_train2_losses.append(history.history['student_loss'][0])
    distiller_val_losses.append(history.history['val_student_loss'][0])
    distiller_train_accuracies.append(history.history['categorical_accuracy'][0])
    distiller_val_accuracies.append(history.history['val_categorical_accuracy'][0])
    distiller_train_precisions.append(history.history['precision'][0])
    distiller_val_precisions.append(history.history['val_precision'][0])
    distiller_train_recalls.append(history.history['recall'][0])
    distiller_val_recalls.append(history.history['val_recall'][0])
    distiller_train_cosine_similarity.append(history.history['cosine_similarity'][0])
    distiller_val_cosine_similarity.append(history.history['val_cosine_similarity'][0])

    # Check if the current validation loss is better than the best seen so far
    if history.history['val_student_loss'][0] < best_val_loss:
        best_val_loss = history.history['val_student_loss'][0]
        best_weights = distiller.get_weights()
        # You can also save the weights to a file here if desired

# After training, you can set the model weights to the best weights
distiller.set_weights(best_weights)

# Now you have the training and validation metrics (loss, accuracy, precision, recall, and cosine similarity) stored in the respective lists.
# Out:
# 100/100 [==============================] - 16s 112ms/step - categorical_accuracy: 0.3255 - top_5_categorical_accuracy: 1.0000 - precision: 0.4483 - recall: 0.0020 - cosine_similarity: 0.4859 - student_loss: 1.5120 - distillation_loss: 0.0766 - val_categorical_accuracy: 0.5048 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5471 - val_student_loss: 1.3717
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.4570 - top_5_categorical_accuracy: 1.0000 - precision: 0.5944 - recall: 0.0595 - cosine_similarity: 0.5525 - student_loss: 1.3554 - distillation_loss: 0.0696 - val_categorical_accuracy: 0.5393 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8142 - val_recall: 0.1577 - val_cosine_similarity: 0.6140 - val_student_loss: 1.1246
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.4939 - top_5_categorical_accuracy: 1.0000 - precision: 0.7179 - recall: 0.1956 - cosine_similarity: 0.5954 - student_loss: 1.2428 - distillation_loss: 0.0637 - val_categorical_accuracy: 0.5593 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8315 - val_recall: 0.2612 - val_cosine_similarity: 0.6415 - val_student_loss: 1.0278
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.5080 - top_5_categorical_accuracy: 1.0000 - precision: 0.7542 - recall: 0.2612 - cosine_similarity: 0.6160 - student_loss: 1.1776 - distillation_loss: 0.0603 - val_categorical_accuracy: 0.5641 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8409 - val_recall: 0.2848 - val_cosine_similarity: 0.6563 - val_student_loss: 0.9152
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.5327 - top_5_categorical_accuracy: 1.0000 - precision: 0.7558 - recall: 0.2950 - cosine_similarity: 0.6351 - student_loss: 1.1139 - distillation_loss: 0.0575 - val_categorical_accuracy: 0.5824 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.7936 - val_recall: 0.3528 - val_cosine_similarity: 0.6693 - val_student_loss: 0.8679
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.5472 - top_5_categorical_accuracy: 1.0000 - precision: 0.7645 - recall: 0.3241 - cosine_similarity: 0.6484 - student_loss: 1.0747 - distillation_loss: 0.0555 - val_categorical_accuracy: 0.5723 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8149 - val_recall: 0.3175 - val_cosine_similarity: 0.6696 - val_student_loss: 0.9668
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.5614 - top_5_categorical_accuracy: 1.0000 - precision: 0.7729 - recall: 0.3377 - cosine_similarity: 0.6578 - student_loss: 1.0457 - distillation_loss: 0.0541 - val_categorical_accuracy: 0.6071 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8362 - val_recall: 0.3723 - val_cosine_similarity: 0.6885 - val_student_loss: 0.8349
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.5830 - top_5_categorical_accuracy: 1.0000 - precision: 0.7811 - recall: 0.3613 - cosine_similarity: 0.6690 - student_loss: 1.0130 - distillation_loss: 0.0525 - val_categorical_accuracy: 0.6123 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8274 - val_recall: 0.3951 - val_cosine_similarity: 0.6951 - val_student_loss: 0.8578
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.5839 - top_5_categorical_accuracy: 1.0000 - precision: 0.7665 - recall: 0.3775 - cosine_similarity: 0.6756 - student_loss: 0.9886 - distillation_loss: 0.0516 - val_categorical_accuracy: 0.6272 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8178 - val_recall: 0.4224 - val_cosine_similarity: 0.7008 - val_student_loss: 0.7870
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.5997 - top_5_categorical_accuracy: 1.0000 - precision: 0.7836 - recall: 0.3927 - cosine_similarity: 0.6842 - student_loss: 0.9641 - distillation_loss: 0.0504 - val_categorical_accuracy: 0.6272 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.7803 - val_recall: 0.4668 - val_cosine_similarity: 0.7071 - val_student_loss: 0.7243
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.6181 - top_5_categorical_accuracy: 1.0000 - precision: 0.7852 - recall: 0.4187 - cosine_similarity: 0.6957 - student_loss: 0.9367 - distillation_loss: 0.0490 - val_categorical_accuracy: 0.6432 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8149 - val_recall: 0.4773 - val_cosine_similarity: 0.7174 - val_student_loss: 0.7323
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.6297 - top_5_categorical_accuracy: 1.0000 - precision: 0.7861 - recall: 0.4428 - cosine_similarity: 0.7058 - student_loss: 0.9043 - distillation_loss: 0.0474 - val_categorical_accuracy: 0.6644 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8218 - val_recall: 0.4987 - val_cosine_similarity: 0.7327 - val_student_loss: 0.7282
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.6472 - top_5_categorical_accuracy: 1.0000 - precision: 0.8008 - recall: 0.4592 - cosine_similarity: 0.7141 - student_loss: 0.8860 - distillation_loss: 0.0462 - val_categorical_accuracy: 0.6812 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8473 - val_recall: 0.4980 - val_cosine_similarity: 0.7420 - val_student_loss: 0.7293
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.6544 - top_5_categorical_accuracy: 1.0000 - precision: 0.8071 - recall: 0.4891 - cosine_similarity: 0.7249 - student_loss: 0.8495 - distillation_loss: 0.0444 - val_categorical_accuracy: 0.6777 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8157 - val_recall: 0.5251 - val_cosine_similarity: 0.7419 - val_student_loss: 0.6860
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.6633 - top_5_categorical_accuracy: 1.0000 - precision: 0.8076 - recall: 0.5102 - cosine_similarity: 0.7326 - student_loss: 0.8280 - distillation_loss: 0.0434 - val_categorical_accuracy: 0.6941 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8273 - val_recall: 0.5511 - val_cosine_similarity: 0.7561 - val_student_loss: 0.7088
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.6769 - top_5_categorical_accuracy: 1.0000 - precision: 0.8077 - recall: 0.5192 - cosine_similarity: 0.7397 - student_loss: 0.8095 - distillation_loss: 0.0425 - val_categorical_accuracy: 0.7095 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8223 - val_recall: 0.5872 - val_cosine_similarity: 0.7670 - val_student_loss: 0.6635
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.6848 - top_5_categorical_accuracy: 1.0000 - precision: 0.8173 - recall: 0.5395 - cosine_similarity: 0.7492 - student_loss: 0.7831 - distillation_loss: 0.0411 - val_categorical_accuracy: 0.7145 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8247 - val_recall: 0.5804 - val_cosine_similarity: 0.7683 - val_student_loss: 0.6994
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.7005 - top_5_categorical_accuracy: 1.0000 - precision: 0.8166 - recall: 0.5581 - cosine_similarity: 0.7570 - student_loss: 0.7616 - distillation_loss: 0.0399 - val_categorical_accuracy: 0.7180 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8300 - val_recall: 0.5937 - val_cosine_similarity: 0.7730 - val_student_loss: 0.5595
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.7064 - top_5_categorical_accuracy: 1.0000 - precision: 0.8181 - recall: 0.5727 - cosine_similarity: 0.7621 - student_loss: 0.7413 - distillation_loss: 0.0391 - val_categorical_accuracy: 0.7196 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.7985 - val_recall: 0.6344 - val_cosine_similarity: 0.7764 - val_student_loss: 0.5944
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.7277 - top_5_categorical_accuracy: 1.0000 - precision: 0.8306 - recall: 0.5975 - cosine_similarity: 0.7772 - student_loss: 0.7004 - distillation_loss: 0.0368 - val_categorical_accuracy: 0.7409 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8285 - val_recall: 0.6581 - val_cosine_similarity: 0.7946 - val_student_loss: 0.5489
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.7281 - top_5_categorical_accuracy: 1.0000 - precision: 0.8280 - recall: 0.6136 - cosine_similarity: 0.7806 - student_loss: 0.6858 - distillation_loss: 0.0363 - val_categorical_accuracy: 0.7476 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8442 - val_recall: 0.6373 - val_cosine_similarity: 0.7948 - val_student_loss: 0.6901
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.7441 - top_5_categorical_accuracy: 1.0000 - precision: 0.8390 - recall: 0.6384 - cosine_similarity: 0.7934 - student_loss: 0.6527 - distillation_loss: 0.0343 - val_categorical_accuracy: 0.7617 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8385 - val_recall: 0.6803 - val_cosine_similarity: 0.8063 - val_student_loss: 0.5240
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.7573 - top_5_categorical_accuracy: 1.0000 - precision: 0.8428 - recall: 0.6542 - cosine_similarity: 0.7998 - student_loss: 0.6354 - distillation_loss: 0.0334 - val_categorical_accuracy: 0.7751 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8645 - val_recall: 0.6841 - val_cosine_similarity: 0.8167 - val_student_loss: 0.5310
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.7686 - top_5_categorical_accuracy: 1.0000 - precision: 0.8473 - recall: 0.6686 - cosine_similarity: 0.8083 - student_loss: 0.6102 - distillation_loss: 0.0322 - val_categorical_accuracy: 0.7820 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8394 - val_recall: 0.7211 - val_cosine_similarity: 0.8199 - val_student_loss: 0.5120
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.7764 - top_5_categorical_accuracy: 1.0000 - precision: 0.8566 - recall: 0.6848 - cosine_similarity: 0.8183 - student_loss: 0.5818 - distillation_loss: 0.0305 - val_categorical_accuracy: 0.7955 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8606 - val_recall: 0.7275 - val_cosine_similarity: 0.8316 - val_student_loss: 0.4698
# 100/100 [==============================] - 11s 112ms/step - categorical_accuracy: 0.7867 - top_5_categorical_accuracy: 1.0000 - precision: 0.8561 - recall: 0.7017 - cosine_similarity: 0.8239 - student_loss: 0.5638 - distillation_loss: 0.0296 - val_categorical_accuracy: 0.7855 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8505 - val_recall: 0.7251 - val_cosine_similarity: 0.8257 - val_student_loss: 0.3775
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.7986 - top_5_categorical_accuracy: 1.0000 - precision: 0.8704 - recall: 0.7233 - cosine_similarity: 0.8344 - student_loss: 0.5379 - distillation_loss: 0.0280 - val_categorical_accuracy: 0.7919 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8557 - val_recall: 0.7375 - val_cosine_similarity: 0.8310 - val_student_loss: 0.4485
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.8091 - top_5_categorical_accuracy: 1.0000 - precision: 0.8724 - recall: 0.7402 - cosine_similarity: 0.8452 - student_loss: 0.5034 - distillation_loss: 0.0264 - val_categorical_accuracy: 0.7927 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8524 - val_recall: 0.7353 - val_cosine_similarity: 0.8302 - val_student_loss: 0.4079
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.8277 - top_5_categorical_accuracy: 1.0000 - precision: 0.8857 - recall: 0.7603 - cosine_similarity: 0.8554 - student_loss: 0.4725 - distillation_loss: 0.0247 - val_categorical_accuracy: 0.8301 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8835 - val_recall: 0.7739 - val_cosine_similarity: 0.8555 - val_student_loss: 0.3489
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.8327 - top_5_categorical_accuracy: 1.0000 - precision: 0.8846 - recall: 0.7680 - cosine_similarity: 0.8605 - student_loss: 0.4595 - distillation_loss: 0.0239 - val_categorical_accuracy: 0.8161 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8576 - val_recall: 0.7812 - val_cosine_similarity: 0.8501 - val_student_loss: 0.4333
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.8428 - top_5_categorical_accuracy: 1.0000 - precision: 0.8907 - recall: 0.7905 - cosine_similarity: 0.8702 - student_loss: 0.4285 - distillation_loss: 0.0222 - val_categorical_accuracy: 0.8363 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8789 - val_recall: 0.8001 - val_cosine_similarity: 0.8645 - val_student_loss: 0.3822
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.8473 - top_5_categorical_accuracy: 1.0000 - precision: 0.8950 - recall: 0.7966 - cosine_similarity: 0.8732 - student_loss: 0.4200 - distillation_loss: 0.0217 - val_categorical_accuracy: 0.8181 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8484 - val_recall: 0.7860 - val_cosine_similarity: 0.8488 - val_student_loss: 0.4044
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.8625 - top_5_categorical_accuracy: 1.0000 - precision: 0.9051 - recall: 0.8169 - cosine_similarity: 0.8868 - student_loss: 0.3791 - distillation_loss: 0.0195 - val_categorical_accuracy: 0.8472 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8844 - val_recall: 0.8144 - val_cosine_similarity: 0.8732 - val_student_loss: 0.3263
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.8706 - top_5_categorical_accuracy: 1.0000 - precision: 0.9080 - recall: 0.8261 - cosine_similarity: 0.8913 - student_loss: 0.3683 - distillation_loss: 0.0189 - val_categorical_accuracy: 0.8127 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8462 - val_recall: 0.7864 - val_cosine_similarity: 0.8465 - val_student_loss: 0.4413
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.8813 - top_5_categorical_accuracy: 1.0000 - precision: 0.9144 - recall: 0.8397 - cosine_similarity: 0.8990 - student_loss: 0.3423 - distillation_loss: 0.0176 - val_categorical_accuracy: 0.8397 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8705 - val_recall: 0.8103 - val_cosine_similarity: 0.8663 - val_student_loss: 0.2944
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.8917 - top_5_categorical_accuracy: 1.0000 - precision: 0.9233 - recall: 0.8502 - cosine_similarity: 0.9051 - student_loss: 0.3275 - distillation_loss: 0.0167 - val_categorical_accuracy: 0.8492 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8785 - val_recall: 0.8220 - val_cosine_similarity: 0.8734 - val_student_loss: 0.2663
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.8894 - top_5_categorical_accuracy: 1.0000 - precision: 0.9199 - recall: 0.8486 - cosine_similarity: 0.9058 - student_loss: 0.3219 - distillation_loss: 0.0164 - val_categorical_accuracy: 0.8691 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9002 - val_recall: 0.8363 - val_cosine_similarity: 0.8889 - val_student_loss: 0.3466
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9045 - top_5_categorical_accuracy: 1.0000 - precision: 0.9306 - recall: 0.8755 - cosine_similarity: 0.9190 - student_loss: 0.2848 - distillation_loss: 0.0144 - val_categorical_accuracy: 0.8485 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8800 - val_recall: 0.8201 - val_cosine_similarity: 0.8752 - val_student_loss: 0.3209
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9134 - top_5_categorical_accuracy: 1.0000 - precision: 0.9418 - recall: 0.8848 - cosine_similarity: 0.9272 - student_loss: 0.2578 - distillation_loss: 0.0129 - val_categorical_accuracy: 0.8685 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8916 - val_recall: 0.8488 - val_cosine_similarity: 0.8893 - val_student_loss: 0.2843
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9120 - top_5_categorical_accuracy: 1.0000 - precision: 0.9340 - recall: 0.8847 - cosine_similarity: 0.9241 - student_loss: 0.2633 - distillation_loss: 0.0134 - val_categorical_accuracy: 0.8764 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.8964 - val_recall: 0.8575 - val_cosine_similarity: 0.8953 - val_student_loss: 0.2855
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9270 - top_5_categorical_accuracy: 1.0000 - precision: 0.9441 - recall: 0.9053 - cosine_similarity: 0.9356 - student_loss: 0.2317 - distillation_loss: 0.0115 - val_categorical_accuracy: 0.8847 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9111 - val_recall: 0.8648 - val_cosine_similarity: 0.9029 - val_student_loss: 0.1651
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9245 - top_5_categorical_accuracy: 1.0000 - precision: 0.9448 - recall: 0.9031 - cosine_similarity: 0.9358 - student_loss: 0.2256 - distillation_loss: 0.0114 - val_categorical_accuracy: 0.8892 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9099 - val_recall: 0.8707 - val_cosine_similarity: 0.9048 - val_student_loss: 0.2588
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9330 - top_5_categorical_accuracy: 1.0000 - precision: 0.9506 - recall: 0.9086 - cosine_similarity: 0.9414 - student_loss: 0.2107 - distillation_loss: 0.0105 - val_categorical_accuracy: 0.8965 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9130 - val_recall: 0.8824 - val_cosine_similarity: 0.9114 - val_student_loss: 0.2582
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9433 - top_5_categorical_accuracy: 1.0000 - precision: 0.9573 - recall: 0.9252 - cosine_similarity: 0.9511 - student_loss: 0.1793 - distillation_loss: 0.0088 - val_categorical_accuracy: 0.8847 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9031 - val_recall: 0.8712 - val_cosine_similarity: 0.9020 - val_student_loss: 0.2086
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9456 - top_5_categorical_accuracy: 1.0000 - precision: 0.9608 - recall: 0.9295 - cosine_similarity: 0.9526 - student_loss: 0.1767 - distillation_loss: 0.0085 - val_categorical_accuracy: 0.9044 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9202 - val_recall: 0.8912 - val_cosine_similarity: 0.9176 - val_student_loss: 0.2677
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9539 - top_5_categorical_accuracy: 1.0000 - precision: 0.9623 - recall: 0.9384 - cosine_similarity: 0.9572 - student_loss: 0.1620 - distillation_loss: 0.0078 - val_categorical_accuracy: 0.8927 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9072 - val_recall: 0.8815 - val_cosine_similarity: 0.9083 - val_student_loss: 0.1669
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9541 - top_5_categorical_accuracy: 1.0000 - precision: 0.9677 - recall: 0.9416 - cosine_similarity: 0.9595 - student_loss: 0.1513 - distillation_loss: 0.0073 - val_categorical_accuracy: 0.9029 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9171 - val_recall: 0.8913 - val_cosine_similarity: 0.9173 - val_student_loss: 0.1266
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9583 - top_5_categorical_accuracy: 1.0000 - precision: 0.9689 - recall: 0.9489 - cosine_similarity: 0.9643 - student_loss: 0.1361 - distillation_loss: 0.0065 - val_categorical_accuracy: 0.9128 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9242 - val_recall: 0.9035 - val_cosine_similarity: 0.9234 - val_student_loss: 0.2192
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9627 - top_5_categorical_accuracy: 1.0000 - precision: 0.9715 - recall: 0.9523 - cosine_similarity: 0.9676 - student_loss: 0.1253 - distillation_loss: 0.0059 - val_categorical_accuracy: 0.9117 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9206 - val_recall: 0.9045 - val_cosine_similarity: 0.9229 - val_student_loss: 0.1098
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9608 - top_5_categorical_accuracy: 1.0000 - precision: 0.9696 - recall: 0.9506 - cosine_similarity: 0.9657 - student_loss: 0.1276 - distillation_loss: 0.0062 - val_categorical_accuracy: 0.9144 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9261 - val_recall: 0.9076 - val_cosine_similarity: 0.9269 - val_student_loss: 0.1448
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9652 - top_5_categorical_accuracy: 1.0000 - precision: 0.9710 - recall: 0.9561 - cosine_similarity: 0.9691 - student_loss: 0.1187 - distillation_loss: 0.0057 - val_categorical_accuracy: 0.9057 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9178 - val_recall: 0.8988 - val_cosine_similarity: 0.9193 - val_student_loss: 0.3026
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9641 - top_5_categorical_accuracy: 1.0000 - precision: 0.9722 - recall: 0.9552 - cosine_similarity: 0.9697 - student_loss: 0.1132 - distillation_loss: 0.0054 - val_categorical_accuracy: 0.9195 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9313 - val_recall: 0.9091 - val_cosine_similarity: 0.9297 - val_student_loss: 0.1348
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9737 - top_5_categorical_accuracy: 1.0000 - precision: 0.9799 - recall: 0.9661 - cosine_similarity: 0.9757 - student_loss: 0.0948 - distillation_loss: 0.0044 - val_categorical_accuracy: 0.9181 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9265 - val_recall: 0.9095 - val_cosine_similarity: 0.9283 - val_student_loss: 0.1270
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9725 - top_5_categorical_accuracy: 1.0000 - precision: 0.9777 - recall: 0.9653 - cosine_similarity: 0.9758 - student_loss: 0.0946 - distillation_loss: 0.0044 - val_categorical_accuracy: 0.9129 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9215 - val_recall: 0.9064 - val_cosine_similarity: 0.9236 - val_student_loss: 0.0927
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9734 - top_5_categorical_accuracy: 1.0000 - precision: 0.9787 - recall: 0.9677 - cosine_similarity: 0.9770 - student_loss: 0.0909 - distillation_loss: 0.0042 - val_categorical_accuracy: 0.9215 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9294 - val_recall: 0.9147 - val_cosine_similarity: 0.9304 - val_student_loss: 0.1127
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9778 - top_5_categorical_accuracy: 1.0000 - precision: 0.9814 - recall: 0.9708 - cosine_similarity: 0.9785 - student_loss: 0.0854 - distillation_loss: 0.0040 - val_categorical_accuracy: 0.9229 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9332 - val_recall: 0.9171 - val_cosine_similarity: 0.9336 - val_student_loss: 0.1355
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9773 - top_5_categorical_accuracy: 1.0000 - precision: 0.9825 - recall: 0.9717 - cosine_similarity: 0.9800 - student_loss: 0.0795 - distillation_loss: 0.0037 - val_categorical_accuracy: 0.9240 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9309 - val_recall: 0.9165 - val_cosine_similarity: 0.9326 - val_student_loss: 0.1408
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9789 - top_5_categorical_accuracy: 1.0000 - precision: 0.9837 - recall: 0.9736 - cosine_similarity: 0.9814 - student_loss: 0.0757 - distillation_loss: 0.0035 - val_categorical_accuracy: 0.9103 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9167 - val_recall: 0.9051 - val_cosine_similarity: 0.9209 - val_student_loss: 0.4002
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9786 - top_5_categorical_accuracy: 1.0000 - precision: 0.9830 - recall: 0.9742 - cosine_similarity: 0.9817 - student_loss: 0.0717 - distillation_loss: 0.0033 - val_categorical_accuracy: 0.9220 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9290 - val_recall: 0.9177 - val_cosine_similarity: 0.9323 - val_student_loss: 0.1295
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9808 - top_5_categorical_accuracy: 1.0000 - precision: 0.9850 - recall: 0.9777 - cosine_similarity: 0.9840 - student_loss: 0.0658 - distillation_loss: 0.0030 - val_categorical_accuracy: 0.9289 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9361 - val_recall: 0.9245 - val_cosine_similarity: 0.9377 - val_student_loss: 0.1380
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9845 - top_5_categorical_accuracy: 1.0000 - precision: 0.9876 - recall: 0.9803 - cosine_similarity: 0.9853 - student_loss: 0.0628 - distillation_loss: 0.0028 - val_categorical_accuracy: 0.9203 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9273 - val_recall: 0.9155 - val_cosine_similarity: 0.9301 - val_student_loss: 0.1258
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9873 - top_5_categorical_accuracy: 1.0000 - precision: 0.9896 - recall: 0.9852 - cosine_similarity: 0.9884 - student_loss: 0.0514 - distillation_loss: 0.0022 - val_categorical_accuracy: 0.9263 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9338 - val_recall: 0.9217 - val_cosine_similarity: 0.9357 - val_student_loss: 0.0932
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9864 - top_5_categorical_accuracy: 1.0000 - precision: 0.9887 - recall: 0.9828 - cosine_similarity: 0.9873 - student_loss: 0.0545 - distillation_loss: 0.0024 - val_categorical_accuracy: 0.9228 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9327 - val_recall: 0.9177 - val_cosine_similarity: 0.9321 - val_student_loss: 0.1417
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9817 - top_5_categorical_accuracy: 1.0000 - precision: 0.9855 - recall: 0.9786 - cosine_similarity: 0.9845 - student_loss: 0.0623 - distillation_loss: 0.0029 - val_categorical_accuracy: 0.9291 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9372 - val_recall: 0.9235 - val_cosine_similarity: 0.9375 - val_student_loss: 0.1139
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9875 - top_5_categorical_accuracy: 1.0000 - precision: 0.9896 - recall: 0.9848 - cosine_similarity: 0.9890 - student_loss: 0.0480 - distillation_loss: 0.0021 - val_categorical_accuracy: 0.9304 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9365 - val_recall: 0.9249 - val_cosine_similarity: 0.9375 - val_student_loss: 0.0767
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9864 - top_5_categorical_accuracy: 1.0000 - precision: 0.9890 - recall: 0.9841 - cosine_similarity: 0.9875 - student_loss: 0.0522 - distillation_loss: 0.0023 - val_categorical_accuracy: 0.9335 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9382 - val_recall: 0.9296 - val_cosine_similarity: 0.9406 - val_student_loss: 0.0715
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9887 - top_5_categorical_accuracy: 1.0000 - precision: 0.9901 - recall: 0.9858 - cosine_similarity: 0.9889 - student_loss: 0.0484 - distillation_loss: 0.0021 - val_categorical_accuracy: 0.9303 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9384 - val_recall: 0.9263 - val_cosine_similarity: 0.9389 - val_student_loss: 0.0864
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9891 - top_5_categorical_accuracy: 1.0000 - precision: 0.9915 - recall: 0.9878 - cosine_similarity: 0.9905 - student_loss: 0.0418 - distillation_loss: 0.0018 - val_categorical_accuracy: 0.9328 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9385 - val_recall: 0.9301 - val_cosine_similarity: 0.9401 - val_student_loss: 0.1278
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9902 - top_5_categorical_accuracy: 1.0000 - precision: 0.9917 - recall: 0.9877 - cosine_similarity: 0.9907 - student_loss: 0.0410 - distillation_loss: 0.0018 - val_categorical_accuracy: 0.9296 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9364 - val_recall: 0.9249 - val_cosine_similarity: 0.9379 - val_student_loss: 0.1130
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9898 - top_5_categorical_accuracy: 1.0000 - precision: 0.9915 - recall: 0.9878 - cosine_similarity: 0.9903 - student_loss: 0.0429 - distillation_loss: 0.0018 - val_categorical_accuracy: 0.9313 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9371 - val_recall: 0.9269 - val_cosine_similarity: 0.9389 - val_student_loss: 0.1617
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9912 - top_5_categorical_accuracy: 1.0000 - precision: 0.9929 - recall: 0.9900 - cosine_similarity: 0.9921 - student_loss: 0.0356 - distillation_loss: 0.0015 - val_categorical_accuracy: 0.9337 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9378 - val_recall: 0.9311 - val_cosine_similarity: 0.9409 - val_student_loss: 0.0922
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9923 - top_5_categorical_accuracy: 1.0000 - precision: 0.9937 - recall: 0.9909 - cosine_similarity: 0.9924 - student_loss: 0.0353 - distillation_loss: 0.0015 - val_categorical_accuracy: 0.9344 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9380 - val_recall: 0.9319 - val_cosine_similarity: 0.9410 - val_student_loss: 0.1253
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9928 - top_5_categorical_accuracy: 1.0000 - precision: 0.9936 - recall: 0.9919 - cosine_similarity: 0.9931 - student_loss: 0.0322 - distillation_loss: 0.0013 - val_categorical_accuracy: 0.9309 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9348 - val_recall: 0.9277 - val_cosine_similarity: 0.9386 - val_student_loss: 0.0793
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9917 - top_5_categorical_accuracy: 1.0000 - precision: 0.9931 - recall: 0.9903 - cosine_similarity: 0.9924 - student_loss: 0.0335 - distillation_loss: 0.0014 - val_categorical_accuracy: 0.9340 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9389 - val_recall: 0.9315 - val_cosine_similarity: 0.9423 - val_student_loss: 0.1668
# 100/100 [==============================] - 11s 112ms/step - categorical_accuracy: 0.9934 - top_5_categorical_accuracy: 1.0000 - precision: 0.9941 - recall: 0.9922 - cosine_similarity: 0.9937 - student_loss: 0.0305 - distillation_loss: 0.0012 - val_categorical_accuracy: 0.9293 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9334 - val_recall: 0.9263 - val_cosine_similarity: 0.9351 - val_student_loss: 0.0403
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9923 - top_5_categorical_accuracy: 1.0000 - precision: 0.9936 - recall: 0.9906 - cosine_similarity: 0.9926 - student_loss: 0.0336 - distillation_loss: 0.0014 - val_categorical_accuracy: 0.9356 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9407 - val_recall: 0.9323 - val_cosine_similarity: 0.9422 - val_student_loss: 0.0603
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9936 - top_5_categorical_accuracy: 1.0000 - precision: 0.9950 - recall: 0.9925 - cosine_similarity: 0.9941 - student_loss: 0.0270 - distillation_loss: 0.0011 - val_categorical_accuracy: 0.9320 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9368 - val_recall: 0.9296 - val_cosine_similarity: 0.9406 - val_student_loss: 0.1039
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9925 - top_5_categorical_accuracy: 1.0000 - precision: 0.9939 - recall: 0.9905 - cosine_similarity: 0.9933 - student_loss: 0.0296 - distillation_loss: 0.0013 - val_categorical_accuracy: 0.9344 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9384 - val_recall: 0.9319 - val_cosine_similarity: 0.9413 - val_student_loss: 0.0766
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9936 - top_5_categorical_accuracy: 1.0000 - precision: 0.9951 - recall: 0.9925 - cosine_similarity: 0.9940 - student_loss: 0.0285 - distillation_loss: 0.0012 - val_categorical_accuracy: 0.9375 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9403 - val_recall: 0.9344 - val_cosine_similarity: 0.9436 - val_student_loss: 0.1832
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9939 - top_5_categorical_accuracy: 1.0000 - precision: 0.9947 - recall: 0.9925 - cosine_similarity: 0.9940 - student_loss: 0.0272 - distillation_loss: 0.0012 - val_categorical_accuracy: 0.9352 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9386 - val_recall: 0.9317 - val_cosine_similarity: 0.9413 - val_student_loss: 0.0744
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9950 - top_5_categorical_accuracy: 1.0000 - precision: 0.9961 - recall: 0.9936 - cosine_similarity: 0.9949 - student_loss: 0.0248 - distillation_loss: 0.0010 - val_categorical_accuracy: 0.9332 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9371 - val_recall: 0.9313 - val_cosine_similarity: 0.9403 - val_student_loss: 0.0661
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9936 - top_5_categorical_accuracy: 1.0000 - precision: 0.9945 - recall: 0.9927 - cosine_similarity: 0.9940 - student_loss: 0.0271 - distillation_loss: 0.0012 - val_categorical_accuracy: 0.9369 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9402 - val_recall: 0.9341 - val_cosine_similarity: 0.9429 - val_student_loss: 0.0418
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9952 - top_5_categorical_accuracy: 1.0000 - precision: 0.9958 - recall: 0.9941 - cosine_similarity: 0.9953 - student_loss: 0.0226 - distillation_loss: 9.1797e-04 - val_categorical_accuracy: 0.9348 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9393 - val_recall: 0.9328 - val_cosine_similarity: 0.9417 - val_student_loss: 0.1129
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9933 - top_5_categorical_accuracy: 1.0000 - precision: 0.9934 - recall: 0.9927 - cosine_similarity: 0.9943 - student_loss: 0.0255 - distillation_loss: 0.0011 - val_categorical_accuracy: 0.9340 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9393 - val_recall: 0.9311 - val_cosine_similarity: 0.9415 - val_student_loss: 0.1473
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9934 - top_5_categorical_accuracy: 1.0000 - precision: 0.9948 - recall: 0.9922 - cosine_similarity: 0.9940 - student_loss: 0.0264 - distillation_loss: 0.0011 - val_categorical_accuracy: 0.9336 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9392 - val_recall: 0.9316 - val_cosine_similarity: 0.9413 - val_student_loss: 0.0403
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9950 - top_5_categorical_accuracy: 1.0000 - precision: 0.9955 - recall: 0.9939 - cosine_similarity: 0.9951 - student_loss: 0.0229 - distillation_loss: 9.6112e-04 - val_categorical_accuracy: 0.9383 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9420 - val_recall: 0.9351 - val_cosine_similarity: 0.9444 - val_student_loss: 0.0545
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9962 - top_5_categorical_accuracy: 1.0000 - precision: 0.9970 - recall: 0.9942 - cosine_similarity: 0.9955 - student_loss: 0.0221 - distillation_loss: 8.7607e-04 - val_categorical_accuracy: 0.9369 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9402 - val_recall: 0.9351 - val_cosine_similarity: 0.9435 - val_student_loss: 0.0724
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9945 - top_5_categorical_accuracy: 1.0000 - precision: 0.9955 - recall: 0.9941 - cosine_similarity: 0.9951 - student_loss: 0.0226 - distillation_loss: 9.4601e-04 - val_categorical_accuracy: 0.9356 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9398 - val_recall: 0.9327 - val_cosine_similarity: 0.9429 - val_student_loss: 0.0363
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9962 - top_5_categorical_accuracy: 1.0000 - precision: 0.9969 - recall: 0.9947 - cosine_similarity: 0.9959 - student_loss: 0.0205 - distillation_loss: 8.2542e-04 - val_categorical_accuracy: 0.9371 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9398 - val_recall: 0.9351 - val_cosine_similarity: 0.9429 - val_student_loss: 0.0218
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9959 - top_5_categorical_accuracy: 1.0000 - precision: 0.9962 - recall: 0.9952 - cosine_similarity: 0.9960 - student_loss: 0.0191 - distillation_loss: 8.0095e-04 - val_categorical_accuracy: 0.9359 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9389 - val_recall: 0.9336 - val_cosine_similarity: 0.9419 - val_student_loss: 0.0325
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9950 - top_5_categorical_accuracy: 1.0000 - precision: 0.9961 - recall: 0.9937 - cosine_similarity: 0.9953 - student_loss: 0.0220 - distillation_loss: 9.2035e-04 - val_categorical_accuracy: 0.9340 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9381 - val_recall: 0.9319 - val_cosine_similarity: 0.9411 - val_student_loss: 0.0705
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9953 - top_5_categorical_accuracy: 1.0000 - precision: 0.9959 - recall: 0.9941 - cosine_similarity: 0.9955 - student_loss: 0.0220 - distillation_loss: 9.0292e-04 - val_categorical_accuracy: 0.9344 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9381 - val_recall: 0.9316 - val_cosine_similarity: 0.9422 - val_student_loss: 0.0579
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9962 - top_5_categorical_accuracy: 1.0000 - precision: 0.9967 - recall: 0.9956 - cosine_similarity: 0.9967 - student_loss: 0.0170 - distillation_loss: 6.7283e-04 - val_categorical_accuracy: 0.9380 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9417 - val_recall: 0.9361 - val_cosine_similarity: 0.9443 - val_student_loss: 0.0258
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9956 - top_5_categorical_accuracy: 1.0000 - precision: 0.9959 - recall: 0.9947 - cosine_similarity: 0.9961 - student_loss: 0.0182 - distillation_loss: 7.5290e-04 - val_categorical_accuracy: 0.9367 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9406 - val_recall: 0.9355 - val_cosine_similarity: 0.9439 - val_student_loss: 0.0391
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9961 - top_5_categorical_accuracy: 1.0000 - precision: 0.9964 - recall: 0.9956 - cosine_similarity: 0.9961 - student_loss: 0.0188 - distillation_loss: 7.6443e-04 - val_categorical_accuracy: 0.9360 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9396 - val_recall: 0.9336 - val_cosine_similarity: 0.9429 - val_student_loss: 0.0504
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9945 - top_5_categorical_accuracy: 1.0000 - precision: 0.9947 - recall: 0.9941 - cosine_similarity: 0.9955 - student_loss: 0.0194 - distillation_loss: 8.7607e-04 - val_categorical_accuracy: 0.9395 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9431 - val_recall: 0.9365 - val_cosine_similarity: 0.9446 - val_student_loss: 0.0131
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9956 - top_5_categorical_accuracy: 1.0000 - precision: 0.9962 - recall: 0.9948 - cosine_similarity: 0.9961 - student_loss: 0.0178 - distillation_loss: 7.7130e-04 - val_categorical_accuracy: 0.9383 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9423 - val_recall: 0.9363 - val_cosine_similarity: 0.9443 - val_student_loss: 0.0354
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9980 - top_5_categorical_accuracy: 1.0000 - precision: 0.9983 - recall: 0.9970 - cosine_similarity: 0.9976 - student_loss: 0.0144 - distillation_loss: 5.0458e-04 - val_categorical_accuracy: 0.9376 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9404 - val_recall: 0.9359 - val_cosine_similarity: 0.9428 - val_student_loss: 0.0656
# 100/100 [==============================] - 11s 110ms/step - categorical_accuracy: 0.9952 - top_5_categorical_accuracy: 1.0000 - precision: 0.9962 - recall: 0.9944 - cosine_similarity: 0.9959 - student_loss: 0.0184 - distillation_loss: 8.1183e-04 - val_categorical_accuracy: 0.9369 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9406 - val_recall: 0.9349 - val_cosine_similarity: 0.9429 - val_student_loss: 0.0172
# 100/100 [==============================] - 11s 111ms/step - categorical_accuracy: 0.9947 - top_5_categorical_accuracy: 1.0000 - precision: 0.9952 - recall: 0.9939 - cosine_similarity: 0.9956 - student_loss: 0.0191 - distillation_loss: 8.4891e-04 - val_categorical_accuracy: 0.9367 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.9402 - val_recall: 0.9345 - val_cosine_similarity: 0.9426 - val_student_loss: 0.0095

# %%
import matplotlib.pyplot as plt

# Create a single figure for all subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

# Plot training and validation loss
axes[0, 0].plot(distiller_train1_losses, label='Distillation Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(distiller_train2_losses, label='Student Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(distiller_val_losses, label='Validation_Student Loss', linestyle='--', linewidth=2)
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].set_title('Training and Validation Loss (Distilled CNN)')

# Plot training and validation accuracy
axes[0, 1].plot(distiller_train_accuracies, label='Training Accuracy', linestyle='-', linewidth=2)
axes[0, 1].plot(distiller_val_accuracies, label='Validation Accuracy', linestyle='--', linewidth=2)
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].set_title('Training and Validation Accuracy (Distilled CNN)')

# Plot precision, recall, and cosine similarity
axes[0, 2].plot(distiller_train_precisions, label='Training Precision', linestyle='-', linewidth=2)
axes[0, 2].plot(distiller_val_precisions, label='Validation Precision', linestyle='--', linewidth=2)
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend()
axes[0, 2].set_title('Training and Validation Precision (Distilled CNN)')

axes[1, 0].plot(distiller_train_recalls, label='Training Recall', linestyle='-', linewidth=2)
axes[1, 0].plot(distiller_val_recalls, label='Validation Recall', linestyle='--', linewidth=2)
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend()
axes[1, 0].set_title('Training and Validation Recall (Distilled CNN)')

axes[1, 1].plot(distiller_train_cosine_similarity, label='Training Cosine Similarity', linestyle='-', linewidth=2)
axes[1, 1].plot(distiller_val_cosine_similarity, label='Validation Cosine Similarity', linestyle='--', linewidth=2)
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Cosine Similarity')
axes[1, 1].legend()
axes[1, 1].set_title('Training and Validation Cosine Similarity (Distilled CNN)')

# Ensure that the layout is tight
plt.tight_layout()

plt.show()

# %%
# Evaluate the model
evaluation_results = distiller.evaluate(test_ds, batch_size=32)
print("Evaluation results:", evaluation_results)
# Save the trained model to a file
#distiller.save(f"{path}/distiller.h5")
print("Model saved to", f"{path}/distiller2.h5")
# Out:
# 118/118 [==============================] - 1s 7ms/step - categorical_accuracy: 0.9397 - top_5_categorical_accuracy: 1.0000 - precision: 0.9441 - recall: 0.9375 - cosine_similarity: 0.9470 - student_loss: 0.2453
# Evaluation results: [0.9397333264350891, 1.0, 0.9441385865211487, 0.9374666810035706, 0.9469638466835022, 0.4313942492008209]
# Model saved to /content/NSCLC_Radiomics_50k_splitted2/distiller2.h5

# %%
# Generate predictions for train, validation, and test datasets
train_predictions = cnn.predict(train_ds)
val_predictions = cnn.predict(val_ds)
test_predictions = cnn.predict(test_ds)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
val_pred_labels = np.argmax(val_predictions, axis=1)
test_pred_labels = np.argmax(test_predictions, axis=1)

# Get true labels for training, validation, and test datasets
train_true_labels = np.concatenate([y for _, y in train_ds], axis=0)
val_true_labels = np.concatenate([y for _, y in val_ds], axis=0)
test_true_labels = np.concatenate([y for _, y in test_ds], axis=0)

# Convert one-hot encoded labels to integer labels
train_true_labels = np.argmax(train_true_labels, axis=1)
val_true_labels = np.argmax(val_true_labels, axis=1)
test_true_labels = np.argmax(test_true_labels, axis=1)

# Calculate confusion matrices
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
val_conf_matrix = confusion_matrix(val_true_labels, val_pred_labels)
test_conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)

# Plot confusion matrices
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.heatmap(train_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Train Confusion Matrix (Distilled CNN) ')

plt.subplot(1, 3, 2)
sns.heatmap(val_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Validation Confusion Matrix (Distilled CNN)')

plt.subplot(1, 3, 3)
sns.heatmap(test_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Test Confusion Matrix (Distilled CNN)')

plt.tight_layout()
plt.show()
# Out:
# 157/157 [==============================] - 1s 3ms/step
# 118/118 [==============================] - 0s 3ms/step
# 118/118 [==============================] - 0s 3ms/step
