png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12951.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12952.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12953.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12954.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12956.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12958.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_1296.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12960.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_1297.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12973.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12978.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12981.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12985.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12987.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12989.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_1299.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12990.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12993.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_12994.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13000.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13003.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13004.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13006.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13011.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13013.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13017.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13018.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13019.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13029.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13036.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13037.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13038.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13039.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13041.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13043.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13044.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13046.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13047.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13049.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13050.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13053.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13056.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13057.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13060.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13063.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13066.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13071.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13075.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13078.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13082.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13083.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_1309.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13099.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13100.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13101.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13108.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13109.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13110.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13112.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13113.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13122.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13127.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13135.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13136.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13137.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13141.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13142.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13143.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13148.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_13149.png
# ...
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9545.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9548.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9557.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9559.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9560.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9564.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9566.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9569.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9571.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9577.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9578.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9579.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9581.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9583.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9586.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9589.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_959.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9591.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9599.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_96.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9600.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9611.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9613.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9615.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9617.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9626.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9627.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_963.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9630.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9637.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9642.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9645.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9646.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9650.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9651.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9654.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9660.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9664.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9665.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9666.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9669.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9670.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9672.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9673.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9676.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9679.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9687.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9691.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9692.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9695.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9699.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9701.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9705.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9706.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9708.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9709.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9715.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9716.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_972.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9721.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9723.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9727.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9728.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9732.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9740.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_975.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9755.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9757.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9758.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9762.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9763.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9766.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9768.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9770.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9773.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9775.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9778.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9785.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9788.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9789.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9791.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9793.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9797.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9798.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9809.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9810.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9811.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9813.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_982.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9827.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9832.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9836.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9838.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_984.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9842.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9843.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9846.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9851.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9853.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9854.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9856.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9858.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9859.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_986.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9860.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9861.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9863.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9873.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_988.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9883.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9884.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9886.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9889.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9892.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9912.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9913.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9914.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9917.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9919.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_992.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9921.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9922.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9923.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9924.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9925.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9927.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9928.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9929.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9935.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9937.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_994.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9943.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9948.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9949.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_995.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9952.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9953.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9959.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_996.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9963.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9964.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9966.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9969.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9972.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9975.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9979.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9980.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9993.png
#  extracting: NSCLC_Radiomics_50k_TTV/validation/Squamous_cell_carcinoma/Squamous_cell_carcinoma_9998.png

# %%
#path = "/content/NSCLC_Radiomics_50k_splitted2" #25K
path = "/content/NSCLC_Radiomics_50k_TTV" #50K + cost sensitive

# %%
train_ds = keras.utils.image_dataset_from_directory(
    f"{path}/train",
    labels='inferred',
    label_mode='int',
    batch_size=64,
    image_size=(300, 300)

)

test_ds = keras.utils.image_dataset_from_directory(
    f"{path}/test",
    labels='inferred',
    label_mode='int',
    batch_size=64,
    image_size=(300, 300)

)

val_ds = keras.utils.image_dataset_from_directory(
    f"{path}/validation",
    labels='inferred',
    label_mode='int',
    batch_size=64,
    image_size=(300, 300)

)
# Out:
# Found 20485 files belonging to 5 classes.
# Found 15364 files belonging to 5 classes.
# Found 15366 files belonging to 5 classes.

# %%
# Define the new image size
new_image_size = (80, 80)

# Function to resize images
def resize_image(image, label):
    image = tf.image.resize(image, new_image_size)
    return image, label

# Apply resizing to the datasets
train_ds = train_ds.map(resize_image)
test_ds = test_ds.map(resize_image)
val_ds = val_ds.map(resize_image)

# %%
# Normalize the pixel values
def preprocess(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)  # Convert to float32
    image = image / 255.0  # Normalize pixel values
    return image, label

# Apply preprocessing to the datasets
train_ds = train_ds.map(preprocess)
test_ds = test_ds.map(preprocess)
val_ds = val_ds.map(preprocess)

# One-hot encode the labels
num_classes = 5  # Update with the actual number of classes
train_ds = train_ds.map(lambda image, label: (image, tf.one_hot(label, num_classes)))
test_ds = test_ds.map(lambda image, label: (image, tf.one_hot(label, num_classes)))
val_ds = val_ds.map(lambda image, label: (image, tf.one_hot(label, num_classes)))

# Configure the datasets for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
total_images = 51215
class_frequencies = {
    0: 6018,  # Adenocarcinoma
    1: 13655,  # Large_cell_carcinoma
    2: 5130,   # Normal
    3: 7643,   # Not_otherwise_specified
    4: 18769   # Squamous_cell_carcinoma
}

# Calculate class weights for imbalanced classes
class_weights = {}
total_samples = sum(class_frequencies.values())

for cls, num_samples in class_frequencies.items():
    weight = total_samples / (len(class_frequencies) * num_samples)
    class_weights[cls] = weight

print("Calculated Class Weights for Imbalanced Classes:", class_weights)
# Out:
# Calculated Class Weights for Imbalanced Classes: {0: 1.7020604852110335, 1: 0.7501281581838155, 2: 1.9966861598440546, 3: 1.3401805573727594, 4: 0.545740316479301}

# %%
patch_size = (1, 1)
dropout_rate = 0.05
num_heads = 4
embed_dim = 128  # Higher embedding dimension
num_mlp = 64  # Larger MLP layer
qkv_bias = True  # Keep the same
window_size = 2  # Larger attention window
shift_size = 1  # Larger shift size
image_dimension = 80  # Initial image size
input_shape = (80, 80, 3)

num_patch_x = input_shape[0] // patch_size[0]
num_patch_y = input_shape[1] // patch_size[1]

learning_rate = 0.001
batch_size = 64
num_epochs = 100  # More epochs
weight_decay = 0.0001
label_smoothing = 0.1

# %%
def window_partition(x, window_size):
    _, height, width, channels = x.shape
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    new_height = patch_num_y * window_size
    new_width = patch_num_x * window_size
    x = x[:, :new_height, :new_width, :]  # Trim the input tensor to match the new shape
    x = tf.reshape(
        x, shape=(-1, patch_num_y, window_size, patch_num_x, window_size, channels)
    )
    x = tf.transpose(x, (0, 1, 3, 2, 4, 5))
    windows = tf.reshape(x, shape=(-1, window_size, window_size, channels))
    return windows


def window_reverse(windows, window_size, height, width, channels):
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    x = tf.reshape(
        windows,
        shape=(-1, patch_num_y, patch_num_x, window_size, window_size, channels),
    )
    x = tf.transpose(x, perm=(0, 1, 3, 2, 4, 5))
    x = tf.reshape(x, shape=(-1, height, width, channels))
    return x


class DropPath(layers.Layer):
    def __init__(self, drop_prob=None, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prob

    def call(self, x):
        input_shape = tf.shape(x)
        batch_size = input_shape[0]
        rank = x.shape.rank
        shape = (batch_size,) + (1,) * (rank - 1)
        random_tensor = (1 - self.drop_prob) + tf.random.uniform(shape, dtype=x.dtype)
        path_mask = tf.floor(random_tensor)
        output = tf.math.divide(x, 1 - self.drop_prob) * path_mask
        return output

# %%
class WindowAttention(layers.Layer):
    def __init__(
        self, dim, window_size, num_heads, qkv_bias=True, dropout_rate=0.0, **kwargs
    ):
        super().__init__(**kwargs)
        self.dim = dim
        self.window_size = window_size
        self.num_heads = num_heads
        self.scale = (dim // num_heads) ** -0.5
        self.qkv = layers.Dense(dim * 3, use_bias=qkv_bias)
        self.dropout = layers.Dropout(dropout_rate)
        self.proj = layers.Dense(dim)

    def build(self, input_shape):
        num_window_elements = (2 * self.window_size[0] - 1) * (
            2 * self.window_size[1] - 1
        )
        self.relative_position_bias_table = self.add_weight(
            shape=(num_window_elements, self.num_heads),
            initializer=tf.initializers.Zeros(),
            trainable=True,
        )
        coords_h = np.arange(self.window_size[0])
        coords_w = np.arange(self.window_size[1])
        coords_matrix = np.meshgrid(coords_h, coords_w, indexing="ij")
        coords = np.stack(coords_matrix)
        coords_flatten = coords.reshape(2, -1)
        relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
        relative_coords = relative_coords.transpose([1, 2, 0])
        relative_coords[:, :, 0] += self.window_size[0] - 1
        relative_coords[:, :, 1] += self.window_size[1] - 1
        relative_coords[:, :, 0] *= 2 * self.window_size[1] - 1
        relative_position_index = relative_coords.sum(-1)

        self.relative_position_index = tf.Variable(
            initial_value=tf.convert_to_tensor(relative_position_index), trainable=False
        )

    def call(self, x, mask=None):
        _, size, channels = x.shape
        head_dim = channels // self.num_heads
        x_qkv = self.qkv(x)
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, 3, self.num_heads, head_dim))
        x_qkv = tf.transpose(x_qkv, perm=(2, 0, 3, 1, 4))
        q, k, v = x_qkv[0], x_qkv[1], x_qkv[2]
        q = q * self.scale
        k = tf.transpose(k, perm=(0, 1, 3, 2))
        attn = q @ k

        num_window_elements = self.window_size[0] * self.window_size[1]
        relative_position_index_flat = tf.reshape(
            self.relative_position_index, shape=(-1,)
        )
        relative_position_bias = tf.gather(
            self.relative_position_bias_table, relative_position_index_flat
        )
        relative_position_bias = tf.reshape(
            relative_position_bias, shape=(num_window_elements, num_window_elements, -1)
        )
        relative_position_bias = tf.transpose(relative_position_bias, perm=(2, 0, 1))
        attn = attn + tf.expand_dims(relative_position_bias, axis=0)

        if mask is not None:
            nW = mask.get_shape()[0]
            mask_float = tf.cast(
                tf.expand_dims(tf.expand_dims(mask, axis=1), axis=0), tf.float32
            )
            attn = (
                tf.reshape(attn, shape=(-1, nW, self.num_heads, size, size))
                + mask_float
            )
            attn = tf.reshape(attn, shape=(-1, self.num_heads, size, size))
            attn = keras.activations.softmax(attn, axis=-1)
        else:
            attn = keras.activations.softmax(attn, axis=-1)
        attn = self.dropout(attn)

        x_qkv = attn @ v
        x_qkv = tf.transpose(x_qkv, perm=(0, 2, 1, 3))
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, channels))
        x_qkv = self.proj(x_qkv)
        x_qkv = self.dropout(x_qkv)
        return x_qkv

# %%
class SwinTransformer(layers.Layer):
    def __init__(
        self,
        dim,
        num_patch,
        num_heads,
        window_size=2,
        shift_size=1,
        num_mlp=1024,
        qkv_bias=True,
        dropout_rate=0.0,
        **kwargs,
    ):
        super().__init__(**kwargs)

        self.dim = dim  # number of input dimensions
        self.num_patch = num_patch  # number of embedded patches
        self.num_heads = num_heads  # number of attention heads
        self.window_size = window_size  # size of window
        self.shift_size = shift_size  # size of window shift
        self.num_mlp = num_mlp  # number of MLP nodes

        self.norm1 = layers.LayerNormalization(epsilon=1e-5)
        self.attn = WindowAttention(
            dim,
            window_size=(self.window_size, self.window_size),
            num_heads=num_heads,
            qkv_bias=qkv_bias,
            dropout_rate=dropout_rate,
        )
        self.drop_path = DropPath(dropout_rate)
        self.norm2 = layers.LayerNormalization(epsilon=1e-5)

        self.mlp = keras.Sequential(
            [
                layers.Dense(num_mlp),
                layers.Activation(keras.activations.gelu),
                layers.Dropout(dropout_rate),
                layers.Dense(dim),
                layers.Dropout(dropout_rate),
            ]
        )

        if min(self.num_patch) < self.window_size:
            self.shift_size = 0
            self.window_size = min(self.num_patch)

    def build(self, input_shape):
        if self.shift_size == 0:
            self.attn_mask = None
        else:
            height, width = self.num_patch
            h_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            w_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            mask_array = np.zeros((1, height, width, 1))
            count = 0
            for h in h_slices:
                for w in w_slices:
                    mask_array[:, h, w, :] = count
                    count += 1
            mask_array = tf.convert_to_tensor(mask_array)

            # mask array to windows
            mask_windows = window_partition(mask_array, self.window_size)
            mask_windows = tf.reshape(
                mask_windows, shape=[-1, self.window_size * self.window_size]
            )
            attn_mask = tf.expand_dims(mask_windows, axis=1) - tf.expand_dims(
                mask_windows, axis=2
            )
            attn_mask = tf.where(attn_mask != 0, -100.0, attn_mask)
            attn_mask = tf.where(attn_mask == 0, 0.0, attn_mask)
            self.attn_mask = tf.Variable(initial_value=attn_mask, trainable=False)

    def call(self, x):
        height, width = self.num_patch
        _, num_patches_before, channels = x.shape
        x_skip = x
        x = self.norm1(x)
        x = tf.reshape(x, shape=(-1, height, width, channels))
        if self.shift_size > 0:
            shifted_x = tf.roll(
                x, shift=[-self.shift_size, -self.shift_size], axis=[1, 2]
            )
        else:
            shifted_x = x

        x_windows = window_partition(shifted_x, self.window_size)
        x_windows = tf.reshape(
            x_windows, shape=(-1, self.window_size * self.window_size, channels)
        )
        attn_windows = self.attn(x_windows, mask=self.attn_mask)

        attn_windows = tf.reshape(
            attn_windows, shape=(-1, self.window_size, self.window_size, channels)
        )
        shifted_x = window_reverse(
            attn_windows, self.window_size, height, width, channels
        )
        if self.shift_size > 0:
            x = tf.roll(
                shifted_x, shift=[self.shift_size, self.shift_size], axis=[1, 2]
            )
        else:
            x = shifted_x

        x = tf.reshape(x, shape=(-1, height * width, channels))
        x = self.drop_path(x)
        x = x_skip + x
        x_skip = x
        x = self.norm2(x)
        x = self.mlp(x)
        x = self.drop_path(x)
        x = x_skip + x
        return x

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size_x = patch_size[0]
        self.patch_size_y = patch_size[0]

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size_x, self.patch_size_y, 1),
            strides=(1, self.patch_size_x, self.patch_size_y, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))


class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)


class PatchMerging(keras.layers.Layer):
    def __init__(self, num_patch, embed_dim):
        super().__init__()
        self.num_patch = num_patch
        self.embed_dim = embed_dim
        self.linear_trans = layers.Dense(2 * embed_dim, use_bias=False)

    def call(self, x):
        height, width = self.num_patch
        _, _, C = x.shape

        if height % 2 != 0 or width % 2 != 0:
            raise ValueError("Input dimensions must be divisible by 2 for patch merging")

        x = tf.reshape(x, shape=(-1, height, width, C))
        x0 = x[:, 0::2, 0::2, :]
        x1 = x[:, 1::2, 0::2, :]
        x2 = x[:, 0::2, 1::2, :]
        x3 = x[:, 1::2, 1::2, :]
        x = tf.concat((x0, x1, x2, x3), axis=-1)
        x = tf.reshape(x, shape=(-1, (height // 2) * (width // 2), 4 * C))
        return self.linear_trans(x)

# %%
input = layers.Input(input_shape)
x = layers.RandomCrop(image_dimension, image_dimension)(input)
x = layers.RandomFlip("horizontal")(x)
x = PatchExtract(patch_size)(x)
x = PatchEmbedding(num_patch_x * num_patch_y, embed_dim)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=0,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=shift_size,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = PatchMerging((num_patch_x, num_patch_y), embed_dim=embed_dim)(x)
x = layers.GlobalAveragePooling1D()(x)
output = layers.Dense(num_classes, activation="softmax")(x)

# %%
swin = keras.Model(input, output)
swin.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 80, 80, 3)]       0
#
#  random_crop (RandomCrop)    (None, 80, 80, 3)         0
#
#  random_flip (RandomFlip)    (None, 80, 80, 3)         0
#
#  patch_extract (PatchExtrac  (None, 6400, 3)           0
#  t)
#
#  patch_embedding (PatchEmbe  (None, 6400, 128)         819712
#  dding)
#
#  swin_transformer (SwinTran  (None, 6400, 128)         83188
#  sformer)
#
#  swin_transformer_1 (SwinTr  (None, 6400, 128)         108788
#  ansformer)
#
#  patch_merging (PatchMergin  (None, 1600, 256)         131072
#  g)
#
#  global_average_pooling1d (  (None, 256)               0
#  GlobalAveragePooling1D)
#
#  dense_10 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 1144045 (4.46 MB)
# Trainable params: 1118413 (4.27 MB)
# Non-trainable params: 25632 (200.25 KB)
# _________________________________________________________________

# %%
# Define early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # You can choose any metric to monitor
    patience=30,          # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    restore_best_weights=True  # Do restore best weights
)

# Compile the model
swin.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_categorical_accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.CosineSimilarity(name='cosine_similarity')
    ]
)

# Initialize variables to keep track of the best validation loss and corresponding model weights
best_val_loss = float('inf')
best_weights = None

# Lists to store training and validation metrics
swin_train_losses = []
swin_val_losses = []
swin_train_accuracies = []
swin_val_accuracies = []
swin_train_precisions = []
swin_val_precisions = []
swin_train_recalls = []
swin_val_recalls = []
swin_train_cosine_similarity = []
swin_val_cosine_similarity = []

for epoch in range(200):
    # Train the model for one epoch
    #history = swin.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping],class_weight = class_weights)
    history = swin.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping])
    # Append training and validation metrics for plotting
    swin_train_losses.append(history.history['loss'][0])
    swin_val_losses.append(history.history['val_loss'][0])
    swin_train_accuracies.append(history.history['categorical_accuracy'][0])
    swin_val_accuracies.append(history.history['val_categorical_accuracy'][0])
    swin_train_precisions.append(history.history['precision'][0])
    swin_val_precisions.append(history.history['val_precision'][0])
    swin_train_recalls.append(history.history['recall'][0])
    swin_val_recalls.append(history.history['val_recall'][0])
    swin_train_cosine_similarity.append(history.history['cosine_similarity'][0])
    swin_val_cosine_similarity.append(history.history['val_cosine_similarity'][0])

    # Check if the current validation loss is better than the best seen so far
    if history.history['val_loss'][0] < best_val_loss:
        best_val_loss = history.history['val_loss'][0]
        best_weights = swin.get_weights()
        # You can also save the weights to a file here if desired

# After training, you can set the model weights to the best weights
swin.set_weights(best_weights)

# Now you have the training and validation metrics (loss, accuracy, precision, recall, and cosine similarity) stored in the respective lists.
# Out:
# 100/100 [==============================] - 144s 1s/step - loss: 3.3733 - categorical_accuracy: 0.3028 - top_5_categorical_accuracy: 1.0000 - precision: 0.2652 - recall: 0.0811 - cosine_similarity: 0.4257 - val_loss: 1.4976 - val_categorical_accuracy: 0.3648 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4985
# 100/100 [==============================] - 136s 1s/step - loss: 1.5017 - categorical_accuracy: 0.3550 - top_5_categorical_accuracy: 1.0000 - precision: 0.3333 - recall: 3.1250e-04 - cosine_similarity: 0.4967 - val_loss: 1.4941 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4981
# 100/100 [==============================] - 136s 1s/step - loss: 1.4989 - categorical_accuracy: 0.3684 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.4975 - val_loss: 1.4917 - val_categorical_accuracy: 0.3662 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4999
# 100/100 [==============================] - 136s 1s/step - loss: 1.4929 - categorical_accuracy: 0.3659 - top_5_categorical_accuracy: 1.0000 - precision: 0.3077 - recall: 6.2500e-04 - cosine_similarity: 0.4993 - val_loss: 1.4926 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.
- top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5024 - val_loss: 1.4907 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5000
# 100/100 [==============================] - 136s 1s/step - loss: 1.4847 - categorical_accuracy: 0.3706 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5026 - val_loss: 1.4900 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5003
# 100/100 [==============================] - 136s 1s/step - loss: 1.4830 - categorical_accuracy: 0.3713 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5033 - val_loss: 1.4883 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5009
# 100/100 [==============================] - 136s 1s/step - loss: 1.4807 - categorical_accuracy: 0.3730 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5043 - val_loss: 1.4886 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5009
# 100/100 [==============================] - 136s 1s/step - loss: 1.4828 - categorical_accuracy: 0.3706 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5032 - val_loss: 1.4880 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5009
# 100/100 [==============================] - 136s 1s/step - loss: 1.4842 - categorical_accuracy: 0.3703 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5027 - val_loss: 1.4878 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5010
# 100/100 [==============================] - 136s 1s/step - loss: 1.4837 - categorical_accuracy: 0.3698 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5029 - val_loss: 1.4878 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5010
# 100/100 [==============================] - 136s 1s/step - loss: 1.4839 - categorical_accuracy: 0.3709 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5028 - val_loss: 1.4900 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5002
# 100/100 [==============================] - 136s 1s/step - loss: 1.4829 - categorical_accuracy: 0.3717 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5032 - val_loss: 1.4880 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5010
# 100/100 [==============================] - 136s 1s/step - loss: 1.4842 - categorical_accuracy: 0.3709 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5028 - val_loss: 1.4885 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5008
# 100/100 [==============================] - 136s 1s/step - loss: 1.4830 - categorical_accuracy: 0.3703 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5031 - val_loss: 1.4872 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5012
# 100/100 [==============================] - 136s 1s/step - loss: 1.4832 - categorical_accuracy: 0.3705 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5031 - val_loss: 1.4879 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5010
# 100/100 [==============================] - 136s 1s/step - loss: 1.4846 - categorical_accuracy: 0.3692 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5025 - val_loss: 1.4886 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5007
# 100/100 [==============================] - 136s 1s/step - loss: 1.4836 - categorical_accuracy: 0.3694 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5027 - val_loss: 1.4888 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5007
# 100/100 [==============================] - 136s 1s/step - loss: 1.4827 - categorical_accuracy: 0.3717 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5032 - val_loss: 1.4869 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5013
# 100/100 [==============================] - 136s 1s/step - loss: 1.4820 - categorical_accuracy: 0.3720 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5037 - val_loss: 1.4876 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5010
# 100/100 [==============================] - 136s 1s/step - loss: 1.4811 - categorical_accuracy: 0.3711 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5038 - val_loss: 1.4890 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5004
# 100/100 [==============================] - 136s 1s/step - loss: 1.4841 - categorical_accuracy: 0.3711 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5028 - val_loss: 1.4892 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5006
# 100/100 [==============================] - 136s 1s/step - loss: 1.4827 - categorical_accuracy: 0.3711 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5033 - val_loss: 1.4870 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5012
# 100/100 [==============================] - 136s 1s/step - loss: 1.4841 - categorical_accuracy: 0.3683 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5027 - val_loss: 1.4883 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5008
# 100/100 [==============================] - 136s 1s/step - loss: 1.4837 - categorical_accuracy: 0.3706 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5029 - val_loss: 1.4890 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5006
# 100/100 [==============================] - 136s 1s/step - loss: 1.4839 - categorical_accuracy: 0.3709 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5028 - val_loss: 1.4880 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5010
# 100/100 [==============================] - 136s 1s/step - loss: 1.4818 - categorical_accuracy: 0.3717 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5038 - val_loss: 1.4876 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5011
# 100/100 [==============================] - 136s 1s/step - loss: 1.4838 - categorical_accuracy: 0.3700 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5029 - val_loss: 1.4879 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5010
# 100/100 [==============================] - 136s 1s/step - loss: 1.4840 - categorical_accuracy: 0.3700 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5029 - val_loss: 1.4896 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5005
# 100/100 [==============================] - 136s 1s/step - loss: 1.4842 - categorical_accuracy: 0.3695 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5025 - val_loss: 1.4890 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5006

# %%
import matplotlib.pyplot as plt

# Create a single figure for all subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

# Plot training and validation loss
axes[0, 0].plot(swin_train_losses, label='Training Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(swin_val_losses, label='Validation Loss', linestyle='--', linewidth=2)
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].set_title('Training and Validation Loss (SWIN)')

# Plot training and validation accuracy
axes[0, 1].plot(swin_train_accuracies, label='Training Accuracy', linestyle='-', linewidth=2)
axes[0, 1].plot(swin_val_accuracies, label='Validation Accuracy', linestyle='--', linewidth=2)
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].set_title('Training and Validation Accuracy (SWIN)')

# Plot precision, recall, and cosine similarity
axes[0, 2].plot(swin_train_precisions, label='Training Precision', linestyle='-', linewidth=2)
axes[0, 2].plot(swin_val_precisions, label='Validation Precision', linestyle='--', linewidth=2)
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend()
axes[0, 2].set_title('Training and Validation Precision (SWIN)')

axes[1, 0].plot(swin_train_recalls, label='Training Recall', linestyle='-', linewidth=2)
axes[1, 0].plot(swin_val_recalls, label='Validation Recall', linestyle='--', linewidth=2)
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend()
axes[1, 0].set_title('Training and Validation Recall (SWIN)')

axes[1, 1].plot(swin_train_cosine_similarity, label='Training Cosine Similarity', linestyle='-', linewidth=2)
axes[1, 1].plot(swin_val_cosine_similarity, label='Validation Cosine Similarity', linestyle='--', linewidth=2)
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Cosine Similarity')
axes[1, 1].legend()
axes[1, 1].set_title('Training and Validation Cosine Similarity (SWIN)')

# Ensure that the layout is tight
plt.tight_layout()

plt.show()

# %%
num_classes = 5
num_positions = 144  # Example for 18x18 image patches
input_shape = (80, 80, 3)
learning_rate = 0.001
weight_decay = 0.0001  # Increase weight decay if overfitting occurs
batch_size = 64
num_epochs = 100
image_size = 80
patch_size = 12
# Increase model complexity
transformer_layers = 4  # Increase the number of Transformer layers
projection_dim = 256    # Increase projection dimension
num_heads = 4
num_patches = (image_size // patch_size) ** 2
transformer_units = [projection_dim , projection_dim]
mlp_head_units = [256, 128, 64]  # Increase MLP size
          # Increase the number of attention heads

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_classifier():
    inputs = keras.Input(shape=input_shape)

    # Create patches.
    patches = Patches(patch_size)(inputs)
    # Encode patches.
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = layers.Dropout(0.1)(x3)  # Adjust dropout rate
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # MLP head
    mlp = layers.Dense(256, activation="relu")(representation)  # You can modify the size of the MLP
    mlp = layers.Dropout(0.5)(mlp)
    mlp = layers.Dense(128, activation="relu")(mlp)  # Add more dense layers as needed

    # Classify outputs.
    logits = layers.Dense(num_classes, activation="softmax")(mlp)  # Output layer for classification

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
vit = create_vit_classifier()
vit.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 80, 80, 3)]          0         []
#
#  patches (Patches)           (None, None, 432)            0         ['input_2[0][0]']
#
#  patch_encoder (PatchEncode  (None, 36, 256)              120064    ['patches[0][0]']
#  r)
#
#  layer_normalization_4 (Lay  (None, 36, 256)              512       ['patch_encoder[0][0]']
#  erNormalization)
#
#  multi_head_attention (Mult  (None, 36, 256)              1051904   ['layer_normalization_4[0][0]'
#  iHeadAttention)                                                    , 'layer_normalization_4[0][0]
#                                                                     ']
#
#  add (Add)                   (None, 36, 256)              0         ['multi_head_attention[0][0]',
#                                                                      'patch_encoder[0][0]']
#
#  layer_normalization_5 (Lay  (None, 36, 256)              512       ['add[0][0]']
#  erNormalization)
#
#  dropout_6 (Dropout)         (None, 36, 256)              0         ['layer_normalization_5[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 36, 256)              0         ['dropout_6[0][0]',
#                                                                      'add[0][0]']
#
#  layer_normalization_6 (Lay  (None, 36, 256)              512       ['add_1[0][0]']
#  erNormalization)
#
#  multi_head_attention_1 (Mu  (None, 36, 256)              1051904   ['layer_normalization_6[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_6[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 36, 256)              0         ['multi_head_attention_1[0][0]
#                                                                     ',
#                                                                      'add_1[0][0]']
#
#  layer_normalization_7 (Lay  (None, 36, 256)              512       ['add_2[0][0]']
#  erNormalization)
#
#  dropout_7 (Dropout)         (None, 36, 256)              0         ['layer_normalization_7[0][0]'
#                                                                     ]
#
#  add_3 (Add)                 (None, 36, 256)              0         ['dropout_7[0][0]',
#                                                                      'add_2[0][0]']
#
#  layer_normalization_8 (Lay  (None, 36, 256)              512       ['add_3[0][0]']
#  erNormalization)
#
#  multi_head_attention_2 (Mu  (None, 36, 256)              1051904   ['layer_normalization_8[0][0]'
#  ltiHeadAttention)                                                  , 'layer_normalization_8[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 36, 256)              0         ['multi_head_attention_2[0][0]
#                                                                     ',
#                                                                      'add_3[0][0]']
#
#  layer_normalization_9 (Lay  (None, 36, 256)              512       ['add_4[0][0]']
#  erNormalization)
#
#  dropout_8 (Dropout)         (None, 36, 256)              0         ['layer_normalization_9[0][0]'
#                                                                     ]
#
#  add_5 (Add)                 (None, 36, 256)              0         ['dropout_8[0][0]',
#                                                                      'add_4[0][0]']
#
#  layer_normalization_10 (La  (None, 36, 256)              512       ['add_5[0][0]']
#  yerNormalization)
#
#  multi_head_attention_3 (Mu  (None, 36, 256)              1051904   ['layer_normalization_10[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_10[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 36, 256)              0         ['multi_head_attention_3[0][0]
#                                                                     ',
#                                                                      'add_5[0][0]']
#
#  layer_normalization_11 (La  (None, 36, 256)              512       ['add_6[0][0]']
#  yerNormalization)
#
#  dropout_9 (Dropout)         (None, 36, 256)              0         ['layer_normalization_11[0][0]
#                                                                     ']
#
#  add_7 (Add)                 (None, 36, 256)              0         ['dropout_9[0][0]',
#                                                                      'add_6[0][0]']
#
#  layer_normalization_12 (La  (None, 36, 256)              512       ['add_7[0][0]']
#  yerNormalization)
#
#  flatten (Flatten)           (None, 9216)                 0         ['layer_normalization_12[0][0]
#                                                                     ']
#
#  dropout_10 (Dropout)        (None, 9216)                 0         ['flatten[0][0]']
#
#  dense_12 (Dense)            (None, 256)                  2359552   ['dropout_10[0][0]']
#
#  dropout_11 (Dropout)        (None, 256)                  0         ['dense_12[0][0]']
#
#  dense_13 (Dense)            (None, 128)                  32896     ['dropout_11[0][0]']
#
#  dense_14 (Dense)            (None, 5)                    645       ['dense_13[0][0]']
#
# ==================================================================================================
# Total params: 6725381 (25.66 MB)
# Trainable params: 6725381 (25.66 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Define early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # You can choose any metric to monitor
    patience=30,          # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    restore_best_weights=True  # Do restore best weights
)

# Compile the model
vit.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_categorical_accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.CosineSimilarity(name='cosine_similarity')
    ]
)

# Initialize variables to keep track of the best validation loss and corresponding model weights
best_val_loss = float('inf')
best_weights = None

# Lists to store training and validation metrics
vit_train_losses = []
vit_val_losses = []
vit_train_accuracies = []
vit_val_accuracies = []
vit_train_precisions = []
vit_val_precisions = []
vit_train_recalls = []
vit_val_recalls = []
vit_train_cosine_similarity = []
vit_val_cosine_similarity = []

for epoch in range(200):
    # Train the model for one epoch
    #history = vit.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping],class_weight = class_weights)
    history = vit.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping])
    # Append training and validation metrics for plotting
    vit_train_losses.append(history.history['loss'][0])
    vit_val_losses.append(history.history['val_loss'][0])
    vit_train_accuracies.append(history.history['categorical_accuracy'][0])
    vit_val_accuracies.append(history.history['val_categorical_accuracy'][0])
    vit_train_precisions.append(history.history['precision'][0])
    vit_val_precisions.append(history.history['val_precision'][0])
    vit_train_recalls.append(history.history['recall'][0])
    vit_val_recalls.append(history.history['val_recall'][0])
    vit_train_cosine_similarity.append(history.history['cosine_similarity'][0])
    vit_val_cosine_similarity.append(history.history['val_cosine_similarity'][0])

    # Check if the current validation loss is better than the best seen so far
    if history.history['val_loss'][0] < best_val_loss:
        best_val_loss = history.history['val_loss'][0]
        best_weights = vit.get_weights()
        # You can also save the weights to a file here if desired

# After training, you can set the model weights to the best weights
vit.set_weights(best_weights)

# Now you have the training and validation metrics (loss, accuracy, precision, recall, and cosine similarity) stored in the respective lists.
# Out:
# 100/100 [==============================] - 14s 78ms/step - loss: 1.6444 - categorical_accuracy: 0.3247 - top_5_categorical_accuracy: 1.0000 - precision: 0.3261 - recall: 0.0495 - cosine_similarity: 0.4690 - val_loss: 1.5485 - val_categorical_accuracy: 0.3664 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4746
# 100/100 [==============================] - 7s 72ms/step - loss: 1.5211 - categorical_accuracy: 0.3502 - top_5_categorical_accuracy: 1.0000 - precision: 0.3322 - recall: 0.0152 - cosine_similarity: 0.4891 - val_loss: 1.5342 - val_categorical_accuracy: 0.2678 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4802
# 100/100 [==============================] - 7s 72ms/step - loss: 1.5155 - categorical_accuracy: 0.3636 - top_5_categorical_accuracy: 1.0000 - precision: 0.3990 - recall: 0.0127 - cosine_similarity: 0.4924 - val_loss: 1.5244 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4870
# 100/100 [==============================] - 7s 72ms/step - loss: 1.5112 - categorical_accuracy: 0.3645 - top_5_categorical_accuracy: 1.0000 - precision: 0.3571 - recall: 0.0078 - cosine_similarity: 0.4927 - val_loss: 1.5035 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4950
# 100/100 [==============================] - 7s 72ms/step - loss: 1.5068 - categorical_accuracy: 0.3573 - top_5_categorical_accuracy: 1.0000 - precision: 0.2990 - recall: 0.0045 - cosine_similarity: 0.4936 - val_loss: 1.5250 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4863
# 100/100 [==============================] - 7s 72ms/step - loss: 1.5010 - categorical_accuracy: 0.3667 - top_5_categorical_accuracy: 1.0000 - precision: 0.3607 - recall: 0.0034 - cosine_similarity: 0.4969 - val_loss: 1.5139 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4905
# 100/100 [==============================] - 7s 72ms/step - loss: 1.4976 - categorical_accuracy: 0.3695 - top_5_categorical_accuracy: 1.0000 - precision: 0.3182 - recall: 0.0044 - cosine_similarity: 0.4980 - val_loss: 1.5147 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4895
# 100/100 [==============================] - 7s 72ms/step - loss: 1.4991 - categorical_accuracy: 0.3673 - top_5_categorical_accuracy: 1.0000 - precision: 0.4160 - recall: 0.0081 - cosine_similarity: 0.4974 - val_loss: 1.5009 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4950
# 100/100 [==============================] - 7s 72ms/step - loss: 1.4955 - categorical_accuracy: 0.3666 - top_5_categorical_accuracy: 1.0000 - precision: 0.4048 - recall: 0.0027 - cosine_similarity: 0.4986 - val_loss: 1.4975 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4973
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4963 - categorical_accuracy: 0.3650 - top_5_categorical_accuracy: 1.0000 - precision: 0.4048 - recall: 0.0027 - cosine_similarity: 0.4983 - val_loss: 1.5098 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4918
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4944 - categorical_accuracy: 0.3675 - top_5_categorical_accuracy: 1.0000 - precision: 0.3864 - recall: 0.0027 - cosine_similarity: 0.4991 - val_loss: 1.5016 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4959
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4924 - categorical_accuracy: 0.3705 - top_5_categorical_accuracy: 1.0000 - precision: 0.4464 - recall: 0.0039 - cosine_similarity: 0.4999 - val_loss: 1.5079 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4927
# 100/100 [==============================] - 7s 72ms/step - loss: 1.4935 - categorical_accuracy: 0.3694 - top_5_categorical_accuracy: 1.0000 - precision: 0.2105 - recall: 6.2500e-04 - cosine_similarity: 0.4996 - val_loss: 1.5024 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.
- categorical_accuracy: 0.3713 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5035 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4803 - categorical_accuracy: 0.3719 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5043 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4838 - categorical_accuracy: 0.3694 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5028 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4821 - categorical_accuracy: 0.3703 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5035 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4820 - categorical_accuracy: 0.3722 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5038 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4812 - categorical_accuracy: 0.3720 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5041 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4830 - categorical_accuracy: 0.3697 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5032 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4830 - categorical_accuracy: 0.3703 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5032 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4842 - categorical_accuracy: 0.3698 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5027 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4830 - categorical_accuracy: 0.3703 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5032 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4820 - categorical_accuracy: 0.3705 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5036 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4817 - categorical_accuracy: 0.3708 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5037 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4828 - categorical_accuracy: 0.3688 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5031 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4845 - categorical_accuracy: 0.3692 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5025 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4825 - categorical_accuracy: 0.3714 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5034 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4836 - categorical_accuracy: 0.3705 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5030 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 71ms/step - loss: 1.4829 - categorical_accuracy: 0.3698 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5032 - val_loss: 1.4867 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4813 - categorical_accuracy: 0.3716 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5040 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4813 - categorical_accuracy: 0.3720 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5039 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4826 - categorical_accuracy: 0.3694 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5033 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4831 - categorical_accuracy: 0.3692 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5031 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4828 - categorical_accuracy: 0.3708 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5033 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4810 - categorical_accuracy: 0.3727 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5042 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4823 - categorical_accuracy: 0.3698 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5034 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014
# 100/100 [==============================] - 7s 70ms/step - loss: 1.4825 - categorical_accuracy: 0.3703 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5034 - val_loss: 1.4868 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5014

# %%
import matplotlib.pyplot as plt

# Create a single figure for all subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

# Plot training and validation loss
axes[0, 0].plot(vit_train_losses, label='Training Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(vit_val_losses, label='Validation Loss', linestyle='--', linewidth=2)
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].set_title('Training and Validation Loss (VIT)')

# Plot training and validation accuracy
axes[0, 1].plot(vit_train_accuracies, label='Training Accuracy', linestyle='-', linewidth=2)
axes[0, 1].plot(vit_val_accuracies, label='Validation Accuracy', linestyle='--', linewidth=2)
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].set_title('Training and Validation Accuracy (VIT)')

# Plot precision, recall, and cosine similarity
axes[0, 2].plot(vit_train_precisions, label='Training Precision', linestyle='-', linewidth=2)
axes[0, 2].plot(vit_val_precisions, label='Validation Precision', linestyle='--', linewidth=2)
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend()
axes[0, 2].set_title('Training and Validation Precision (VIT)')

axes[1, 0].plot(vit_train_recalls, label='Training Recall', linestyle='-', linewidth=2)
axes[1, 0].plot(vit_val_recalls, label='Validation Recall', linestyle='--', linewidth=2)
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend()
axes[1, 0].set_title('Training and Validation Recall (VIT)')

axes[1, 1].plot(vit_train_cosine_similarity, label='Training Cosine Similarity', linestyle='-', linewidth=2)
axes[1, 1].plot(vit_val_cosine_similarity, label='Validation Cosine Similarity', linestyle='--', linewidth=2)
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Cosine Similarity')
axes[1, 1].legend()
axes[1, 1].set_title('Training and Validation Cosine Similarity (VIT)')

# Ensure that the layout is tight
plt.tight_layout()

plt.show()

# %%
# Values are from table 4.
patch_size = 4  # 2x2, for the Transformer blocks.
image_size = 80
expansion_factor = 2  # expansion factor for the MobileNetV2 blocks.
batch_size = 64
auto = tf.data.AUTOTUNE
num_classes = 5
learning_rate = 0.002
label_smoothing_factor = 0.1
epochs = 100

# %%
from keras.applications import imagenet_utils

def conv_block(x, filters=16, kernel_size=3, strides=2):
    conv_layer = layers.Conv2D(
        filters, kernel_size, strides=strides, activation=tf.nn.swish, padding="same"
    )
    return conv_layer(x)


# Reference: https://git.io/JKgtC


def inverted_residual_block(x, expanded_channels, output_channels, strides=1):
    m = layers.Conv2D(expanded_channels, 1, padding="same", use_bias=False)(x)
    m = layers.BatchNormalization()(m)
    m = tf.nn.swish(m)

    m = layers.BatchNormalization()(m)
    m = tf.nn.swish(m)

    m = layers.Conv2D(output_channels, 1, padding="same", use_bias=False)(m)
    m = layers.BatchNormalization()(m)

    if tf.math.equal(x.shape[-1], output_channels) and strides == 1:
        return layers.Add()([m, x])
    return m


# Reference:
# https://keras.io/examples/vision/image_classification_with_vision_transformer/


def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.swish)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x


def transformer_block(x, transformer_layers, projection_dim, num_heads=2):
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(x)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, x])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=[x.shape[-1] * 2, x.shape[-1]], dropout_rate=0.1,)
        # Skip connection 2.
        x = layers.Add()([x3, x2])

    return x


def mobilevit_block(x, num_blocks, projection_dim, strides=1):
    # Local projection with a single 3x3 convolution.
    local_features = layers.Conv2D(projection_dim, kernel_size=3, strides=strides, padding='same')(x)

    # Fold into conv-like feature-maps.
    folded_feature_map = layers.Conv2D(x.shape[-1], kernel_size=1, strides=strides, padding='same')(local_features)

    # Combine the folded feature map with the input features.
    local_global_features = layers.Concatenate(axis=-1)([x, folded_feature_map])

    return local_global_features

# %%
def create_mobilevit(num_classes=5):
    inputs = keras.Input((image_size, image_size, 3))
    x = layers.Rescaling(scale=1.0 / 255)(inputs)

    # Initial conv-stem -> MV2 block.
    x = conv_block(x, filters=16)
    x = inverted_residual_block(
        x, expanded_channels=16 * expansion_factor, output_channels=16
    )

    # Downsampling with MV2 block.
    x = inverted_residual_block(
        x, expanded_channels=16 * expansion_factor, output_channels=24, strides=2
    )
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=24
    )
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=24
    )

    # First MV2 -> MobileViT block.
    x = inverted_residual_block(
        x, expanded_channels=24 * expansion_factor, output_channels=48, strides=2
    )
    x = mobilevit_block(x, num_blocks=2, projection_dim=64)

    # Second MV2 -> MobileViT block.
    x = inverted_residual_block(
        x, expanded_channels=64 * expansion_factor, output_channels=64, strides=2
    )
    x = mobilevit_block(x, num_blocks=4, projection_dim=80)

    # Third MV2 -> MobileViT block.
    x = inverted_residual_block(
        x, expanded_channels=80 * expansion_factor, output_channels=80, strides=2
    )
    x = mobilevit_block(x, num_blocks=3, projection_dim=96)
    x = conv_block(x, filters=320, kernel_size=1, strides=1)

    # Classification head.
    x = layers.GlobalAvgPool2D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return keras.Model(inputs, outputs)


mobilevit = create_mobilevit()
mobilevit.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 80, 80, 3)]          0         []
#
#  rescaling (Rescaling)       (None, 80, 80, 3)            0         ['input_3[0][0]']
#
#  conv2d (Conv2D)             (None, 40, 40, 16)           448       ['rescaling[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 40, 40, 32)           512       ['conv2d[0][0]']
#
#  batch_normalization (Batch  (None, 40, 40, 32)           128       ['conv2d_1[0][0]']
#  Normalization)
#
#  tf.nn.silu (TFOpLambda)     (None, 40, 40, 32)           0         ['batch_normalization[0][0]']
#
#  batch_normalization_1 (Bat  (None, 40, 40, 32)           128       ['tf.nn.silu[0][0]']
#  chNormalization)
#
#  tf.nn.silu_1 (TFOpLambda)   (None, 40, 40, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 40, 40, 16)           512       ['tf.nn.silu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 40, 40, 16)           64        ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_8 (Add)                 (None, 40, 40, 16)           0         ['batch_normalization_2[0][0]'
#                                                                     , 'conv2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 40, 40, 32)           512       ['add_8[0][0]']
#
#  batch_normalization_3 (Bat  (None, 40, 40, 32)           128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  tf.nn.silu_2 (TFOpLambda)   (None, 40, 40, 32)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  batch_normalization_4 (Bat  (None, 40, 40, 32)           128       ['tf.nn.silu_2[0][0]']
#  chNormalization)
#
#  tf.nn.silu_3 (TFOpLambda)   (None, 40, 40, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 40, 40, 24)           768       ['tf.nn.silu_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 40, 40, 24)           96        ['conv2d_4[0][0]']
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 40, 40, 48)           1152      ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  batch_normalization_6 (Bat  (None, 40, 40, 48)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  tf.nn.silu_4 (TFOpLambda)   (None, 40, 40, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  batch_normalization_7 (Bat  (None, 40, 40, 48)           192       ['tf.nn.silu_4[0][0]']
#  chNormalization)
#
#  tf.nn.silu_5 (TFOpLambda)   (None, 40, 40, 48)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 40, 40, 24)           1152      ['tf.nn.silu_5[0][0]']
#
#  batch_normalization_8 (Bat  (None, 40, 40, 24)           96        ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_9 (Add)                 (None, 40, 40, 24)           0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_5[0][0]
#                                                                     ']
#
#  conv2d_7 (Conv2D)           (None, 40, 40, 48)           1152      ['add_9[0][0]']
#
#  batch_normalization_9 (Bat  (None, 40, 40, 48)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  tf.nn.silu_6 (TFOpLambda)   (None, 40, 40, 48)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  batch_normalization_10 (Ba  (None, 40, 40, 48)           192       ['tf.nn.silu_6[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_7 (TFOpLambda)   (None, 40, 40, 48)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_8 (Conv2D)           (None, 40, 40, 24)           1152      ['tf.nn.silu_7[0][0]']
#
#  batch_normalization_11 (Ba  (None, 40, 40, 24)           96        ['conv2d_8[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 40, 40, 24)           0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'add_9[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 40, 40, 48)           1152      ['add_10[0][0]']
#
#  batch_normalization_12 (Ba  (None, 40, 40, 48)           192       ['conv2d_9[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_8 (TFOpLambda)   (None, 40, 40, 48)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  batch_normalization_13 (Ba  (None, 40, 40, 48)           192       ['tf.nn.silu_8[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_9 (TFOpLambda)   (None, 40, 40, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 40, 40, 48)           2304      ['tf.nn.silu_9[0][0]']
#
#  batch_normalization_14 (Ba  (None, 40, 40, 48)           192       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 40, 40, 64)           27712     ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 40, 40, 48)           3120      ['conv2d_11[0][0]']
#
#  concatenate (Concatenate)   (None, 40, 40, 96)           0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 40, 40, 128)          12288     ['concatenate[0][0]']
#
#  batch_normalization_15 (Ba  (None, 40, 40, 128)          512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_10 (TFOpLambda)  (None, 40, 40, 128)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  batch_normalization_16 (Ba  (None, 40, 40, 128)          512       ['tf.nn.silu_10[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_11 (TFOpLambda)  (None, 40, 40, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 40, 40, 64)           8192      ['tf.nn.silu_11[0][0]']
#
#  batch_normalization_17 (Ba  (None, 40, 40, 64)           256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 40, 40, 80)           46160     ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 40, 40, 64)           5184      ['conv2d_15[0][0]']
#
#  concatenate_1 (Concatenate  (None, 40, 40, 128)          0         ['batch_normalization_17[0][0]
#  )                                                                  ',
#                                                                      'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 40, 40, 160)          20480     ['concatenate_1[0][0]']
#
#  batch_normalization_18 (Ba  (None, 40, 40, 160)          640       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_12 (TFOpLambda)  (None, 40, 40, 160)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization_19 (Ba  (None, 40, 40, 160)          640       ['tf.nn.silu_12[0][0]']
#  tchNormalization)
#
#  tf.nn.silu_13 (TFOpLambda)  (None, 40, 40, 160)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 40, 40, 80)           12800     ['tf.nn.silu_13[0][0]']
#
#  batch_normalization_20 (Ba  (None, 40, 40, 80)           320       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 40, 40, 96)           69216     ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 40, 40, 80)           7760      ['conv2d_19[0][0]']
#
#  concatenate_2 (Concatenate  (None, 40, 40, 160)          0         ['batch_normalization_20[0][0]
#  )                                                                  ',
#                                                                      'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 40, 40, 320)          51520     ['concatenate_2[0][0]']
#
#  global_average_pooling2d (  (None, 320)                  0         ['conv2d_21[0][0]']
#  GlobalAveragePooling2D)
#
#  dense_15 (Dense)            (None, 5)                    1605      ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 281941 (1.08 MB)
# Trainable params: 279397 (1.07 MB)
# Non-trainable params: 2544 (9.94 KB)
# __________________________________________________________________________________________________

# %%
# Define early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # You can choose any metric to monitor
    patience=30,          # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    restore_best_weights=True  # Do restore best weights
)

# Compile the model
mobilevit.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_categorical_accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.CosineSimilarity(name='cosine_similarity')
    ]
)

# Initialize variables to keep track of the best validation loss and corresponding model weights
best_val_loss = float('inf')
best_weights = None

# Lists to store training and validation metrics
mobilevit_train_losses = []
mobilevit_val_losses = []
mobilevit_train_accuracies = []
mobilevit_val_accuracies = []
mobilevit_train_precisions = []
mobilevit_val_precisions = []
mobilevit_train_recalls = []
mobilevit_val_recalls = []
mobilevit_train_cosine_similarity = []
mobilevit_val_cosine_similarity = []

for epoch in range(200):
    # Train the model for one epoch
    #history = mobilevit.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping],class_weight = class_weights)
    history = mobilevit.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping])
    # Append training and validation metrics for plotting
    mobilevit_train_losses.append(history.history['loss'][0])
    mobilevit_val_losses.append(history.history['val_loss'][0])
    mobilevit_train_accuracies.append(history.history['categorical_accuracy'][0])
    mobilevit_val_accuracies.append(history.history['val_categorical_accuracy'][0])
    mobilevit_train_precisions.append(history.history['precision'][0])
    mobilevit_val_precisions.append(history.history['val_precision'][0])
    mobilevit_train_recalls.append(history.history['recall'][0])
    mobilevit_val_recalls.append(history.history['val_recall'][0])
    mobilevit_train_cosine_similarity.append(history.history['cosine_similarity'][0])
    mobilevit_val_cosine_similarity.append(history.history['val_cosine_similarity'][0])

    # Check if the current validation loss is better than the best seen so far
    if history.history['val_loss'][0] < best_val_loss:
        best_val_loss = history.history['val_loss'][0]
        best_weights = mobilevit.get_weights()
        # You can also save the weights to a file here if desired

# After training, you can set the model weights to the best weights
mobilevit.set_weights(best_weights)

# Now you have the training and validation metrics (loss, accuracy, precision, recall, and cosine similarity) stored in the respective lists.
# Out:
# 100/100 [==============================] - 33s 235ms/step - loss: 1.5359 - categorical_accuracy: 0.3539 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.5625e-04 - cosine_similarity: 0.4806 - val_loss: 1.5637 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4682
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4878 - categorical_accuracy: 0.3703 - top_5_categorical_accuracy: 1.0000 - precision: 0.6522 - recall: 0.0023 - cosine_similarity: 0.5016 - val_loss: 1.5539 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4726
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4811 - categorical_accuracy: 0.3708 - top_5_categorical_accuracy: 1.0000 - precision: 0.6098 - recall: 0.0039 - cosine_similarity: 0.5041 - val_loss: 1.5512 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4737
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4771 - categorical_accuracy: 0.3722 - top_5_categorical_accuracy: 1.0000 - precision: 0.5581 - recall: 0.0037 - cosine_similarity: 0.5056 - val_loss: 1.5505 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4738
# 100/100 [==============================] - 22s 224ms/step - loss: 1.4786 - categorical_accuracy: 0.3716 - top_5_categorical_accuracy: 1.0000 - precision: 0.5400 - recall: 0.0042 - cosine_similarity: 0.5050 - val_loss: 1.5626 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4679
# 100/100 [==============================] - 22s 224ms/step - loss: 1.4787 - categorical_accuracy: 0.3691 - top_5_categorical_accuracy: 1.0000 - precision: 0.6053 - recall: 0.0036 - cosine_similarity: 0.5048 - val_loss: 3.9465 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.3154
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4783 - categorical_accuracy: 0.3695 - top_5_categorical_accuracy: 1.0000 - precision: 0.5000 - recall: 0.0030 - cosine_similarity: 0.5049 - val_loss: 13.2271 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2840
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4755 - categorical_accuracy: 0.3713 - top_5_categorical_accuracy: 1.0000 - precision: 0.5745 - recall: 0.0042 - cosine_similarity: 0.5061 - val_loss: 90.0888 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4761 - categorical_accuracy: 0.3689 - top_5_categorical_accuracy: 1.0000 - precision: 0.5952 - recall: 0.0039 - cosine_similarity: 0.5058 - val_loss: 25.6978 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 224ms/step - loss: 1.4741 - categorical_accuracy: 0.3703 - top_5_categorical_accuracy: 1.0000 - precision: 0.5510 - recall: 0.0042 - cosine_similarity: 0.5067 - val_loss: 23.8633 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3752
# 100/100 [==============================] - 22s 224ms/step - loss: 1.4707 - categorical_accuracy: 0.3725 - top_5_categorical_accuracy: 1.0000 - precision: 0.4762 - recall: 0.0047 - cosine_similarity: 0.5080 - val_loss: 92.3998 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4717 - categorical_accuracy: 0.3713 - top_5_categorical_accuracy: 1.0000 - precision: 0.4844 - recall: 0.0048 - cosine_similarity: 0.5076 - val_loss: 131.7620 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 224ms/step - loss: 1.4682 - categorical_accuracy: 0.3708 - top_5_categorical_accuracy: 1.0000 - precision: 0.5507 - recall: 0.0059 - cosine_similarity: 0.5089 - val_loss: 4.0486 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.3259
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4692 - categorical_accuracy: 0.3702 - top_5_categorical_accuracy: 1.0000 - precision: 0.5211 - recall: 0.0058 - cosine_similarity: 0.5085 - val_loss: 234.9432 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4667 - categorical_accuracy: 0.3705 - top_5_categorical_accuracy: 1.0000 - precision: 0.6053 - recall: 0.0072 - cosine_similarity: 0.5094 - val_loss: 254.4763 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4670 - categorical_accuracy: 0.3678 - top_5_categorical_accuracy: 1.0000 - precision: 0.6374 - recall: 0.0091 - cosine_similarity: 0.5091 - val_loss: 129.9662 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 23s 225ms/step - loss: 1.4616 - categorical_accuracy: 0.3717 - top_5_categorical_accuracy: 1.0000 - precision: 0.5909 - recall: 0.0081 - cosine_similarity: 0.5115 - val_loss: 77.9369 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4596 - categorical_accuracy: 0.3739 - top_5_categorical_accuracy: 1.0000 - precision: 0.6864 - recall: 0.0127 - cosine_similarity: 0.5120 - val_loss: 255.8749 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 222ms/step - loss: 1.4593 - categorical_accuracy: 0.3714 - top_5_categorical_accuracy: 1.0000 - precision: 0.6303 - recall: 0.0117 - cosine_similarity: 0.5121 - val_loss: 70.2422 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4578 - categorical_accuracy: 0.3731 - top_5_categorical_accuracy: 1.0000 - precision: 0.6642 - recall: 0.0139 - cosine_similarity: 0.5126 - val_loss: 175.2398 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4554 - categorical_accuracy: 0.3728 - top_5_categorical_accuracy: 1.0000 - precision: 0.6972 - recall: 0.0155 - cosine_similarity: 0.5134 - val_loss: 608.6268 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4516 - categorical_accuracy: 0.3731 - top_5_categorical_accuracy: 1.0000 - precision: 0.6839 - recall: 0.0206 - cosine_similarity: 0.5150 - val_loss: 225.0401 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4510 - categorical_accuracy: 0.3738 - top_5_categorical_accuracy: 1.0000 - precision: 0.6580 - recall: 0.0237 - cosine_similarity: 0.5156 - val_loss: 309.4733 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4466 - categorical_accuracy: 0.3722 - top_5_categorical_accuracy: 1.0000 - precision: 0.6569 - recall: 0.0314 - cosine_similarity: 0.5170 - val_loss: 192.0314 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4415 - categorical_accuracy: 0.3714 - top_5_categorical_accuracy: 1.0000 - precision: 0.6657 - recall: 0.0348 - cosine_similarity: 0.5188 - val_loss: 125.3661 - val_categorical_accuracy: 0.1861 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1861 - val_recall: 0.1861 - val_cosine_similarity: 0.2374
# 100/100 [==============================] - 22s 222ms/step - loss: 1.4419 - categorical_accuracy: 0.3762 - top_5_categorical_accuracy: 1.0000 - precision: 0.6142 - recall: 0.0445 - cosine_similarity: 0.5188 - val_loss: 107.5010 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4323 - categorical_accuracy: 0.3780 - top_5_categorical_accuracy: 1.0000 - precision: 0.6542 - recall: 0.0464 - cosine_similarity: 0.5226 - val_loss: 124.4346 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 23s 225ms/step - loss: 1.4314 - categorical_accuracy: 0.3844 - top_5_categorical_accuracy: 1.0000 - precision: 0.6051 - recall: 0.0594 - cosine_similarity: 0.5232 - val_loss: 443.0139 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4217 - categorical_accuracy: 0.3883 - top_5_categorical_accuracy: 1.0000 - precision: 0.6442 - recall: 0.0656 - cosine_similarity: 0.5270 - val_loss: 382.6094 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4189 - categorical_accuracy: 0.3881 - top_5_categorical_accuracy: 1.0000 - precision: 0.6525 - recall: 0.0792 - cosine_similarity: 0.5283 - val_loss: 251.7483 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 224ms/step - loss: 1.4177 - categorical_accuracy: 0.3856 - top_5_categorical_accuracy: 1.0000 - precision: 0.6284 - recall: 0.0864 - cosine_similarity: 0.5287 - val_loss: 155.6523 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 1.4107 - categorical_accuracy: 0.3948 - top_5_categorical_accuracy: 1.0000 - precision: 0.6449 - recall: 0.0911 - cosine_similarity: 0.5316 - val_loss: 115.1897 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 1.4034 - categorical_accuracy: 0.4070 - top_5_categorical_accuracy: 1.0000 - precision: 0.6325 - recall: 0.1022 - cosine_similarity: 0.5352 - val_loss: 302.0129 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3904 - categorical_accuracy: 0.4155 - top_5_categorical_accuracy: 1.0000 - precision: 0.6577 - recall: 0.1105 - cosine_similarity: 0.5403 - val_loss: 579.9979 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3911 - categorical_accuracy: 0.4173 - top_5_categorical_accuracy: 1.0000 - precision: 0.6396 - recall: 0.1106 - cosine_similarity: 0.5401 - val_loss: 368.3069 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3766 - categorical_accuracy: 0.4336 - top_5_categorical_accuracy: 1.0000 - precision: 0.6418 - recall: 0.1291 - cosine_similarity: 0.5459 - val_loss: 829.7919 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3700 - categorical_accuracy: 0.4338 - top_5_categorical_accuracy: 1.0000 - precision: 0.6619 - recall: 0.1361 - cosine_similarity: 0.5483 - val_loss: 416.6130 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3660 - categorical_accuracy: 0.4308 - top_5_categorical_accuracy: 1.0000 - precision: 0.6535 - recall: 0.1427 - cosine_similarity: 0.5499 - val_loss: 109.8228 - val_categorical_accuracy: 0.1175 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1175 - val_recall: 0.1175 - val_cosine_similarity: 0.1175
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3529 - categorical_accuracy: 0.4389 - top_5_categorical_accuracy: 1.0000 - precision: 0.6681 - recall: 0.1491 - cosine_similarity: 0.5549 - val_loss: 202.8120 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3421 - categorical_accuracy: 0.4456 - top_5_categorical_accuracy: 1.0000 - precision: 0.6732 - recall: 0.1567 - cosine_similarity: 0.5590 - val_loss: 99.3139 - val_categorical_accuracy: 0.2658 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2658 - val_recall: 0.2658 - val_cosine_similarity: 0.2728
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3289 - categorical_accuracy: 0.4511 - top_5_categorical_accuracy: 1.0000 - precision: 0.6797 - recall: 0.1658 - cosine_similarity: 0.5642 - val_loss: 1174.2671 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3238 - categorical_accuracy: 0.4583 - top_5_categorical_accuracy: 1.0000 - precision: 0.6734 - recall: 0.1730 - cosine_similarity: 0.5660 - val_loss: 213.4554 - val_categorical_accuracy: 0.1175 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1175 - val_recall: 0.1175 - val_cosine_similarity: 0.1175
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3078 - categorical_accuracy: 0.4594 - top_5_categorical_accuracy: 1.0000 - precision: 0.6872 - recall: 0.1956 - cosine_similarity: 0.5723 - val_loss: 371.9145 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.3007 - categorical_accuracy: 0.4648 - top_5_categorical_accuracy: 1.0000 - precision: 0.6865 - recall: 0.1889 - cosine_similarity: 0.5747 - val_loss: 807.0087 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 1.2820 - categorical_accuracy: 0.4770 - top_5_categorical_accuracy: 1.0000 - precision: 0.7009 - recall: 0.2098 - cosine_similarity: 0.5819 - val_loss: 427.5878 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 1.2677 - categorical_accuracy: 0.4875 - top_5_categorical_accuracy: 1.0000 - precision: 0.6935 - recall: 0.2217 - cosine_similarity: 0.5880 - val_loss: 341.4008 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.2603 - categorical_accuracy: 0.4831 - top_5_categorical_accuracy: 1.0000 - precision: 0.6995 - recall: 0.2266 - cosine_similarity: 0.5893 - val_loss: 2182.1133 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 1.2502 - categorical_accuracy: 0.4903 - top_5_categorical_accuracy: 1.0000 - precision: 0.7059 - recall: 0.2325 - cosine_similarity: 0.5929 - val_loss: 985.4167 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 1.2319 - categorical_accuracy: 0.5069 - top_5_categorical_accuracy: 1.0000 - precision: 0.7034 - recall: 0.2531 - cosine_similarity: 0.6005 - val_loss: 429.0638 - val_categorical_accuracy: 0.1175 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1175 - val_recall: 0.1175 - val_cosine_similarity: 0.1175
# 100/100 [==============================] - 22s 222ms/step - loss: 1.2120 - categorical_accuracy: 0.5108 - top_5_categorical_accuracy: 1.0000 - precision: 0.7142 - recall: 0.2683 - cosine_similarity: 0.6063 - val_loss: 1610.5718 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.1869 - categorical_accuracy: 0.5227 - top_5_categorical_accuracy: 1.0000 - precision: 0.7201 - recall: 0.2837 - cosine_similarity: 0.6160 - val_loss: 1750.4872 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 1.1812 - categorical_accuracy: 0.5284 - top_5_categorical_accuracy: 1.0000 - precision: 0.7226 - recall: 0.2983 - cosine_similarity: 0.6184 - val_loss: 2508.0564 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.1694 - categorical_accuracy: 0.5306 - top_5_categorical_accuracy: 1.0000 - precision: 0.7282 - recall: 0.3047 - cosine_similarity: 0.6230 - val_loss: 1402.6123 - val_categorical_accuracy: 0.3180 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3180 - val_recall: 0.3180 - val_cosine_similarity: 0.3293
# 100/100 [==============================] - 23s 225ms/step - loss: 1.1462 - categorical_accuracy: 0.5434 - top_5_categorical_accuracy: 1.0000 - precision: 0.7377 - recall: 0.3288 - cosine_similarity: 0.6318 - val_loss: 2693.4202 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 1.1242 - categorical_accuracy: 0.5511 - top_5_categorical_accuracy: 1.0000 - precision: 0.7448 - recall: 0.3338 - cosine_similarity: 0.6386 - val_loss: 3641.4277 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 1.1044 - categorical_accuracy: 0.5567 - top_5_categorical_accuracy: 1.0000 - precision: 0.7551 - recall: 0.3517 - cosine_similarity: 0.6450 - val_loss: 892.9694 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 1.0854 - categorical_accuracy: 0.5725 - top_5_categorical_accuracy: 1.0000 - precision: 0.7537 - recall: 0.3663 - cosine_similarity: 0.6521 - val_loss: 310.2681 - val_categorical_accuracy: 0.1175 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1175 - val_recall: 0.1175 - val_cosine_similarity: 0.1175
# 100/100 [==============================] - 22s 224ms/step - loss: 1.0605 - categorical_accuracy: 0.5797 - top_5_categorical_accuracy: 1.0000 - precision: 0.7583 - recall: 0.3725 - cosine_similarity: 0.6600 - val_loss: 9308.2373 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 23s 224ms/step - loss: 1.0557 - categorical_accuracy: 0.5811 - top_5_categorical_accuracy: 1.0000 - precision: 0.7608 - recall: 0.3892 - cosine_similarity: 0.6617 - val_loss: 5017.2100 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 1.0257 - categorical_accuracy: 0.5928 - top_5_categorical_accuracy: 1.0000 - precision: 0.7559 - recall: 0.4016 - cosine_similarity: 0.6707 - val_loss: 7553.9883 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 23s 225ms/step - loss: 1.0182 - categorical_accuracy: 0.5970 - top_5_categorical_accuracy: 1.0000 - precision: 0.7689 - recall: 0.4059 - cosine_similarity: 0.6751 - val_loss: 2815.5637 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 224ms/step - loss: 0.9805 - categorical_accuracy: 0.6167 - top_5_categorical_accuracy: 1.0000 - precision: 0.7759 - recall: 0.4252 - cosine_similarity: 0.6881 - val_loss: 9458.9111 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.9602 - categorical_accuracy: 0.6275 - top_5_categorical_accuracy: 1.0000 - precision: 0.7772 - recall: 0.4350 - cosine_similarity: 0.6940 - val_loss: 12618.7998 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.9241 - categorical_accuracy: 0.6428 - top_5_categorical_accuracy: 1.0000 - precision: 0.7996 - recall: 0.4644 - cosine_similarity: 0.7071 - val_loss: 6803.7310 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.9084 - categorical_accuracy: 0.6466 - top_5_categorical_accuracy: 1.0000 - precision: 0.7958 - recall: 0.4708 - cosine_similarity: 0.7120 - val_loss: 8589.9404 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.8862 - categorical_accuracy: 0.6580 - top_5_categorical_accuracy: 1.0000 - precision: 0.8037 - recall: 0.4837 - cosine_similarity: 0.7193 - val_loss: 12074.7051 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.8644 - categorical_accuracy: 0.6673 - top_5_categorical_accuracy: 1.0000 - precision: 0.8139 - recall: 0.5017 - cosine_similarity: 0.7278 - val_loss: 8530.9219 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.8431 - categorical_accuracy: 0.6716 - top_5_categorical_accuracy: 1.0000 - precision: 0.8102 - recall: 0.5189 - cosine_similarity: 0.7338 - val_loss: 17259.6211 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.8011 - categorical_accuracy: 0.6942 - top_5_categorical_accuracy: 1.0000 - precision: 0.8263 - recall: 0.5381 - cosine_similarity: 0.7482 - val_loss: 10556.8408 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.8109 - categorical_accuracy: 0.6917 - top_5_categorical_accuracy: 1.0000 - precision: 0.8182 - recall: 0.5381 - cosine_similarity: 0.7455 - val_loss: 1762.4689 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.7664 - categorical_accuracy: 0.7091 - top_5_categorical_accuracy: 1.0000 - precision: 0.8289 - recall: 0.5661 - cosine_similarity: 0.7598 - val_loss: 7030.5957 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.7255 - categorical_accuracy: 0.7306 - top_5_categorical_accuracy: 1.0000 - precision: 0.8410 - recall: 0.5934 - cosine_similarity: 0.7747 - val_loss: 5372.2046 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.7280 - categorical_accuracy: 0.7233 - top_5_categorical_accuracy: 1.0000 - precision: 0.8356 - recall: 0.5973 - cosine_similarity: 0.7719 - val_loss: 15786.9424 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.6858 - categorical_accuracy: 0.7481 - top_5_categorical_accuracy: 1.0000 - precision: 0.8466 - recall: 0.6267 - cosine_similarity: 0.7882 - val_loss: 14891.3125 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.6780 - categorical_accuracy: 0.7417 - top_5_categorical_accuracy: 1.0000 - precision: 0.8416 - recall: 0.6242 - cosine_similarity: 0.7882 - val_loss: 7476.3774 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.6462 - categorical_accuracy: 0.7581 - top_5_categorical_accuracy: 1.0000 - precision: 0.8513 - recall: 0.6492 - cosine_similarity: 0.7998 - val_loss: 16868.6172 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.6276 - categorical_accuracy: 0.7658 - top_5_categorical_accuracy: 1.0000 - precision: 0.8506 - recall: 0.6689 - cosine_similarity: 0.8065 - val_loss: 23882.5645 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.6134 - categorical_accuracy: 0.7739 - top_5_categorical_accuracy: 1.0000 - precision: 0.8533 - recall: 0.6809 - cosine_similarity: 0.8115 - val_loss: 19437.0547 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.5730 - categorical_accuracy: 0.7895 - top_5_categorical_accuracy: 1.0000 - precision: 0.8607 - recall: 0.6952 - cosine_similarity: 0.8246 - val_loss: 14538.6299 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.5421 - categorical_accuracy: 0.8044 - top_5_categorical_accuracy: 1.0000 - precision: 0.8720 - recall: 0.7205 - cosine_similarity: 0.8337 - val_loss: 24145.9355 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.5436 - categorical_accuracy: 0.8002 - top_5_categorical_accuracy: 1.0000 - precision: 0.8624 - recall: 0.7259 - cosine_similarity: 0.8336 - val_loss: 10882.0078 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.4998 - categorical_accuracy: 0.8142 - top_5_categorical_accuracy: 1.0000 - precision: 0.8775 - recall: 0.7475 - cosine_similarity: 0.8469 - val_loss: 15104.4219 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.4858 - categorical_accuracy: 0.8311 - top_5_categorical_accuracy: 1.0000 - precision: 0.8829 - recall: 0.7666 - cosine_similarity: 0.8549 - val_loss: 8359.0674 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.4442 - categorical_accuracy: 0.8447 - top_5_categorical_accuracy: 1.0000 - precision: 0.8921 - recall: 0.7858 - cosine_similarity: 0.8673 - val_loss: 67703.8516 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.4483 - categorical_accuracy: 0.8380 - top_5_categorical_accuracy: 1.0000 - precision: 0.8813 - recall: 0.7845 - cosine_similarity: 0.8643 - val_loss: 34846.3711 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.4174 - categorical_accuracy: 0.8556 - top_5_categorical_accuracy: 1.0000 - precision: 0.8957 - recall: 0.8009 - cosine_similarity: 0.8763 - val_loss: 17936.6309 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.4041 - categorical_accuracy: 0.8531 - top_5_categorical_accuracy: 1.0000 - precision: 0.8948 - recall: 0.8138 - cosine_similarity: 0.8794 - val_loss: 23934.9902 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.3845 - categorical_accuracy: 0.8662 - top_5_categorical_accuracy: 1.0000 - precision: 0.9018 - recall: 0.8223 - cosine_similarity: 0.8852 - val_loss: 15496.6396 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.3448 - categorical_accuracy: 0.8838 - top_5_categorical_accuracy: 1.0000 - precision: 0.9145 - recall: 0.8487 - cosine_similarity: 0.9002 - val_loss: 57451.1875 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.3762 - categorical_accuracy: 0.8681 - top_5_categorical_accuracy: 1.0000 - precision: 0.9014 - recall: 0.8327 - cosine_similarity: 0.8880 - val_loss: 32578.6895 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.3440 - categorical_accuracy: 0.8814 - top_5_categorical_accuracy: 1.0000 - precision: 0.9080 - recall: 0.8480 - cosine_similarity: 0.8982 - val_loss: 30953.7695 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.3378 - categorical_accuracy: 0.8861 - top_5_categorical_accuracy: 1.0000 - precision: 0.9107 - recall: 0.8522 - cosine_similarity: 0.9005 - val_loss: 24395.8965 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.2898 - categorical_accuracy: 0.9097 - top_5_categorical_accuracy: 1.0000 - precision: 0.9302 - recall: 0.8847 - cosine_similarity: 0.9183 - val_loss: 29675.2148 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.3907 - categorical_accuracy: 0.8714 - top_5_categorical_accuracy: 1.0000 - precision: 0.8947 - recall: 0.8473 - cosine_similarity: 0.8907 - val_loss: 19255.9629 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.2845 - categorical_accuracy: 0.9003 - top_5_categorical_accuracy: 1.0000 - precision: 0.9237 - recall: 0.8722 - cosine_similarity: 0.9158 - val_loss: 35256.2109 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.2267 - categorical_accuracy: 0.9298 - top_5_categorical_accuracy: 1.0000 - precision: 0.9460 - recall: 0.9091 - cosine_similarity: 0.9377 - val_loss: 2447.4885 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.1862 - categorical_accuracy: 0.9448 - top_5_categorical_accuracy: 1.0000 - precision: 0.9566 - recall: 0.9305 - cosine_similarity: 0.9501 - val_loss: 8444.0635 - val_categorical_accuracy: 0.1492 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1492 - val_recall: 0.1492 - val_cosine_similarity: 0.1492
# 100/100 [==============================] - 22s 224ms/step - loss: 0.1938 - categorical_accuracy: 0.9409 - top_5_categorical_accuracy: 1.0000 - precision: 0.9534 - recall: 0.9266 - cosine_similarity: 0.9475 - val_loss: 22297.0547 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.1837 - categorical_accuracy: 0.9413 - top_5_categorical_accuracy: 1.0000 - precision: 0.9540 - recall: 0.9275 - cosine_similarity: 0.9495 - val_loss: 2544.6589 - val_categorical_accuracy: 0.1492 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1492 - val_recall: 0.1492 - val_cosine_similarity: 0.1492
# 100/100 [==============================] - 22s 223ms/step - loss: 0.2117 - categorical_accuracy: 0.9280 - top_5_categorical_accuracy: 1.0000 - precision: 0.9414 - recall: 0.9136 - cosine_similarity: 0.9390 - val_loss: 9220.1387 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 0.2677 - categorical_accuracy: 0.9086 - top_5_categorical_accuracy: 1.0000 - precision: 0.9232 - recall: 0.8897 - cosine_similarity: 0.9220 - val_loss: 12341.7988 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.1620 - categorical_accuracy: 0.9506 - top_5_categorical_accuracy: 1.0000 - precision: 0.9604 - recall: 0.9403 - cosine_similarity: 0.9554 - val_loss: 13931.5078 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.1259 - categorical_accuracy: 0.9644 - top_5_categorical_accuracy: 1.0000 - precision: 0.9715 - recall: 0.9542 - cosine_similarity: 0.9679 - val_loss: 10373.2168 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0
- val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0271 - categorical_accuracy: 0.9972 - top_5_categorical_accuracy: 1.0000 - precision: 0.9981 - recall: 0.9970 - cosine_similarity: 0.9966 - val_loss: 20907.0742 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0248 - categorical_accuracy: 0.9978 - top_5_categorical_accuracy: 1.0000 - precision: 0.9984 - recall: 0.9975 - cosine_similarity: 0.9971 - val_loss: 10530.3154 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0183 - categorical_accuracy: 0.9994 - top_5_categorical_accuracy: 1.0000 - precision: 0.9997 - recall: 0.9991 - cosine_similarity: 0.9983 - val_loss: 2320.4446 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# ...
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0081 - categorical_accuracy: 0.9997 - top_5_categorical_accuracy: 1.0000 - precision: 0.9997 - recall: 0.9995 - cosine_similarity: 0.9995 - val_loss: 474.1941 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0067 - categorical_accuracy: 0.9997 - top_5_categorical_accuracy: 1.0000 - precision: 0.9997 - recall: 0.9997 - cosine_similarity: 0.9996 - val_loss: 825.6065 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0067 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 0.9998 - cosine_similarity: 0.9997 - val_loss: 5382.9961 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0051 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9998 - val_loss: 1094.1107 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0052 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 0.9998 - cosine_similarity: 0.9998 - val_loss: 610.8290 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0050 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 1943.9736 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0038 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 859.1498 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0038 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 1019.1873 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0039 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 1805.3781 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0049 - categorical_accuracy: 0.9997 - top_5_categorical_accuracy: 1.0000 - precision: 0.9997 - recall: 0.9997 - cosine_similarity: 0.9996 - val_loss: 4477.0015 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0080 - categorical_accuracy: 0.9994 - top_5_categorical_accuracy: 1.0000 - precision: 0.9994 - recall: 0.9994 - cosine_similarity: 0.9991 - val_loss: 790.2810 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0038 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 565.1418 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0036 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 672.4496 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0036 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9998 - val_loss: 703.6077 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0062 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9997 - val_loss: 3951.8711 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0049 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9997 - val_loss: 616.8239 - val_categorical_accuracy: 0.2668 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2668 - val_recall: 0.2668 - val_cosine_similarity: 0.2668
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0034 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 618.7017 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0033 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 4867.1025 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 23s 225ms/step - loss: 0.0035 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 0.9998 - cosine_similarity: 0.9999 - val_loss: 10053.8779 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 23s 225ms/step - loss: 0.0029 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 411.0692 - val_categorical_accuracy: 0.1030 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1030 - val_recall: 0.1030 - val_cosine_similarity: 0.1034
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0025 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 1389.2295 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0022 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 109.2568 - val_categorical_accuracy: 0.1007 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1007 - val_recall: 0.1007 - val_cosine_similarity: 0.1008
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0022 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 867.0222 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0029 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9998 - val_loss: 3218.6404 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0035 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9998 - val_loss: 77.6691 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 173.5979 - val_categorical_accuracy: 0.1494 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1494 - val_recall: 0.1494 - val_cosine_similarity: 0.1495
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0027 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9999 - val_loss: 58.4477 - val_categorical_accuracy: 0.3683 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3683 - val_recall: 0.3683 - val_cosine_similarity: 0.3717
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 126.0971 - val_categorical_accuracy: 0.2667 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2667 - val_recall: 0.2667 - val_cosine_similarity: 0.2667
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0022 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 0.9998 - cosine_similarity: 0.9999 - val_loss: 6603.3877 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0025 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 592.8776 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0019 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 6274.3750 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 23s 225ms/step - loss: 0.0020 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 0.9999 - val_loss: 3165.2302 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3665 - val_recall: 0.3665 - val_cosine_similarity: 0.3665
# 100/100 [==============================] - 23s 225ms/step - loss: 0.0019 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 738.7358 - val_categorical_accuracy: 0.2666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2666 - val_recall: 0.2666 - val_cosine_similarity: 0.2666
# 100/100 [==============================] - 23s 225ms/step - loss: 0.0018 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 1248.1152 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0018 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 115.3790 - val_categorical_accuracy: 0.1492 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1492 - val_recall: 0.1492 - val_cosine_similarity: 0.1492
# 100/100 [==============================] - 22s 224ms/step - loss: 0.0014 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 67.7386 - val_categorical_accuracy: 0.1113 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1113 - val_recall: 0.1113 - val_cosine_similarity: 0.1147
# 100/100 [==============================] - 22s 223ms/step - loss: 0.0013 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 1477.1516 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 23s 226ms/step - loss: 0.0014 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 734.0605 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 23s 226ms/step - loss: 0.0014 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 188.1318 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002
# 100/100 [==============================] - 23s 226ms/step - loss: 0.0016 - categorical_accuracy: 0.9998 - top_5_categorical_accuracy: 1.0000 - precision: 0.9998 - recall: 0.9998 - cosine_similarity: 0.9999 - val_loss: 305.6754 - val_categorical_accuracy: 0.1492 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1492 - val_recall: 0.1492 - val_cosine_similarity: 0.1492
# 100/100 [==============================] - 23s 225ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - cosine_similarity: 1.0000 - val_loss: 132.2968 - val_categorical_accuracy: 0.3365 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3365 - val_recall: 0.3365 - val_cosine_similarity: 0.3538
# 100/100 [==============================] - 23s 227ms/step - loss: 0.0016 - categorical_accuracy: 1.0000 - top_5_categorical_accuracy: 1.0000 - precision: 1.0000 - recall: 0.9998 - cosine_similarity: 0.9999 - val_loss: 1128.7158 - val_categorical_accuracy: 0.1002 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1002 - val_recall: 0.1002 - val_cosine_similarity: 0.1002

# %%
import matplotlib.pyplot as plt

# Create a single figure for all subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

# Plot training and validation loss
axes[0, 0].plot(mobilevit_train_losses, label='Training Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(mobilevit_val_losses, label='Validation Loss', linestyle='--', linewidth=2)
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].set_title('Training and Validation Loss (MOBILEVIT)')

# Plot training and validation accuracy
axes[0, 1].plot(mobilevit_train_accuracies, label='Training Accuracy', linestyle='-', linewidth=2)
axes[0, 1].plot(mobilevit_val_accuracies, label='Validation Accuracy', linestyle='--', linewidth=2)
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].set_title('Training and Validation Accuracy (MOBILEVIT)')

# Plot precision, recall, and cosine similarity
axes[0, 2].plot(mobilevit_train_precisions, label='Training Precision', linestyle='-', linewidth=2)
axes[0, 2].plot(mobilevit_val_precisions, label='Validation Precision', linestyle='--', linewidth=2)
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend()
axes[0, 2].set_title('Training and Validation Precision (MOBILEVIT)')

axes[1, 0].plot(mobilevit_train_recalls, label='Training Recall', linestyle='-', linewidth=2)
axes[1, 0].plot(mobilevit_val_recalls, label='Validation Recall', linestyle='--', linewidth=2)
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend()
axes[1, 0].set_title('Training and Validation Recall (MOBILEVIT)')

axes[1, 1].plot(mobilevit_train_cosine_similarity, label='Training Cosine Similarity', linestyle='-', linewidth=2)
axes[1, 1].plot(mobilevit_val_cosine_similarity, label='Validation Cosine Similarity', linestyle='--', linewidth=2)
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Cosine Similarity')
axes[1, 1].legend()
axes[1, 1].set_title('Training and Validation Cosine Similarity (MOBILEVIT)')

# Ensure that the layout is tight
plt.tight_layout()

plt.show()

# %%
positional_emb = False
conv_layers = 1
projection_dim = 64

num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
transformer_layers = 2
stochastic_depth_rate = 0.1

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 64
num_epochs = 100
image_size = 80

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super().__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %%
# Referred from: github.com:rwightman/pytorch-image-models.
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prop

    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (tf.shape(x).shape[0] - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
def create_cct_model(
    image_size=image_size,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_layers=200,  # Increase the number of transformer layers
    hidden_dim=16384,        # Increase the hidden dimension
    stochastic_depth_rate=0.1,
    num_classes=num_classes,
):
    inputs = layers.Input(input_shape)



    # Multi-Head Self-Attention Block
    for i in range(transformer_layers):

        # Encode patches.
        cct_tokenizer = CCTTokenizer()
        encoded_patches = cct_tokenizer(inputs)

        # Calculate Stochastic Depth probabilities.
        dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

        x = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Skip connection
        attention_output = layers.Dropout(rate=dpr[i])(x)
        encoded_patches = layers.Add()([attention_output, encoded_patches])

    # Sequence Pooling
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Feedforward layers with increased hidden dimension
    x = layers.Dense(hidden_dim, activation="relu")(weighted_representation)
    x = layers.Dropout(0.5)(x)

    # Classification Layer
    logits = layers.Dense(num_classes, activation="softmax")(x)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
cct = create_cct_model()

cct.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 80, 80, 3)]          0         []
#
#  cct_tokenizer_199 (CCTToke  (None, 1600, 64)             1728      ['input_4[0][0]']
#  nizer)
#
#  layer_normalization_212 (L  (None, 1600, 64)             128       ['cct_tokenizer_199[0][0]']
#  ayerNormalization)
#
#  dropout_211 (Dropout)       (None, 1600, 64)             0         ['layer_normalization_212[0][0
#                                                                     ]']
#
#  add_210 (Add)               (None, 1600, 64)             0         ['dropout_211[0][0]',
#                                                                      'cct_tokenizer_199[0][0]']
#
#  layer_normalization_213 (L  (None, 1600, 64)             128       ['add_210[0][0]']
#  ayerNormalization)
#
#  dense_16 (Dense)            (None, 1600, 1)              65        ['layer_normalization_213[0][0
#                                                                     ]']
#
#  tf.nn.softmax (TFOpLambda)  (None, 1600, 1)              0         ['dense_16[0][0]']
#
#  tf.linalg.matmul (TFOpLamb  (None, 1, 64)                0         ['tf.nn.softmax[0][0]',
#  da)                                                                 'layer_normalization_213[0][0
#                                                                     ]']
#
#  tf.compat.v1.squeeze (TFOp  (None, 64)                   0         ['tf.linalg.matmul[0][0]']
#  Lambda)
#
#  dense_17 (Dense)            (None, 16384)                1064960   ['tf.compat.v1.squeeze[0][0]']
#
#  dropout_212 (Dropout)       (None, 16384)                0         ['dense_17[0][0]']
#
#  dense_18 (Dense)            (None, 5)                    81925     ['dropout_212[0][0]']
#
# ==================================================================================================
# Total params: 1148934 (4.38 MB)
# Trainable params: 1148934 (4.38 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Define early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',  # You can choose any metric to monitor
    patience=30,          # Number of epochs with no improvement after which training will be stopped
    verbose=1,
    restore_best_weights=True  # Do restore best weights
)

# Compile the model
cct.compile(
    optimizer=tf.keras.optimizers.SGD(),
    loss=tf.keras.losses.CategoricalCrossentropy(),
    metrics=[
        tf.keras.metrics.CategoricalAccuracy(name='categorical_accuracy'),
        tf.keras.metrics.TopKCategoricalAccuracy(k=5, name='top_5_categorical_accuracy'),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.CosineSimilarity(name='cosine_similarity')
    ]
)

# Initialize variables to keep track of the best validation loss and corresponding model weights
best_val_loss = float('inf')
best_weights = None

# Lists to store training and validation metrics
cct_train_losses = []
cct_val_losses = []
cct_train_accuracies = []
cct_val_accuracies = []
cct_train_precisions = []
cct_val_precisions = []
cct_train_recalls = []
cct_val_recalls = []
cct_train_cosine_similarity = []
cct_val_cosine_similarity = []

for epoch in range(200):
    # Train the model for one epoch
    #history = cct.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping],class_weight = class_weights)
    history = cct.fit(train_ds, epochs=1, validation_data=val_ds,steps_per_epoch = 100, callbacks=[early_stopping])
    # Append training and validation metrics for plotting
    cct_train_losses.append(history.history['loss'][0])
    cct_val_losses.append(history.history['val_loss'][0])
    cct_train_accuracies.append(history.history['categorical_accuracy'][0])
    cct_val_accuracies.append(history.history['val_categorical_accuracy'][0])
    cct_train_precisions.append(history.history['precision'][0])
    cct_val_precisions.append(history.history['val_precision'][0])
    cct_train_recalls.append(history.history['recall'][0])
    cct_val_recalls.append(history.history['val_recall'][0])
    cct_train_cosine_similarity.append(history.history['cosine_similarity'][0])
    cct_val_cosine_similarity.append(history.history['val_cosine_similarity'][0])

    # Check if the current validation loss is better than the best seen so far
    if history.history['val_loss'][0] < best_val_loss:
        best_val_loss = history.history['val_loss'][0]
        best_weights = cct.get_weights()
        # You can also save the weights to a file here if desired

# After training, you can set the model weights to the best weights
cct.set_weights(best_weights)

# Now you have the training and validation metrics (loss, accuracy, precision, recall, and cosine similarity) stored in the respective lists.
# Out:
# 100/100 [==============================] - 9s 67ms/step - loss: 1.4925 - categorical_accuracy: 0.3622 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.4992 - val_loss: 1.4986 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4969
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4866 - categorical_accuracy: 0.3728 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5019 - val_loss: 1.5020 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4945
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4900 - categorical_accuracy: 0.3672 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5004 - val_loss: 1.4895 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5005
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4874 - categorical_accuracy: 0.3694 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5015 - val_loss: 1.4902 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.4995
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4874 - categorical_accuracy: 0.3716 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5013 - val_loss: 1.4896 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5002
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4855 - categorical_accuracy: 0.3692 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5022 - val_loss: 1.4871 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5013
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4880 - categorical_accuracy: 0.3708 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5014 - val_loss: 1.4876 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5009
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4850 - categorical_accuracy: 0.3703 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5025 - val_loss: 1.4884 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5007
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4844 - categorical_accuracy: 0.3713 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5027 - val_loss: 1.4875 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5010
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4848 - categorical_accuracy: 0.3709 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5024 - val_loss: 1.4877 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5007
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4827 - categorical_accuracy: 0.3727 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5035 - val_loss: 1.4882 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5005
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4856 - categorical_accuracy: 0.3678 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5019 - val_loss: 1.4863 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5015
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4833 - categorical_accuracy: 0.3700 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5030 - val_loss: 1.4879 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5008
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4815 - categorical_accuracy: 0.3734 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4673 - categorical_accuracy: 0.3720 - top_5_categorical_accuracy: 1.0000 - precision: 0.3077 - recall: 6.2500e-04 - cosine_similarity: 0.5089 - val_loss: 1.4735 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5061
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4644 - categorical_accuracy: 0.3745 - top_5_categorical_accuracy: 1.0000 - precision: 0.4167 - recall: 7.8125e-04 - cosine_similarity: 0.5101 - val_loss: 1.4770 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.4221 - val_recall: 0.0152 - val_cosine_similarity: 0.5041
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4675 - categorical_accuracy: 0.3727 - top_5_categorical_accuracy: 1.0000 - precision: 0.3200 - recall: 0.0012 - cosine_similarity: 0.5087 - val_loss: 1.4723 - val_categorical_accuracy: 0.3666 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1667 - val_recall: 6.5079e-04 - val_cosine_similarity: 0.5063
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4657 - categorical_accuracy: 0.3744 - top_5_categorical_accuracy: 1.0000 - precision: 0.7333 - recall: 0.0017 - cosine_similarity: 0.5097 - val_loss: 1.4745 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3889 - val_recall: 0.0073 - val_cosine_similarity: 0.5054
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4663 - categorical_accuracy: 0.3725 - top_5_categorical_accuracy: 1.0000 - precision: 0.4545 - recall: 0.0016 - cosine_similarity: 0.5092 - val_loss: 1.4708 - val_categorical_accuracy: 0.3682 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1833 - val_recall: 7.1587e-04 - val_cosine_similarity: 0.5068
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4662 - categorical_accuracy: 0.3705 - top_5_categorical_accuracy: 1.0000 - precision: 0.4545 - recall: 0.0016 - cosine_similarity: 0.5093 - val_loss: 1.4713 - val_categorical_accuracy: 0.3739 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5067
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4660 - categorical_accuracy: 0.3752 - top_5_categorical_accuracy: 1.0000 - precision: 0.2222 - recall: 6.2500e-04 - cosine_similarity: 0.5091 - val_loss: 1.4734 - val_categorical_accuracy: 0.3665 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.4103 - val_recall: 0.0098 - val_cosine_similarity: 0.5057
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4665 - categorical_accuracy: 0.3739 - top_5_categorical_accuracy: 1.0000 - precision: 0.5600 - recall: 0.0022 - cosine_similarity: 0.5091 - val_loss: 1.4698 - val_categorical_accuracy: 0.3691 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3819 - val_recall: 0.0072 - val_cosine_similarity: 0.5069
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4655 - categorical_accuracy: 0.3755 - top_5_categorical_accuracy: 1.0000 - precision: 0.4857 - recall: 0.0027 - cosine_similarity: 0.5097 - val_loss: 1.4689 - val_categorical_accuracy: 0.3732 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.1579 - val_recall: 1.9524e-04 - val_cosine_similarity: 0.5078
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4606 - categorical_accuracy: 0.3792 - top_5_categorical_accuracy: 1.0000 - precision: 0.5938 - recall: 0.0030 - cosine_similarity: 0.5116 - val_loss: 1.4679 - val_categorical_accuracy: 0.3741 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2959 - val_recall: 0.0019 - val_cosine_similarity: 0.5080
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4619 - categorical_accuracy: 0.3806 - top_5_categorical_accuracy: 1.0000 - precision: 0.5000 - recall: 0.0039 - cosine_similarity: 0.5109 - val_loss: 1.4677 - val_categorical_accuracy: 0.3734 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.2920 - val_recall: 0.0021 - val_cosine_similarity: 0.5080
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4608 - categorical_accuracy: 0.3803 - top_5_categorical_accuracy: 1.0000 - precision: 0.4906 - recall: 0.0041 - cosine_similarity: 0.5115 - val_loss: 1.4672 - val_categorical_accuracy: 0.3743 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.4350 - val_recall: 0.0113 - val_cosine_similarity: 0.5077
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4616 - categorical_accuracy: 0.3784 - top_5_categorical_accuracy: 1.0000 - precision: 0.5000 - recall: 0.0050 - cosine_similarity: 0.5110 - val_loss: 1.4656 - val_categorical_accuracy: 0.3742 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_cosine_similarity: 0.5086
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4594 - categorical_accuracy: 0.3808 - top_5_categorical_accuracy: 1.0000 - precision: 0.4750 - recall: 0.0030 - cosine_similarity: 0.5118 - val_loss: 1.4673 - val_categorical_accuracy: 0.3740 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.4843 - val_recall: 0.0181 - val_cosine_similarity: 0.5078
# 100/100 [==============================] - 7s 67ms/step - loss: 1.4618 - categorical_accuracy: 0.3756 - top_5_categorical_accuracy: 1.0000 - precision: 0.5294 - recall: 0.0042 - cosine_similarity: 0.5105 - val_loss: 1.4645 - val_categorical_accuracy: 0.3766 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3381 - val_recall: 0.0031 - val_cosine_similarity: 0.5089
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4593 - categorical_accuracy: 0.3812 - top_5_categorical_accuracy: 1.0000 - precision: 0.5091 - recall: 0.0044 - cosine_similarity: 0.5117 - val_loss: 1.4666 - val_categorical_accuracy: 0.3740 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.4594 - val_recall: 0.0247 - val_cosine_similarity: 0.5075
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4566 - categorical_accuracy: 0.3777 - top_5_categorical_accuracy: 1.0000 - precision: 0.5125 - recall: 0.0064 - cosine_similarity: 0.5126 - val_loss: 1.4653 - val_categorical_accuracy: 0.3743 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.4606 - val_recall: 0.0239 - val_cosine_similarity: 0.5080
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4589 - categorical_accuracy: 0.3834 - top_5_categorical_accuracy: 1.0000 - precision: 0.5213 - recall: 0.0077 - cosine_similarity: 0.5120 - val_loss: 1.4644 - val_categorical_accuracy: 0.3760 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.4816 - val_recall: 0.0213 - val_cosine_similarity: 0.5085
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4553 - categorical_accuracy: 0.3864 - top_5_categorical_accuracy: 1.0000 - precision: 0.4615 - recall: 0.0075 - cosine_similarity: 0.5135 - val_loss: 1.4629 - val_categorical_accuracy: 0.3756 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.4781 - val_recall: 0.0135 - val_cosine_similarity: 0.5092
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4585 - categorical_accuracy: 0.3805 - top_5_categorical_accuracy: 1.0000 - precision: 0.4537 - recall: 0.0077 - cosine_similarity: 0.5121 - val_loss: 1.4611 - val_categorical_accuracy: 0.3762 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.3721 - val_recall: 0.0021 - val_cosine_similarity: 0.5097
# ...
# 100/100 [==============================] - 6s 64ms/step - loss: 1.4295 - categorical_accuracy: 0.3877 - top_5_categorical_accuracy: 1.0000 - precision: 0.5858 - recall: 0.0400 - cosine_similarity: 0.5208 - val_loss: 1.4360 - val_categorical_accuracy: 0.3821 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5671 - val_recall: 0.0473 - val_cosine_similarity: 0.5166
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4282 - categorical_accuracy: 0.3903 - top_5_categorical_accuracy: 1.0000 - precision: 0.5579 - recall: 0.0369 - cosine_similarity: 0.5210 - val_loss: 1.4379 - val_categorical_accuracy: 0.3838 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5484 - val_recall: 0.0567 - val_cosine_similarity: 0.5163
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4252 - categorical_accuracy: 0.3895 - top_5_categorical_accuracy: 1.0000 - precision: 0.6196 - recall: 0.0425 - cosine_similarity: 0.5222 - val_loss: 1.4342 - val_categorical_accuracy: 0.3859 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5875 - val_recall: 0.0533 - val_cosine_similarity: 0.5174
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4299 - categorical_accuracy: 0.3895 - top_5_categorical_accuracy: 1.0000 - precision: 0.5737 - recall: 0.0389 - cosine_similarity: 0.5200 - val_loss: 1.4322 - val_categorical_accuracy: 0.3865 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5946 - val_recall: 0.0472 - val_cosine_similarity: 0.5179
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4271 - categorical_accuracy: 0.3906 - top_5_categorical_accuracy: 1.0000 - precision: 0.5853 - recall: 0.0397 - cosine_similarity: 0.5208 - val_loss: 1.4333 - val_categorical_accuracy: 0.3841 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5663 - val_recall: 0.0567 - val_cosine_similarity: 0.5175
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4270 - categorical_accuracy: 0.3927 - top_5_categorical_accuracy: 1.0000 - precision: 0.5618 - recall: 0.0405 - cosine_similarity: 0.5214 - val_loss: 1.4322 - val_categorical_accuracy: 0.3814 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5474 - val_recall: 0.0601 - val_cosine_similarity: 0.5176
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4251 - categorical_accuracy: 0.3898 - top_5_categorical_accuracy: 1.0000 - precision: 0.5567 - recall: 0.0406 - cosine_similarity: 0.5210 - val_loss: 1.4298 - val_categorical_accuracy: 0.3875 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5751 - val_recall: 0.0491 - val_cosine_similarity: 0.5186
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4282 - categorical_accuracy: 0.3873 - top_5_categorical_accuracy: 1.0000 - precision: 0.5951 - recall: 0.0420 - cosine_similarity: 0.5201 - val_loss: 1.4301 - val_categorical_accuracy: 0.3881 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5600 - val_recall: 0.0604 - val_cosine_similarity: 0.5186
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4246 - categorical_accuracy: 0.3923 - top_5_categorical_accuracy: 1.0000 - precision: 0.6092 - recall: 0.0453 - cosine_similarity: 0.5219 - val_loss: 1.4275 - val_categorical_accuracy: 0.3892 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5861 - val_recall: 0.0514 - val_cosine_similarity: 0.5193
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4244 - categorical_accuracy: 0.3906 - top_5_categorical_accuracy: 1.0000 - precision: 0.6282 - recall: 0.0494 - cosine_similarity: 0.5218 - val_loss: 1.4263 - val_categorical_accuracy: 0.3909 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.6084 - val_recall: 0.0417 - val_cosine_similarity: 0.5199
# 100/100 [==============================] - 6s 63ms/step - loss: 1.4248 - categorical_accuracy: 0.3908 - top_5_categorical_accuracy: 1.0000 - precision: 0.5821 - recall: 0.0437 - cosine_similarity: 0.5213 - val_loss: 1.4262 - val_categorical_accuracy: 0.3898 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5940 - val_recall: 0.0475 - val_cosine_similarity: 0.5198
# 100/100 [==============================] - 6s 63ms/step - loss: 1.4201 - categorical_accuracy: 0.3928 - top_5_categorical_accuracy: 1.0000 - precision: 0.5981 - recall: 0.0505 - cosine_similarity: 0.5227 - val_loss: 1.4252 - val_categorical_accuracy: 0.3871 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5777 - val_recall: 0.0503 - val_cosine_similarity: 0.5200
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4215 - categorical_accuracy: 0.3927 - top_5_categorical_accuracy: 1.0000 - precision: 0.6022 - recall: 0.0506 - cosine_similarity: 0.5229 - val_loss: 1.4258 - val_categorical_accuracy: 0.3898 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5672 - val_recall: 0.0681 - val_cosine_similarity: 0.5199
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4191 - categorical_accuracy: 0.3903 - top_5_categorical_accuracy: 1.0000 - precision: 0.6035 - recall: 0.0538 - cosine_similarity: 0.5236 - val_loss: 1.4233 - val_categorical_accuracy: 0.3916 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5818 - val_recall: 0.0599 - val_cosine_similarity: 0.5207
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4159 - categorical_accuracy: 0.3927 - top_5_categorical_accuracy: 1.0000 - precision: 0.5892 - recall: 0.0511 - cosine_similarity: 0.5245 - val_loss: 1.4228 - val_categorical_accuracy: 0.3931 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5785 - val_recall: 0.0547 - val_cosine_similarity: 0.5207
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4195 - categorical_accuracy: 0.3900 - top_5_categorical_accuracy: 1.0000 - precision: 0.6052 - recall: 0.0548 - cosine_similarity: 0.5234 - val_loss: 1.4232 - val_categorical_accuracy: 0.3894 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5795 - val_recall: 0.0536 - val_cosine_similarity: 0.5209
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4168 - categorical_accuracy: 0.3903 - top_5_categorical_accuracy: 1.0000 - precision: 0.5889 - recall: 0.0533 - cosine_similarity: 0.5238 - val_loss: 1.4233 - val_categorical_accuracy: 0.3898 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5708 - val_recall: 0.0588 - val_cosine_similarity: 0.5207
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4177 - categorical_accuracy: 0.3909 - top_5_categorical_accuracy: 1.0000 - precision: 0.5952 - recall: 0.0538 - cosine_similarity: 0.5237 - val_loss: 1.4207 - val_categorical_accuracy: 0.3914 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5622 - val_recall: 0.0615 - val_cosine_similarity: 0.5213
# 100/100 [==============================] - 7s 66ms/step - loss: 1.4162 - categorical_accuracy: 0.3922 - top_5_categorical_accuracy: 1.0000 - precision: 0.6061 - recall: 0.0527 - cosine_similarity: 0.5236 - val_loss: 1.4192 - val_categorical_accuracy: 0.3913 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5826 - val_recall: 0.0551 - val_cosine_similarity: 0.5218
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4184 - categorical_accuracy: 0.3866 - top_5_categorical_accuracy: 1.0000 - precision: 0.5790 - recall: 0.0527 - cosine_similarity: 0.5231 - val_loss: 1.4173 - val_categorical_accuracy: 0.3925 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5903 - val_recall: 0.0523 - val_cosine_similarity: 0.5227
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4134 - categorical_accuracy: 0.3895 - top_5_categorical_accuracy: 1.0000 - precision: 0.6101 - recall: 0.0545 - cosine_similarity: 0.5249 - val_loss: 1.4196 - val_categorical_accuracy: 0.3935 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5731 - val_recall: 0.0554 - val_cosine_similarity: 0.5219
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4138 - categorical_accuracy: 0.3889 - top_5_categorical_accuracy: 1.0000 - precision: 0.6000 - recall: 0.0558 - cosine_similarity: 0.5245 - val_loss: 1.4177 - val_categorical_accuracy: 0.3875 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5640 - val_recall: 0.0651 - val_cosine_similarity: 0.5224
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4170 - categorical_accuracy: 0.3894 - top_5_categorical_accuracy: 1.0000 - precision: 0.5769 - recall: 0.0545 - cosine_similarity: 0.5236 - val_loss: 1.4165 - val_categorical_accuracy: 0.3920 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5875 - val_recall: 0.0526 - val_cosine_similarity: 0.5231
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4112 - categorical_accuracy: 0.3986 - top_5_categorical_accuracy: 1.0000 - precision: 0.5788 - recall: 0.0545 - cosine_similarity: 0.5260 - val_loss: 1.4179 - val_categorical_accuracy: 0.3943 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5678 - val_recall: 0.0592 - val_cosine_similarity: 0.5224
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4125 - categorical_accuracy: 0.3947 - top_5_categorical_accuracy: 1.0000 - precision: 0.6109 - recall: 0.0594 - cosine_similarity: 0.5258 - val_loss: 1.4132 - val_categorical_accuracy: 0.3948 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5969 - val_recall: 0.0557 - val_cosine_similarity: 0.5242
# 100/100 [==============================] - 6s 64ms/step - loss: 1.4084 - categorical_accuracy: 0.3961 - top_5_categorical_accuracy: 1.0000 - precision: 0.6100 - recall: 0.0594 - cosine_similarity: 0.5273 - val_loss: 1.4140 - val_categorical_accuracy: 0.3951 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5663 - val_recall: 0.0661 - val_cosine_similarity: 0.5239
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4067 - categorical_accuracy: 0.3944 - top_5_categorical_accuracy: 1.0000 - precision: 0.5978 - recall: 0.0606 - cosine_similarity: 0.5273 - val_loss: 1.4156 - val_categorical_accuracy: 0.3898 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5499 - val_recall: 0.0718 - val_cosine_similarity: 0.5226
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4103 - categorical_accuracy: 0.3958 - top_5_categorical_accuracy: 1.0000 - precision: 0.6051 - recall: 0.0630 - cosine_similarity: 0.5266 - val_loss: 1.4133 - val_categorical_accuracy: 0.3922 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5722 - val_recall: 0.0660 - val_cosine_similarity: 0.5243
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4107 - categorical_accuracy: 0.3930 - top_5_categorical_accuracy: 1.0000 - precision: 0.5928 - recall: 0.0614 - cosine_similarity: 0.5256 - val_loss: 1.4107 - val_categorical_accuracy: 0.4000 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5861 - val_recall: 0.0589 - val_cosine_similarity: 0.5250
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4062 - categorical_accuracy: 0.3936 - top_5_categorical_accuracy: 1.0000 - precision: 0.6018 - recall: 0.0623 - cosine_similarity: 0.5274 - val_loss: 1.4099 - val_categorical_accuracy: 0.3948 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5871 - val_recall: 0.0616 - val_cosine_similarity: 0.5254
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4056 - categorical_accuracy: 0.3930 - top_5_categorical_accuracy: 1.0000 - precision: 0.5967 - recall: 0.0622 - cosine_similarity: 0.5271 - val_loss: 1.4098 - val_categorical_accuracy: 0.3985 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5894 - val_recall: 0.0566 - val_cosine_similarity: 0.5253
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4002 - categorical_accuracy: 0.3941 - top_5_categorical_accuracy: 1.0000 - precision: 0.5859 - recall: 0.0623 - cosine_similarity: 0.5291 - val_loss: 1.4119 - val_categorical_accuracy: 0.3918 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5487 - val_recall: 0.0751 - val_cosine_similarity: 0.5241
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4010 - categorical_accuracy: 0.3988 - top_5_categorical_accuracy: 1.0000 - precision: 0.6033 - recall: 0.0694 - cosine_similarity: 0.5296 - val_loss: 1.4095 - val_categorical_accuracy: 0.3972 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5624 - val_recall: 0.0628 - val_cosine_similarity: 0.5253
# 100/100 [==============================] - 7s 65ms/step - loss: 1.4043 - categorical_accuracy: 0.3933 - top_5_categorical_accuracy: 1.0000 - precision: 0.5973 - recall: 0.0681 - cosine_similarity: 0.5274 - val_loss: 1.4088 - val_categorical_accuracy: 0.3983 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5801 - val_recall: 0.0568 - val_cosine_similarity: 0.5257
# 100/100 [==============================] - 6s 64ms/step - loss: 1.4017 - categorical_accuracy: 0.3961 - top_5_categorical_accuracy: 1.0000 - precision: 0.5907 - recall: 0.0636 - cosine_similarity: 0.5286 - val_loss: 1.4061 - val_categorical_accuracy: 0.3987 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5888 - val_recall: 0.0602 - val_cosine_similarity: 0.5266
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4010 - categorical_accuracy: 0.3991 - top_5_categorical_accuracy: 1.0000 - precision: 0.5917 - recall: 0.0666 - cosine_similarity: 0.5290 - val_loss: 1.4054 - val_categorical_accuracy: 0.3958 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5746 - val_recall: 0.0586 - val_cosine_similarity: 0.5267
# 100/100 [==============================] - 7s 64ms/step - loss: 1.4001 - categorical_accuracy: 0.3973 - top_5_categorical_accuracy: 1.0000 - precision: 0.5892 - recall: 0.0614 - cosine_similarity: 0.5297 - val_loss: 1.4067 - val_categorical_accuracy: 0.3971 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5775 - val_recall: 0.0587 - val_cosine_similarity: 0.5264
# 100/100 [==============================] - 7s 65ms/step - loss: 1.3973 - categorical_accuracy: 0.4041 - top_5_categorical_accuracy: 1.0000 - precision: 0.6116 - recall: 0.0706 - cosine_similarity: 0.5307 - val_loss: 1.4048 - val_categorical_accuracy: 0.3944 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5504 - val_recall: 0.0804 - val_cosine_similarity: 0.5269
# 100/100 [==============================] - 7s 64ms/step - loss: 1.3939 - categorical_accuracy: 0.4022 - top_5_categorical_accuracy: 1.0000 - precision: 0.5950 - recall: 0.0709 - cosine_similarity: 0.5317 - val_loss: 1.4079 - val_categorical_accuracy: 0.3935 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5304 - val_recall: 0.0902 - val_cosine_similarity: 0.5251
# 100/100 [==============================] - 7s 64ms/step - loss: 1.3956 - categorical_accuracy: 0.4030 - top_5_categorical_accuracy: 1.0000 - precision: 0.5944 - recall: 0.0694 - cosine_similarity: 0.5307 - val_loss: 1.4031 - val_categorical_accuracy: 0.4000 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5540 - val_recall: 0.0714 - val_cosine_similarity: 0.5277
# 100/100 [==============================] - 7s 64ms/step - loss: 1.3969 - categorical_accuracy: 0.4022 - top_5_categorical_accuracy: 1.0000 - precision: 0.5925 - recall: 0.0695 - cosine_similarity: 0.5307 - val_loss: 1.4029 - val_categorical_accuracy: 0.3991 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5601 - val_recall: 0.0743 - val_cosine_similarity: 0.5276
# 100/100 [==============================] - 7s 64ms/step - loss: 1.3940 - categorical_accuracy: 0.3984 - top_5_categorical_accuracy: 1.0000 - precision: 0.5959 - recall: 0.0723 - cosine_similarity: 0.5319 - val_loss: 1.4005 - val_categorical_accuracy: 0.3968 - val_top_5_categorical_accuracy: 1.0000 - val_precision: 0.5632 - val_recall: 0.0731 - val_cosine_similarity: 0.5288

# %%
import matplotlib.pyplot as plt

# Create a single figure for all subplots
fig, axes = plt.subplots(2, 3, figsize=(18, 8))

# Plot training and validation loss
axes[0, 0].plot(cct_train_losses, label='Training Loss', linestyle='-', linewidth=2)
axes[0, 0].plot(cct_val_losses, label='Validation Loss', linestyle='--', linewidth=2)
axes[0, 0].set_xlabel('Epochs')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].legend()
axes[0, 0].set_title('Training and Validation Loss (CCT)')

# Plot training and validation accuracy
axes[0, 1].plot(cct_train_accuracies, label='Training Accuracy', linestyle='-', linewidth=2)
axes[0, 1].plot(cct_val_accuracies, label='Validation Accuracy', linestyle='--', linewidth=2)
axes[0, 1].set_xlabel('Epochs')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].legend()
axes[0, 1].set_title('Training and Validation Accuracy (CCT)')

# Plot precision, recall, and cosine similarity
axes[0, 2].plot(cct_train_precisions, label='Training Precision', linestyle='-', linewidth=2)
axes[0, 2].plot(cct_val_precisions, label='Validation Precision', linestyle='--', linewidth=2)
axes[0, 2].set_xlabel('Epochs')
axes[0, 2].set_ylabel('Precision')
axes[0, 2].legend()
axes[0, 2].set_title('Training and Validation Precision (CCT)')

axes[1, 0].plot(cct_train_recalls, label='Training Recall', linestyle='-', linewidth=2)
axes[1, 0].plot(cct_val_recalls, label='Validation Recall', linestyle='--', linewidth=2)
axes[1, 0].set_xlabel('Epochs')
axes[1, 0].set_ylabel('Recall')
axes[1, 0].legend()
axes[1, 0].set_title('Training and Validation Recall (CCT)')

axes[1, 1].plot(cct_train_cosine_similarity, label='Training Cosine Similarity', linestyle='-', linewidth=2)
axes[1, 1].plot(cct_val_cosine_similarity, label='Validation Cosine Similarity', linestyle='--', linewidth=2)
axes[1, 1].set_xlabel('Epochs')
axes[1, 1].set_ylabel('Cosine Similarity')
axes[1, 1].legend()
axes[1, 1].set_title('Training and Validation Cosine Similarity (CCT)')

# Ensure that the layout is tight
plt.tight_layout()

plt.show()

# %%
import os

# Define the directory path where you want to save the models
path = "50K" #Initial
#path = "50K_Cost_sensitive" #Initial
#path = "25K" #Augmented

# Ensure that the directory path exists, or create it if it doesn't
if not os.path.exists(path):
    os.makedirs(path)

# Evaluate the model
evaluation_results = swin.evaluate(test_ds, batch_size=32)
print("Evaluation results:", evaluation_results)
# Save the trained model to a file
#swin.save(f"{path}/swin.h5")
print("Model saved to", f"{path}/swin.h5")

# Evaluate the model
evaluation_results = vit.evaluate(test_ds, batch_size=32)
print("Evaluation results:", evaluation_results)
# Save the trained model to a file
#vit.save(f"{path}/vit.h5")
print("Model saved to", f"{path}/vit.h5")

# Evaluate the model
evaluation_results = mobilevit.evaluate(test_ds, batch_size=32)
print("Evaluation results:", evaluation_results)
# Save the trained model to a file
#mobilevit.save(f"{path}/mobilevit.h5")
print("Model saved to", f"{path}/mobilevit.h5")

# Evaluate the model
evaluation_results = cct.evaluate(test_ds, batch_size=32)
print("Evaluation results:", evaluation_results)
# Save the trained model to a file
#cct.save(f"{path}/cct.h5")
print("Model saved to", f"{path}/cct.h5")
# Out:
# 241/241 [==============================] - 60s 248ms/step - loss: 1.4870 - categorical_accuracy: 0.3665 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5013
# Evaluation results: [1.4869863986968994, 0.3665061295032501, 1.0, 0.0, 0.0, 0.5013179183006287]
# Model saved to 50K/swin.h5
# 241/241 [==============================] - 3s 14ms/step - loss: 1.4866 - categorical_accuracy: 0.3665 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.5014
# Evaluation results: [1.4865844249725342, 0.3665061295032501, 1.0, 0.0, 0.0, 0.501437246799469]
# Model saved to 50K/vit.h5
# 241/241 [==============================] - 10s 40ms/step - loss: 1.5504 - categorical_accuracy: 0.3665 - top_5_categorical_accuracy: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00 - cosine_similarity: 0.4738
# Evaluation results: [1.5504467487335205, 0.3665061295032501, 1.0, 0.0, 0.0, 0.47380486130714417]
# Model saved to 50K/mobilevit.h5
# 241/241 [==============================] - 3s 13ms/step - loss: 1.4024 - categorical_accuracy: 0.3899 - top_5_categorical_accuracy: 1.0000 - precision: 0.5609 - recall: 0.0734 - cosine_similarity: 0.5271
# Evaluation results: [1.402416706085205, 0.3898724317550659, 1.0, 0.5609149932861328, 0.07341837882995605, 0.5270903706550598]
# Model saved to 50K/cct.h5

# %%
# Generate predictions for train, validation, and test datasets
train_predictions = swin.predict(train_ds)
val_predictions = swin.predict(val_ds)
test_predictions = swin.predict(test_ds)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
val_pred_labels = np.argmax(val_predictions, axis=1)
test_pred_labels = np.argmax(test_predictions, axis=1)

# Get true labels for training, validation, and test datasets
train_true_labels = np.concatenate([y for _, y in train_ds], axis=0)
val_true_labels = np.concatenate([y for _, y in val_ds], axis=0)
test_true_labels = np.concatenate([y for _, y in test_ds], axis=0)

# Convert one-hot encoded labels to integer labels
train_true_labels = np.argmax(train_true_labels, axis=1)
val_true_labels = np.argmax(val_true_labels, axis=1)
test_true_labels = np.argmax(test_true_labels, axis=1)

# Calculate confusion matrices
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
val_conf_matrix = confusion_matrix(val_true_labels, val_pred_labels)
test_conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)

# Plot confusion matrices
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.heatmap(train_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Train Confusion Matrix (SWIN)')

plt.subplot(1, 3, 2)
sns.heatmap(val_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Validation Confusion Matrix (SWIN)')

plt.subplot(1, 3, 3)
sns.heatmap(test_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Test Confusion Matrix (SWIN)')

plt.tight_layout()
plt.show()
# Out:
# 321/321 [==============================] - 79s 243ms/step
# 241/241 [==============================] - 58s 242ms/step
# 241/241 [==============================] - 58s 242ms/step

# %%
# Generate predictions for train, validation, and test datasets
train_predictions = vit.predict(train_ds)
val_predictions = vit.predict(val_ds)
test_predictions = vit.predict(test_ds)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
val_pred_labels = np.argmax(val_predictions, axis=1)
test_pred_labels = np.argmax(test_predictions, axis=1)

# Get true labels for training, validation, and test datasets
train_true_labels = np.concatenate([y for _, y in train_ds], axis=0)
val_true_labels = np.concatenate([y for _, y in val_ds], axis=0)
test_true_labels = np.concatenate([y for _, y in test_ds], axis=0)

# Convert one-hot encoded labels to integer labels
train_true_labels = np.argmax(train_true_labels, axis=1)
val_true_labels = np.argmax(val_true_labels, axis=1)
test_true_labels = np.argmax(test_true_labels, axis=1)

# Calculate confusion matrices
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
val_conf_matrix = confusion_matrix(val_true_labels, val_pred_labels)
test_conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)

# Plot confusion matrices
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.heatmap(train_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Train Confusion Matrix (VIT)')

plt.subplot(1, 3, 2)
sns.heatmap(val_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Validation Confusion Matrix (VIT)')

plt.subplot(1, 3, 3)
sns.heatmap(test_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Test Confusion Matrix (VIT)')

plt.tight_layout()
plt.show()
# Out:
# 321/321 [==============================] - 4s 13ms/step
# 241/241 [==============================] - 3s 13ms/step
# 241/241 [==============================] - 3s 13ms/step

# %%
# Generate predictions for train, validation, and test datasets
train_predictions = mobilevit.predict(train_ds)
val_predictions = mobilevit.predict(val_ds)
test_predictions = mobilevit.predict(test_ds)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
val_pred_labels = np.argmax(val_predictions, axis=1)
test_pred_labels = np.argmax(test_predictions, axis=1)

# Get true labels for training, validation, and test datasets
train_true_labels = np.concatenate([y for _, y in train_ds], axis=0)
val_true_labels = np.concatenate([y for _, y in val_ds], axis=0)
test_true_labels = np.concatenate([y for _, y in test_ds], axis=0)

# Convert one-hot encoded labels to integer labels
train_true_labels = np.argmax(train_true_labels, axis=1)
val_true_labels = np.argmax(val_true_labels, axis=1)
test_true_labels = np.argmax(test_true_labels, axis=1)

# Calculate confusion matrices
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
val_conf_matrix = confusion_matrix(val_true_labels, val_pred_labels)
test_conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)

# Plot confusion matrices
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.heatmap(train_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Train Confusion Matrix (MOBILEVIT)')

plt.subplot(1, 3, 2)
sns.heatmap(val_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Validation Confusion Matrix (MOBILEVIT)')

plt.subplot(1, 3, 3)
sns.heatmap(test_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Test Confusion Matrix (MOBILEVIT)')

plt.tight_layout()
plt.show()
# Out:
# 321/321 [==============================] - 12s 37ms/step
# 241/241 [==============================] - 9s 36ms/step
# 241/241 [==============================] - 9s 36ms/step

# %%
# Generate predictions for train, validation, and test datasets
train_predictions = cct.predict(train_ds)
val_predictions = cct.predict(val_ds)
test_predictions = cct.predict(test_ds)

# Convert predictions to class labels
train_pred_labels = np.argmax(train_predictions, axis=1)
val_pred_labels = np.argmax(val_predictions, axis=1)
test_pred_labels = np.argmax(test_predictions, axis=1)

# Get true labels for training, validation, and test datasets
train_true_labels = np.concatenate([y for _, y in train_ds], axis=0)
val_true_labels = np.concatenate([y for _, y in val_ds], axis=0)
test_true_labels = np.concatenate([y for _, y in test_ds], axis=0)

# Convert one-hot encoded labels to integer labels
train_true_labels = np.argmax(train_true_labels, axis=1)
val_true_labels = np.argmax(val_true_labels, axis=1)
test_true_labels = np.argmax(test_true_labels, axis=1)

# Calculate confusion matrices
train_conf_matrix = confusion_matrix(train_true_labels, train_pred_labels)
val_conf_matrix = confusion_matrix(val_true_labels, val_pred_labels)
test_conf_matrix = confusion_matrix(test_true_labels, test_pred_labels)

# Plot confusion matrices
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.heatmap(train_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Train Confusion Matrix (CCT)')

plt.subplot(1, 3, 2)
sns.heatmap(val_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Validation Confusion Matrix (CCT)')

plt.subplot(1, 3, 3)
sns.heatmap(test_conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Test Confusion Matrix (CCT)')

plt.tight_layout()
plt.show()
# Out:
# 321/321 [==============================] - 4s 12ms/step
# 241/241 [==============================] - 3s 12ms/step
# 241/241 [==============================] - 3s 13ms/step

# %%
#pip install shap

# %%
'''
import shap
import matplotlib.pyplot as plt

# Choose an image from the test dataset
image_index = 0  # Change this to the index of the image you want to explain

# Extract the specific image and label using a loop
for i, (image, label) in enumerate(test_ds):
    if i == image_index:
        chosen_image = image
        chosen_label = label
        break

# Create a SHAP explainer with a higher max_evals value
num_features = 300 * 300 * 3  # Number of features in your image
max_evals = 2 * num_features + 1  # Minimum required value
explainer = shap.Explainer(cnn, test_ds.map(lambda x, y: x), max_evals=max_evals)

# Calculate SHAP values for the chosen image
shap_values = explainer(chosen_image)

# Choose the class you want to explain (e.g., class 0)
class_to_explain = 0

# Get the expected value (baseline) for the model's output
expected_value = explainer.expected_value[class_to_explain]

# Plot the SHAP values as an overlay on the image
shap.image_plot(shap_values[class_to_explain], chosen_image.numpy(), show=False)
# Add a title to the plot
plt.title(f'SHAP Explanation for Class {class_to_explain}, Expected Value: {expected_value:.2f}')
# Show the plot
plt.show()
'''
